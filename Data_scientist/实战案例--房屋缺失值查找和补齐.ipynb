# %% [markdown]
# 读取数据

# %%
import pandas
df = pandas.read_csv('house_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 15 columns):
# Unnamed: 0    240 non-null int64
# 標題            240 non-null object
# 产权性质          228 non-null object
# 住宅类别          218 non-null object
# 建筑类别          188 non-null object
# 参考月供          0 non-null float64
# 年代            224 non-null object
# 建筑面积          240 non-null float64
# 户型            240 non-null object
# 楼层            228 non-null object
# 物 业 费         240 non-null object
# 物业类型          240 non-null object
# 结构            181 non-null object
# 装修            228 non-null object
# 總價            237 non-null float64
# dtypes: float64(3), int64(1), object(11)
# memory usage: 28.2+ KB

# %%
df.head(3)
# Out:
#    Unnamed: 0                             標題  产权性质  住宅类别 建筑类别  参考月供     年代  \
# 0           0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年
# 1           1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年
# 2           2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年
#
#      建筑面积        户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0   70.40  2室2厅1厨1卫   中层(共6层)       暂无资料   住宅   平层  精装修    30.6
# 1   49.82  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  288.30  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
del df['Unnamed: 0']#移除一栏

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)       暂无资料   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df = pandas.read_csv('house_data.csv',  index_col=0)#设置第一栏为索引

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)       暂无资料   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %% [markdown]
# 将"暂无资料"变成缺失值

# %%
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df['物 业 费']
# Out:
# 0             暂无资料
# 1          1元/平米・月
# 2        3.5元/平米・月
# 3        0.4元/平米・月
# 4        0.4元/平米・月
# 5       0.85元/平米・月
# 6        3.8元/平米・月
# 7             暂无资料
# 8        0.8元/平米・月
# 9        0.5元/平米・月
# 10         4.3元/・月
# 11      6.5元/平方米・月
# 12       0.6元/平米・月
# 13       0.5元/平米・月
# 14         4.8元/・月
# 15       1.4元/平米・月
# 16       1.5元/平米・月
# 17       0.8元/平米・月
# 18       0.3元/平米・月
# 19       0.3元/平米・月
# 20        2.95元/・月
# 21       0.8元/平米・月
# 22       0.8元/平米・月
# 23      3.05元/平米・月
# 24         3.8元/・月
# 25       0.9元/平米・月
# 26      0.99元/平米・月
# 27            暂无资料
# 28      1.65元/平米・月
# 29       2.1元/平米・月
#           ...
# 210           暂无资料
# 211           暂无资料
# 212       1.86元/・月
# 213        1.9元/・月
# 214           暂无资料
# 215        1.7元/・月
# 216          2元/・月
# 217      0.5元/平米・月
# 218      0.7元/平米・月
# 219        2元/平米・月
# 220      1.4元/平米・月
# 221      0.7元/平米・月
# 222           暂无资料
# 223    2.85元/平方米・月
# 224           暂无资料
# 225      0.7元/平米・月
# ...

# %%
df[df['物 业 费'] == '暂无资料']#回带，把暂无资料的数据提取出来
# Out:
#                                    標題  产权性质   住宅类别 建筑类别  参考月供     年代   建筑面积  \
# 0       急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权   普通住宅   板楼   NaN  1989年   70.4
# 7                纪联小区，，大一房一厅，精装修，，！诚售  个人产权   普通住宅   板楼   NaN  1996年   50.0
# 27     投咨300亿山水六旗主题公园 金色海岸 海景房 得房率110  个人产权   普通住宅  NaN   NaN  2016年   84.0
# 65          老客户转让，首付20万，可，1梯1户，专车接送看房  个人产权   普通住宅  NaN   NaN  2017年   82.0
# 70       南浔古镇，月亮湾花园，南北通透，双轨交汇，配套齐全，得房  个人产权   普通住宅   板楼   NaN  2017年   92.0
# 71           疯了，居然还有这么的房子。房东120万诚心出售。  个人产权   普通住宅   板楼   NaN  2004年   90.0
# 74                   携手途家包租10年，10个点，客  个人产权  酒店式公寓   板楼   NaN  2014年   50.0
# 89        长征新村周围生活配套齐全，3号线，赠送面积大，可看房。  个人产权   普通住宅   钢混   NaN  1985年   35.0
# 124              海宁市，三 双公园，首付三成配套完善，！  个人产权   普通住宅  NaN   NaN  2017年  130.0
# 159      热销三房 别墅区 高铁 首付无忧 古镇风景旁 太湖风景区  个人产权   普通住宅   板楼   NaN    NaN   88.0
# 160             周边六所 高铁旁 风景边 别墅生活圈 户型   商品房   普通住宅   钢混   NaN  2013年   90.0
# ...

# %%
import numpy as np
df.ix[df['物 业 费'] == '暂无资料', '物 业 费'] = np.nan#把暂无资料变为NAN缺失值
#逗号前面是行的筛选，后面是列的
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
#另一种方法
import pandas
df = pandas.read_csv('house_data.csv', na_values='暂无资料',  index_col=0)#把暂无资料变为NAN缺失值
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df.tail(3)
# Out:
#                                  標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 237  6.12双轨，交通便利，配套成熟，购物方便，房东可接受置换！  个人产权  普通住宅   钢混   NaN  2005年   96.82
# 238       业主二次装修，保养好，户型方正，三房朝南，，随时看  个人产权  普通住宅   板楼   NaN  2002年  168.00
# 239   区进门位置 三街坊43平直套通风一房 一梯二户 房东诚心卖  个人产权  普通住宅   板楼   NaN  1996年   43.13
#
#            户型        楼层       物 业 费 物业类型  结构   装修      總價
# 237  2室2厅1厨1卫   高层(共8层)  1.86元/平米・月   住宅  平层  精装修   460.0
# 238  3室2厅1厨2卫  高层(共20层)     2元/平米・月   住宅  平层  简装修  1250.0
# 239  1室1厅1厨1卫   高层(共7层)   0.3元/平米・月   住宅  平层  简装修   278.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 240 entries, 0 to 239
# Data columns (total 14 columns):
# 標題       240 non-null object
# 产权性质     228 non-null object
# 住宅类别     218 non-null object
# 建筑类别     188 non-null object
# 参考月供     0 non-null float64
# 年代       224 non-null object
# 建筑面积     240 non-null float64
# 户型       240 non-null object
# 楼层       228 non-null object
# 物 业 费    215 non-null object
# 物业类型     240 non-null object
# 结构       181 non-null object
# 装修       228 non-null object
# 總價       237 non-null float64
# dtypes: float64(3), object(11)
# memory usage: 28.1+ KB

# %%
#查看列（字段）名称
df.columns
# Out:
# Index(['標題', '产权性质', '住宅类别', '建筑类别', '参考月供', '年代', '建筑面积', '户型', '楼层', '物 业 费',
#        '物业类型', '结构', '装修', '總價'],
#       dtype='object')

# %%
#查看字段类型
df.dtypes
# Out:
# 標題        object
# 产权性质      object
# 住宅类别      object
# 建筑类别      object
# 参考月供     float64
# 年代        object
# 建筑面积     float64
# 户型        object
# 楼层        object
# 物 业 费     object
# 物业类型      object
# 结构        object
# 装修        object
# 總價       float64
# dtype: object

# %%
#取得叙述性统计
df.describe()
# Out:
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:4269: RuntimeWarning: Invalid value encountered in percentile
#   interpolation=interpolation)
#        参考月供        建筑面积            總價
# count   0.0  240.000000    237.000000
# mean    NaN  113.435333    646.092869
# std     NaN   99.199836   1300.349319
# min     NaN   22.500000     30.600000
# 25%     NaN   68.952500           NaN
# 50%     NaN   88.155000           NaN
# 75%     NaN  123.250000           NaN
# max     NaN  731.240000  11000.000000

# %%
#发现缺失值

# %%
df.isnull()#哪些包含了缺失值
# Out:
#         標題   产权性质   住宅类别   建筑类别  参考月供     年代   建筑面积     户型     楼层  物 业 费  \
# 0    False  False  False  False  True  False  False  False  False   True
# 1    False  False  False  False  True  False  False  False  False  False
# 2    False  False  False   True  True  False  False  False  False  False
# 3    False  False   True  False  True  False  False  False  False  False
# 4    False  False  False  False  True  False  False  False  False  False
# 5    False  False   True  False  True  False  False  False  False  False
# 6    False   True   True   True  True   True  False  False   True  False
# 7    False  False  False  False  True  False  False  False  False   True
# 8    False  False  False  False  True  False  False  False  False  False
# 9    False  False  False  False  True  False  False  False  False  False
# 10   False  False  False  False  True  False  False  False  False  False
# 11   False   True   True   True  True   True  False  False   True  False
# ...

# %%
df.isnull().any()#是否有缺失值
# Out:
# 標題       False
# 产权性质      True
# 住宅类别      True
# 建筑类别      True
# 参考月供      True
# 年代        True
# 建筑面积     False
# 户型       False
# 楼层        True
# 物 业 费     True
# 物业类型     False
# 结构        True
# 装修        True
# 總價        True
# dtype: bool

# %%
df.isnull().sum()#每个里有多少个缺失值   参考月供全是缺失值
# Out:
# 標題         0
# 产权性质      12
# 住宅类别      22
# 建筑类别      52
# 参考月供     240
# 年代        16
# 建筑面积       0
# 户型         0
# 楼层        12
# 物 业 费     25
# 物业类型       0
# 结构        59
# 装修        12
# 總價         3
# dtype: int64

# %%
df.isnull().sum() / df.count()#缺失值比例
# Out:
# 標題       0.000000
# 产权性质     0.052632
# 住宅类别     0.100917
# 建筑类别     0.276596
# 参考月供          inf
# 年代       0.071429
# 建筑面积     0.000000
# 户型       0.000000
# 楼层       0.052632
# 物 业 费    0.116279
# 物业类型     0.000000
# 结构       0.325967
# 装修       0.052632
# 總價       0.012658
# dtype: float64

# %%
#删除有缺失值的字段

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼   NaN  1989年   70.40
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼   NaN  1989年   49.82
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN   NaN  2005年  288.30
#
#          户型        楼层      物 业 费 物业类型   结构   装修      總價
# 0  2室2厅1厨1卫   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1  2室1厅0厨1卫   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  4室2厅0厨2卫  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df = df.drop('参考月供', axis = 1)#axis = 1 针对列，因为参考月供都是缺失值

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
#筛选字段

# %%
df['产权性质'].value_counts()
# Out:
# 个人产权     171
# 商品房       54
# 经济适用房      2
# 售后公房       1
# Name: 产权性质, dtype: int64

# %%
df[df['产权性质'] == '个人产权'].head(3)#产权性质中包含个人产权的
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df.iloc[5:7]#取索引值5和6的数据
# Out:
#                       標題 产权性质 住宅类别 建筑类别     年代   建筑面积        户型       楼层  \
# 5      延吉控江一楼天井精装修水丰南北通透  商品房  NaN   板楼  1986年   35.0  1室2厅1厨1卫  低层(共6层)
# 6  纯双拼别墅，外环旁低总价，奢华大厅，美极了  NaN  NaN  NaN    NaN  237.0  4室3厅1厨4卫      NaN
#
#         物 业 费 物业类型   结构   装修      總價
# 5  0.85元/平米・月   住宅   平层  简装修   205.0
# 6   3.8元/平米・月   别墅  NaN  NaN  1000.0

# %%
df.ix[(df['建筑面积'] > 100) & (df['總價'] > 2000) , ].head(1)#筛选，逗号前面放的是行的信息，后面是列的信息
# Out:
#                   標題  产权性质  住宅类别 建筑类别     年代   建筑面积        户型        楼层  \
# 2  大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.3  4室2厅0厨2卫  高层(共40层)
#
#        物 业 费 物业类型   结构   装修      總價
# 2  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df.ix[(df['建筑面积'] > 100) & (df['總價'] > 2000) , ]#筛选，逗号前面放的是行的信息，后面是列的信息
# Out:
#                                     標題  产权性质  住宅类别 建筑类别     年代    建筑面积  \
# 2                    大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30
# 11      绿城豪宅，精品纯独栋，格局方正，双南设计，全明通透，豪华气派   NaN   NaN  NaN    NaN  502.00
# 60   华府天地主营专员+价格可谈+1层1户+看房方便+送车位+高区看湖景  个人产权  普通住宅  NaN  2006年  454.82
# 82              央企品质！厅南北通卧室全南！一线看江！带车位  个人产权  普通住宅  NaN  1900年  186.88
# 103        每一座传世尊邸稀若上天恩赐。。此房仅献给少数人中的少数   NaN   NaN  NaN    NaN  558.00
# 120           九间堂总价低+800平花园+随意装修+超华洲君庭   NaN   NaN  NaN    NaN  551.00
# 121    九间堂别墅+性价比醉高+前后600平庭院+随意设计！超东郊壹号   NaN   NaN  NaN    NaN  625.89
# 122        九间堂+1200平大花园+双面临水+中位置+业主急售！   NaN   NaN  NaN    NaN  731.24
# 142                  !星河湾三期样板间！独有4.2！！  个人产权  普通住宅  NaN  2015年  375.00
# 143           西郊宾馆旁，千林海内，密度低一手现房，复地御西郊  个人产权  普通住宅  NaN  2015年  350.00
# 179      业主定居国外―无奈出售爱房―一手房高区已经售完，从未入住，  个人产权  普通住宅  NaN  2015年  382.00
#
#            户型        楼层       物 业 费 物业类型   结构    装修       總價
# ...

# %%
df.loc[df['建筑面积'] > 100].head(1)
# Out:
#                   標題  产权性质  住宅类别 建筑类别     年代   建筑面积        户型        楼层  \
# 2  大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.3  4室2厅0厨2卫  高层(共40层)
#
#        物 业 费 物业类型   结构   装修      總價
# 2  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df.loc[df['建筑面积'] > 100]
# Out:
#                                      標題   产权性质   住宅类别  建筑类别     年代    建筑面积  \
# 2                     大四房出售，带会所+高区景观+车位   个人产权   普通住宅   NaN  2005年  288.30
# 6                 纯双拼别墅，外环旁低总价，奢华大厅，美极了    NaN    NaN   NaN    NaN  237.00
# 10              11年次新 业主急降 繁华地段 满5年 税费少   个人产权   普通住宅    板楼  2011年  110.00
# 11       绿城豪宅，精品纯独栋，格局方正，双南设计，全明通透，豪华气派    NaN    NaN   NaN    NaN  502.00
# 14         开发商内部保留房,一手房更名,全新豪华装修！带产权车位！   个人产权   普通住宅    钢混  2017年  123.00
# 16              1号线，闸北公园景观房，十院，精装修，生活便利   个人产权   普通住宅    板楼  2002年  103.00
# 23      业主移民急售低于市场价300万高区全屋地暖中央空调送车位有钥匙   个人产权   普通住宅    板楼  2004年  161.09
# 24       迪士尼旁精装一手住宅，绿都绣云里，总价低至280万，日后必涨    商品房   普通住宅    板楼  2016年  116.00
# 26                       宜浩佳园电梯房买到就是赚到.   个人产权   普通住宅    板楼  2008年  110.42
# 28      嘉利明珠城南北直通两房 中区楼层 价格实惠 业主买好本小区三房   个人产权   普通住宅    板楼  2005年  109.00
# 29            近地铁精装下叠加别墅，送花园，送地下室和私家车库，    NaN    NaN   NaN    NaN  125.00
# ...

# %%
df = df[df['产权性质'] == '个人产权']
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df['产权性质'].value_counts()
# Out:
# 个人产权    171
# Name: 产权性质, dtype: int64

# %%
#舍弃包含缺失值的字段

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df[df['建筑类别'].isnull()].head(3)
# Out:
#                                 標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 2                大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
# 12          月浦八村繁华地段 毗邻公园双南两房 双轨交通  个人产权  普通住宅  NaN  1991年   47.12  2室0厅0厨1卫
# 27  投咨300亿山水六旗主题公园 金色海岸 海景房 得房率110  个人产权  普通住宅  NaN  2016年   84.00  2室2厅0厨1卫
#
#           楼层      物 业 费 物业类型   结构   装修      總價
# 2   高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0
# 12   高层(共6层)  0.6元/平米・月   住宅  NaN  中装修   180.0
# 27  中层(共15层)        NaN   住宅  NaN   毛坯    80.0

# %%
df = df.dropna(axis=1, how='all')#全部为缺失值则舍弃

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
#补齐缺失值

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)        NaN   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df['物 业 费'] =df['物 业 费'].fillna(0)#物业费缺失值用0替换

# %%
df.head(3)
# Out:
#                               標題  产权性质  住宅类别 建筑类别     年代    建筑面积        户型  \
# 0  急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权  普通住宅   板楼  1989年   70.40  2室2厅1厨1卫
# 1       世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权  普通住宅   塔楼  1989年   49.82  2室1厅0厨1卫
# 2              大四房出售，带会所+高区景观+车位  个人产权  普通住宅  NaN  2005年  288.30  4室2厅0厨2卫
#
#          楼层      物 业 费 物业类型   结构   装修      總價
# 0   中层(共6层)          0   住宅   平层  精装修    30.6
# 1   中层(共6层)    1元/平米・月   住宅   平层  简装修   418.0
# 2  高层(共40层)  3.5元/平米・月   住宅  NaN  精装修  2650.0

# %%
df
# Out:
#                                    標題  产权性质   住宅类别 建筑类别  参考月供     年代    建筑面积  \
# 0       急售70年产权房源 房东装修 户型正气 产证清晰 随时看房  个人产权   普通住宅   板楼   NaN  1989年   70.40
# 1            世纪大道站  福山外国语+建平西校 看房随时急卖  个人产权   普通住宅   塔楼   NaN  1989年   49.82
# 2                   大四房出售，带会所+高区景观+车位  个人产权   普通住宅  NaN   NaN  2005年  288.30
# 3            精装二房全明户型户型好客厅主卧朝南带阳台看房方便   商品房    NaN   板楼   NaN  1994年   56.00
# 4        满五税费少,房东接受置换客户,房东这边房子已经看好,急卖  个人产权   普通住宅   钢混   NaN  1998年   58.00
# 5                   延吉控江一楼天井精装修水丰南北通透   商品房    NaN   板楼   NaN  1986年   35.00
# 6               纯双拼别墅，外环旁低总价，奢华大厅，美极了   NaN    NaN  NaN   NaN    NaN  237.00
# 7                纪联小区，，大一房一厅，精装修，，！诚售  个人产权   普通住宅   板楼   NaN  1996年   50.00
# 8       特荐：淞南精品实惠小户型 双南户型 一梯两户 性价比很高哦   商品房   普通住宅   塔楼   NaN  1994年   68.81
# 9             成熟正规小区。二楼。双南两房。距离 看房随时。  个人产权   普通住宅   板楼   NaN  1996年   72.00
# 10            11年次新 业主急降 繁华地段 满5年 税费少  个人产权   普通住宅   板楼   NaN  2011年  110.00
# ...
