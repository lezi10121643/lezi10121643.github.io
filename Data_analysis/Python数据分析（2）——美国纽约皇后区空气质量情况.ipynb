# %%
import pandas as pd
df = pd.read_csv('pollution_us_2000_2016.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
# 4           4           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#    Date Local          NO2 Units  ...            SO2 Units  SO2 Mean  \
# 0  2000-01-01  Parts per billion  ...    Parts per billion  3.000000
# 1  2000-01-01  Parts per billion  ...    Parts per billion  3.000000
# 2  2000-01-01  Parts per billion  ...    Parts per billion  2.975000
# 3  2000-01-01  Parts per billion  ...    Parts per billion  2.975000
# 4  2000-01-02  Parts per billion  ...    Parts per billion  1.958333
#
#    SO2 1st Max Value  SO2 1st Max Hour SO2 AQI           CO Units   CO Mean  \
# 0                9.0                21    13.0  Parts per million  1.145833
# 1                9.0                21    13.0  Parts per million  0.878947
# 2                6.6                23     NaN  Parts per million  1.145833
# 3                6.6                23     NaN  Parts per million  0.878947
# 4                3.0                22     4.0  Parts per million  0.850000
#
#    CO 1st Max Value  CO 1st Max Hour CO AQI
# 0               4.2               21    NaN
# 1               2.2               23   25.0
# 2               4.2               21    NaN
# 3               2.2               23   25.0
# 4               1.6               23    NaN
#
# [5 rows x 29 columns]

# %%
del df['Unnamed: 0']


df.head()
# Out:
#    State Code  County Code  Site Num                                  Address  \
# 0           4           13      3002  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1           4           13      3002  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 2           4           13      3002  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 3           4           13      3002  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 4           4           13      3002  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
#
#      State    County     City  Date Local          NO2 Units   NO2 Mean  \
# 0  Arizona  Maricopa  Phoenix  2000-01-01  Parts per billion  19.041667
# 1  Arizona  Maricopa  Phoenix  2000-01-01  Parts per billion  19.041667
# 2  Arizona  Maricopa  Phoenix  2000-01-01  Parts per billion  19.041667
# 3  Arizona  Maricopa  Phoenix  2000-01-01  Parts per billion  19.041667
# 4  Arizona  Maricopa  Phoenix  2000-01-02  Parts per billion  22.958333
#
#     ...            SO2 Units  SO2 Mean  SO2 1st Max Value SO2 1st Max Hour  \
# 0   ...    Parts per billion  3.000000                9.0               21
# 1   ...    Parts per billion  3.000000                9.0               21
# 2   ...    Parts per billion  2.975000                6.6               23
# 3   ...    Parts per billion  2.975000                6.6               23
# 4   ...    Parts per billion  1.958333                3.0               22
#
#    SO2 AQI           CO Units   CO Mean  CO 1st Max Value CO 1st Max Hour  \
# 0     13.0  Parts per million  1.145833               4.2              21
# 1     13.0  Parts per million  0.878947               2.2              23
# 2      NaN  Parts per million  1.145833               4.2              21
# 3      NaN  Parts per million  0.878947               2.2              23
# 4      4.0  Parts per million  0.850000               1.6              23
#
#    CO AQI
# 0     NaN
# 1    25.0
# 2     NaN
# 3    25.0
# 4     NaN
#
# [5 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1746661 entries, 0 to 1746660
# Data columns (total 28 columns):
# State Code           int64
# County Code          int64
# Site Num             int64
# Address              object
# State                object
# County               object
# City                 object
# Date Local           object
# NO2 Units            object
# NO2 Mean             float64
# NO2 1st Max Value    float64
# NO2 1st Max Hour     int64
# NO2 AQI              int64
# O3 Units             object
# O3 Mean              float64
# O3 1st Max Value     float64
# O3 1st Max Hour      int64
# O3 AQI               int64
# SO2 Units            object
# SO2 Mean             float64
# SO2 1st Max Value    float64
# SO2 1st Max Hour     int64
# SO2 AQI              float64
# CO Units             object
# CO Mean              float64
# CO 1st Max Value     float64
# CO 1st Max Hour      int64
# CO AQI               float64
# dtypes: float64(10), int64(9), object(9)
# memory usage: 373.1+ MB

# %%
df.isnull().any()
# Out:
# State Code           False
# County Code          False
# Site Num             False
# Address              False
# State                False
# County               False
# City                 False
# Date Local           False
# NO2 Units            False
# NO2 Mean             False
# NO2 1st Max Value    False
# NO2 1st Max Hour     False
# NO2 AQI              False
# O3 Units             False
# O3 Mean              False
# O3 1st Max Value     False
# O3 1st Max Hour      False
# O3 AQI               False
# SO2 Units            False
# SO2 Mean             False
# SO2 1st Max Value    False
# SO2 1st Max Hour     False
# SO2 AQI               True
# CO Units             False
# CO Mean              False
# CO 1st Max Value     False
# CO 1st Max Hour      False
# CO AQI                True
# dtype: bool

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 436876 entries, 1 to 1746658
# Data columns (total 28 columns):
# State Code           436876 non-null int64
# County Code          436876 non-null int64
# Site Num             436876 non-null int64
# Address              436876 non-null object
# State                436876 non-null object
# County               436876 non-null object
# City                 436876 non-null object
# Date Local           436876 non-null object
# NO2 Units            436876 non-null object
# NO2 Mean             436876 non-null float64
# NO2 1st Max Value    436876 non-null float64
# NO2 1st Max Hour     436876 non-null int64
# NO2 AQI              436876 non-null int64
# O3 Units             436876 non-null object
# O3 Mean              436876 non-null float64
# O3 1st Max Value     436876 non-null float64
# O3 1st Max Hour      436876 non-null int64
# O3 AQI               436876 non-null int64
# SO2 Units            436876 non-null object
# SO2 Mean             436876 non-null float64
# SO2 1st Max Value    436876 non-null float64
# SO2 1st Max Hour     436876 non-null int64
# SO2 AQI              436876 non-null float64
# CO Units             436876 non-null object
# CO Mean              436876 non-null float64
# CO 1st Max Value     436876 non-null float64
# CO 1st Max Hour      436876 non-null int64
# CO AQI               436876 non-null float64
# dtypes: float64(10), int64(9), object(9)
# memory usage: 96.7+ MB

# %%
436876*4
# Out:
# 1747504

# %%
df.head()
# Out:
#     State Code  County Code  Site Num  \
# 1            4           13      3002
# 5            4           13      3002
# 9            4           13      3002
# 13           4           13      3002
# 17           4           13      3002
#
#                                     Address    State    County     City  \
# 1   1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 5   1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 9   1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 13  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 17  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#     Date Local          NO2 Units   NO2 Mean   ...            SO2 Units  \
# 1   2000-01-01  Parts per billion  19.041667   ...    Parts per billion
# 5   2000-01-02  Parts per billion  22.958333   ...    Parts per billion
# 9   2000-01-03  Parts per billion  38.125000   ...    Parts per billion
# 13  2000-01-04  Parts per billion  40.260870   ...    Parts per billion
# 17  2000-01-05  Parts per billion  48.450000   ...    Parts per billion
#
#     SO2 Mean  SO2 1st Max Value SO2 1st Max Hour  SO2 AQI           CO Units  \
# 1   3.000000                9.0               21     13.0  Parts per million
# 5   1.958333                3.0               22      4.0  Parts per million
# 9   5.250000               11.0               19     16.0  Parts per million
# 13  7.083333               16.0                8     23.0  Parts per million
# 17  8.708333               15.0                7     21.0  Parts per million
#
#      CO Mean  CO 1st Max Value CO 1st Max Hour  CO AQI
# 1   0.878947               2.2              23    25.0
# 5   1.066667               2.3               0    26.0
# 9   1.762500               2.5               8    28.0
# 13  1.829167               3.0              23    34.0
# 17  2.700000               3.7               2    42.0
#
# [5 rows x 28 columns]

# %%
df.tail()
# Out:
#          State Code  County Code  Site Num  \
# 1746642          56           21       100
# 1746646          56           21       100
# 1746650          56           21       100
# 1746654          56           21       100
# 1746658          56           21       100
#
#                                        Address    State   County  \
# 1746642  NCore - North Cheyenne Soccer Complex  Wyoming  Laramie
# 1746646  NCore - North Cheyenne Soccer Complex  Wyoming  Laramie
# 1746650  NCore - North Cheyenne Soccer Complex  Wyoming  Laramie
# 1746654  NCore - North Cheyenne Soccer Complex  Wyoming  Laramie
# 1746658  NCore - North Cheyenne Soccer Complex  Wyoming  Laramie
#
#                   City  Date Local          NO2 Units  NO2 Mean   ...    \
# 1746642  Not in a city  2016-03-27  Parts per billion  4.277273   ...
# 1746646  Not in a city  2016-03-28  Parts per billion  8.317391   ...
# 1746650  Not in a city  2016-03-29  Parts per billion  2.564706   ...
# 1746654  Not in a city  2016-03-30  Parts per billion  1.083333   ...
# 1746658  Not in a city  2016-03-31  Parts per billion  0.939130   ...
#
#                  SO2 Units  SO2 Mean  SO2 1st Max Value SO2 1st Max Hour  \
# 1746642  Parts per billion -0.095238                0.0                0
# 1746646  Parts per billion  0.117391                0.5                7
# 1746650  Parts per billion  0.143750                0.7                8
# 1746654  Parts per billion  0.016667                0.1                0
# 1746658  Parts per billion -0.022727                0.0                0
#
#          SO2 AQI           CO Units   CO Mean  CO 1st Max Value  \
# 1746642      0.0  Parts per million  0.100000               0.1
# 1746646      0.0  Parts per million  0.100000               0.1
# 1746650      0.0  Parts per million  0.006667               0.1
# 1746654      0.0  Parts per million  0.091667               0.1
# 1746658      0.0  Parts per million  0.100000               0.1
#
#         CO 1st Max Hour  CO AQI
# 1746642               0     1.0
# 1746646               0     1.0
# 1746650               0     1.0
# 1746654               2     1.0
# 1746658               0     1.0
#
# [5 rows x 28 columns]

# %%
#只剩下1/4

# %%
df.to_csv('pollution_new.csv')

# %%
df = pd.read_csv('pollution_new.csv')
df.head()
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           1           4           13      3002
# 1           5           4           13      3002
# 2           9           4           13      3002
# 3          13           4           13      3002
# 4          17           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#    Date Local          NO2 Units  ...            SO2 Units  SO2 Mean  \
# 0  2000-01-01  Parts per billion  ...    Parts per billion  3.000000
# 1  2000-01-02  Parts per billion  ...    Parts per billion  1.958333
# 2  2000-01-03  Parts per billion  ...    Parts per billion  5.250000
# 3  2000-01-04  Parts per billion  ...    Parts per billion  7.083333
# 4  2000-01-05  Parts per billion  ...    Parts per billion  8.708333
#
#    SO2 1st Max Value  SO2 1st Max Hour SO2 AQI           CO Units   CO Mean  \
# 0                9.0                21    13.0  Parts per million  0.878947
# 1                3.0                22     4.0  Parts per million  1.066667
# 2               11.0                19    16.0  Parts per million  1.762500
# 3               16.0                 8    23.0  Parts per million  1.829167
# 4               15.0                 7    21.0  Parts per million  2.700000
#
#    CO 1st Max Value  CO 1st Max Hour CO AQI
# 0               2.2               23   25.0
# 1               2.3                0   26.0
# 2               2.5                8   28.0
# 3               3.0               23   34.0
# 4               3.7                2   42.0
#
# [5 rows x 29 columns]

# %%
del df['Unnamed: 0']

# %%
df.head()
# Out:
#    State Code  County Code  Site Num                                  Address  \
# 0           4           13      3002  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 1           4           13      3002  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 2           4           13      3002  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 3           4           13      3002  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
# 4           4           13      3002  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN
#
#      State    County     City  Date Local          NO2 Units   NO2 Mean  \
# 0  Arizona  Maricopa  Phoenix  2000-01-01  Parts per billion  19.041667
# 1  Arizona  Maricopa  Phoenix  2000-01-02  Parts per billion  22.958333
# 2  Arizona  Maricopa  Phoenix  2000-01-03  Parts per billion  38.125000
# 3  Arizona  Maricopa  Phoenix  2000-01-04  Parts per billion  40.260870
# 4  Arizona  Maricopa  Phoenix  2000-01-05  Parts per billion  48.450000
#
#     ...            SO2 Units  SO2 Mean  SO2 1st Max Value SO2 1st Max Hour  \
# 0   ...    Parts per billion  3.000000                9.0               21
# 1   ...    Parts per billion  1.958333                3.0               22
# 2   ...    Parts per billion  5.250000               11.0               19
# 3   ...    Parts per billion  7.083333               16.0                8
# 4   ...    Parts per billion  8.708333               15.0                7
#
#    SO2 AQI           CO Units   CO Mean  CO 1st Max Value CO 1st Max Hour  \
# 0     13.0  Parts per million  0.878947               2.2              23
# 1      4.0  Parts per million  1.066667               2.3               0
# 2     16.0  Parts per million  1.762500               2.5               8
# 3     23.0  Parts per million  1.829167               3.0              23
# 4     21.0  Parts per million  2.700000               3.7               2
#
#    CO AQI
# 0    25.0
# 1    26.0
# 2    28.0
# 3    34.0
# 4    42.0
#
# [5 rows x 28 columns]

# %%
df[df['County'] == 'Queens']
# Out:
#         State Code  County Code  Site Num  \
# 16079           36           81        97
# 16080           36           81        97
# 16081           36           81        97
# 16082           36           81        97
# 16083           36           81        97
# 16084           36           81        97
# 16085           36           81        97
# 16086           36           81        97
# 16087           36           81        97
# 16088           36           81        97
# 16089           36           81        97
# 16090           36           81        97
# 16091           36           81        97
# 16092           36           81        97
# 16093           36           81        97
# 16094           36           81        97
# 16095           36           81        97
# 16096           36           81        97
# 16097           36           81        97
# 16098           36           81        97
# 16099           36           81        97
# 16100           36           81        97
# 16101           36           81        97
# 16102           36           81        97
# 16103           36           81        97
# 16104           36           81        97
# 16105           36           81        97
# 16106           36           81        97
# 16107           36           81        97
# 16108           36           81        97
# ...            ...          ...       ...
# 434812          36           81       124
# 434813          36           81       124
# 434814          36           81       124
# 434815          36           81       124
# 434816          36           81       124
# 434817          36           81       124
# 434818          36           81       124
# 434819          36           81       124
# 434820          36           81       124
# 434821          36           81       124
# 434822          36           81       124
# 434823          36           81       124
# 434824          36           81       124
# 434825          36           81       124
# 434826          36           81       124
# 434827          36           81       124
# 434828          36           81       124
# 434829          36           81       124
# 434830          36           81       124
# 434831          36           81       124
# 434832          36           81       124
# 434833          36           81       124
# 434834          36           81       124
# 434835          36           81       124
# 434836          36           81       124
# 434837          36           81       124
# 434838          36           81       124
# 434839          36           81       124
# 434840          36           81       124
# 434841          36           81       124
#
#                                                   Address     State  County  \
# 16079                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16080                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16081                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16082                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16083                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16084                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16085                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16086                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16087                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16088                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16089                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16090                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16091                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16092                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16093                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16094                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16095                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16096                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16097                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16098                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16099                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16100                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16101                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16102                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16103                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16104                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16105                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16106                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16107                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# 16108                        56TH AVE AT SPRINGFIELD BLVD  New York  Queens
# ...                                                   ...       ...     ...
# 434812  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434813  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434814  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434815  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434816  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434817  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434818  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434819  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434820  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434821  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434822  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434823  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434824  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434825  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434826  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434827  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434828  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434829  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434830  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434831  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434832  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434833  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434834  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434835  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434836  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434837  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434838  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434839  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434840  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434841  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
#
#             City  Date Local          NO2 Units   NO2 Mean   ...    \
# 16079   New York  2000-01-01  Parts per billion  28.041667   ...
# 16080   New York  2000-01-02  Parts per billion  35.375000   ...
# 16081   New York  2000-01-03  Parts per billion  32.875000   ...
# 16082   New York  2000-01-04  Parts per billion  22.125000   ...
# 16083   New York  2000-01-05  Parts per billion  15.958333   ...
# 16084   New York  2000-01-06  Parts per billion  31.125000   ...
# 16085   New York  2000-01-07  Parts per billion  34.458333   ...
# 16086   New York  2000-01-08  Parts per billion  25.500000   ...
# 16087   New York  2000-01-09  Parts per billion  33.375000   ...
# 16088   New York  2000-01-10  Parts per billion  28.250000   ...
# 16089   New York  2000-01-11  Parts per billion  28.333333   ...
# 16090   New York  2000-01-12  Parts per billion  23.909091   ...
# 16091   New York  2000-01-13  Parts per billion  22.208333   ...
# 16092   New York  2000-01-14  Parts per billion  13.958333   ...
# 16093   New York  2000-01-15  Parts per billion  30.250000   ...
# 16094   New York  2000-01-16  Parts per billion  18.333333   ...
# 16095   New York  2000-01-17  Parts per billion  13.333333   ...
# 16096   New York  2000-01-18  Parts per billion  24.458333   ...
# 16097   New York  2000-01-19  Parts per billion  33.666667   ...
# 16098   New York  2000-01-20  Parts per billion  33.583333   ...
# 16099   New York  2000-01-21  Parts per billion  16.208333   ...
# 16100   New York  2000-01-22  Parts per billion  20.458333   ...
# 16101   New York  2000-01-23  Parts per billion  32.263158   ...
# 16102   New York  2000-01-24  Parts per billion  34.125000   ...
# 16103   New York  2000-01-25  Parts per billion  11.708333   ...
# 16104   New York  2000-01-26  Parts per billion  19.708333   ...
# 16105   New York  2000-01-27  Parts per billion  16.000000   ...
# 16106   New York  2000-01-28  Parts per billion  19.583333   ...
# 16107   New York  2000-01-29  Parts per billion  32.666667   ...
# 16108   New York  2000-01-30  Parts per billion  49.523810   ...
# ...          ...         ...                ...        ...   ...
# 434812  New York  2016-03-29  Parts per billion   6.520833   ...
# 434813  New York  2016-03-30  Parts per billion  16.870833   ...
# 434814  New York  2016-03-31  Parts per billion  11.129167   ...
# 434815  New York  2016-04-01  Parts per billion  17.768421   ...
# 434816  New York  2016-04-02  Parts per billion   9.475000   ...
# 434817  New York  2016-04-06  Parts per billion  14.614286   ...
# 434818  New York  2016-04-07  Parts per billion  12.741176   ...
# 434819  New York  2016-04-08  Parts per billion  11.895833   ...
# 434820  New York  2016-04-09  Parts per billion  16.962500   ...
# 434821  New York  2016-04-10  Parts per billion   7.937500   ...
# 434822  New York  2016-04-11  Parts per billion  10.337500   ...
# 434823  New York  2016-04-12  Parts per billion  13.916667   ...
# 434824  New York  2016-04-13  Parts per billion  17.200000   ...
# 434825  New York  2016-04-14  Parts per billion  22.781250   ...
# 434826  New York  2016-04-15  Parts per billion  18.416667   ...
# 434827  New York  2016-04-16  Parts per billion  12.795833   ...
# 434828  New York  2016-04-17  Parts per billion  20.941667   ...
# 434829  New York  2016-04-18  Parts per billion  23.241667   ...
# 434830  New York  2016-04-19  Parts per billion  16.329167   ...
# 434831  New York  2016-04-20  Parts per billion  11.904167   ...
# 434832  New York  2016-04-21  Parts per billion  17.275000   ...
# 434833  New York  2016-04-22  Parts per billion  29.800000   ...
# 434834  New York  2016-04-23  Parts per billion   7.620833   ...
# 434835  New York  2016-04-24  Parts per billion   7.954167   ...
# 434836  New York  2016-04-25  Parts per billion  15.637500   ...
# 434837  New York  2016-04-26  Parts per billion  11.462500   ...
# 434838  New York  2016-04-27  Parts per billion  13.480000   ...
# 434839  New York  2016-04-28  Parts per billion  11.989474   ...
# 434840  New York  2016-04-29  Parts per billion   9.041667   ...
# 434841  New York  2016-04-30  Parts per billion   8.204167   ...
#
#                 SO2 Units   SO2 Mean  SO2 1st Max Value SO2 1st Max Hour  \
# 16079   Parts per billion  16.541667               26.0               21
# 16080   Parts per billion  13.791667               29.0                2
# 16081   Parts per billion   9.958333               19.0                6
# 16082   Parts per billion   3.541667               12.0               22
# 16083   Parts per billion   3.291667                5.0               19
# 16084   Parts per billion   6.666667               14.0                7
# 16085   Parts per billion  13.416667               27.0                7
# 16086   Parts per billion   9.875000               22.0               23
# 16087   Parts per billion  14.541667               22.0                9
# 16088   Parts per billion   6.458333               13.0                1
# 16089   Parts per billion   6.125000               10.0                5
# 16090   Parts per billion   5.800000               10.0               19
# 16091   Parts per billion   4.958333                9.0                0
# 16092   Parts per billion   3.208333                6.0               22
# 16093   Parts per billion  10.166667               17.0               14
# 16094   Parts per billion   6.500000               17.0               14
# 16095   Parts per billion   3.666667                8.0               16
# 16096   Parts per billion  15.583333               36.0               21
# 16097   Parts per billion  22.541667               44.0                8
# 16098   Parts per billion  16.916667               37.0                4
# 16099   Parts per billion   8.916667               14.0                0
# 16100   Parts per billion   8.416667               17.0               19
# 16101   Parts per billion  17.222222               42.0                7
# 16102   Parts per billion  19.291667               29.0               13
# 16103   Parts per billion   5.291667               10.0                0
# 16104   Parts per billion   5.875000                9.0                1
# 16105   Parts per billion   4.833333                7.0                7
# 16106   Parts per billion   5.666667                8.0               14
# 16107   Parts per billion  13.250000               28.0               19
# 16108   Parts per billion  30.380952               77.0                9
# ...                   ...        ...                ...              ...
# 434812  Parts per billion   0.591667                1.8               13
# 434813  Parts per billion   0.629167                2.2                7
# 434814  Parts per billion   0.266667                0.9                1
# 434815  Parts per billion   0.304545                0.8               15
# 434816  Parts per billion   0.208333                0.5                8
# 434817  Parts per billion   0.620833                1.3                8
# 434818  Parts per billion   0.291667                1.1               20
# 434819  Parts per billion   0.562500                1.4                7
# 434820  Parts per billion   0.562500                2.0               20
# 434821  Parts per billion   0.445833                0.7                9
# 434822  Parts per billion   0.287500                0.6                0
# 434823  Parts per billion   0.391667                1.3               12
# 434824  Parts per billion   0.710000                1.8                5
# 434825  Parts per billion   0.471429                0.8               22
# 434826  Parts per billion   0.437500                1.6               18
# 434827  Parts per billion   0.291667                0.8                1
# 434828  Parts per billion   0.695833                1.7               19
# 434829  Parts per billion   0.662500                2.5                6
# 434830  Parts per billion   0.727273                2.6                3
# 434831  Parts per billion   0.304167                0.9                5
# 434832  Parts per billion   0.562500                2.5                6
# 434833  Parts per billion   0.837500                1.7                6
# 434834  Parts per billion   0.025000                0.3                0
# 434835  Parts per billion   0.325000                0.9               20
# 434836  Parts per billion   0.291667                0.7               12
# 434837  Parts per billion   0.012500                0.1                2
# 434838  Parts per billion   0.157143                0.4               16
# 434839  Parts per billion   0.287500                0.7               19
# 434840  Parts per billion   0.170833                0.5                5
# 434841  Parts per billion   0.245833                0.9               20
#
#         SO2 AQI           CO Units   CO Mean  CO 1st Max Value  \
# 16079      37.0  Parts per million  0.652632               1.1
# 16080      41.0  Parts per million  0.833333               1.6
# 16081      27.0  Parts per million  0.383333               0.7
# 16082      17.0  Parts per million  0.150000               0.5
# 16083       7.0  Parts per million  0.050000               0.2
# 16084      20.0  Parts per million  0.170833               0.4
# 16085      39.0  Parts per million  0.475000               0.9
# 16086      31.0  Parts per million  0.222222               0.6
# 16087      31.0  Parts per million  0.516667               0.7
# 16088      19.0  Parts per million  0.358333               0.7
# 16089      14.0  Parts per million  0.237500               0.3
# 16090      14.0  Parts per million  0.347059               0.7
# 16091      13.0  Parts per million  0.554167               0.7
# 16092       9.0  Parts per million  0.362500               0.4
# 16093      24.0  Parts per million  0.508333               0.9
# 16094      24.0  Parts per million  0.520833               0.8
# 16095      11.0  Parts per million  0.325000               0.5
# 16096      51.0  Parts per million  0.329167               0.5
# 16097      61.0  Parts per million  0.558333               0.8
# 16098      52.0  Parts per million  0.779167               1.0
# 16099      20.0  Parts per million  0.508333               0.6
# 16100      24.0  Parts per million  0.304167               0.4
# 16101      59.0  Parts per million  0.644444               0.8
# 16102      41.0  Parts per million  0.791667               1.4
# 16103      14.0  Parts per million  0.650000               1.3
# 16104      13.0  Parts per million  0.616667               0.7
# 16105      10.0  Parts per million  0.533333               0.6
# 16106      11.0  Parts per million  0.437500               0.5
# 16107      40.0  Parts per million  0.591667               0.8
# 16108     101.0  Parts per million  0.827273               0.9
# ...         ...                ...       ...               ...
# 434812      1.0  Parts per million  0.200000               0.2
# 434813      3.0  Parts per million  0.241667               0.3
# 434814      0.0  Parts per million  0.200000               0.2
# 434815      0.0  Parts per million  0.229167               0.3
# 434816      0.0  Parts per million  0.225000               0.3
# 434817      1.0  Parts per million  0.200000               0.2
# 434818      1.0  Parts per million  0.200000               0.2
# 434819      1.0  Parts per million  0.200000               0.2
# 434820      3.0  Parts per million  0.237500               0.3
# 434821      0.0  Parts per million  0.200000               0.2
# 434822      0.0  Parts per million  0.200000               0.2
# 434823      1.0  Parts per million  0.204167               0.3
# 434824      1.0  Parts per million  0.216667               0.3
# 434825      0.0  Parts per million  0.245833               0.3
# 434826      1.0  Parts per million  0.241667               0.3
# 434827      0.0  Parts per million  0.216667               0.3
# 434828      1.0  Parts per million  0.279167               0.4
# 434829      3.0  Parts per million  0.300000               0.4
# 434830      3.0  Parts per million  0.272222               0.3
# 434831      0.0  Parts per million  0.200000               0.2
# 434832      3.0  Parts per million  0.208333               0.3
# 434833      1.0  Parts per million  0.337500               0.4
# 434834      0.0  Parts per million  0.212500               0.3
# 434835      0.0  Parts per million  0.187500               0.2
# 434836      0.0  Parts per million  0.220833               0.3
# 434837      0.0  Parts per million  0.200000               0.2
# 434838      0.0  Parts per million  0.208333               0.3
# 434839      0.0  Parts per million  0.229167               0.3
# 434840      0.0  Parts per million  0.187500               0.2
# 434841      0.0  Parts per million  0.195833               0.2
#
#        CO 1st Max Hour  CO AQI
# 16079               23    13.0
# 16080                2    18.0
# 16081               19     8.0
# 16082                0     6.0
# 16083                0     2.0
# 16084               23     5.0
# 16085                9    10.0
# 16086               21     7.0
# 16087               22     8.0
# 16088                0     8.0
# 16089                8     3.0
# 16090               22     8.0
# 16091                0     8.0
# 16092                0     5.0
# 16093               20    10.0
# 16094                0     9.0
# 16095                0     6.0
# 16096               18     6.0
# 16097               23     9.0
# 16098                3    11.0
# 16099                0     7.0
# 16100                0     5.0
# 16101                9     9.0
# 16102               20    16.0
# 16103                0    15.0
# 16104               12     8.0
# 16105                0     7.0
# 16106                0     6.0
# 16107               20     9.0
# 16108                8    10.0
# ...                ...     ...
# 434812               0     2.0
# 434813               5     3.0
# 434814               0     2.0
# 434815               9     3.0
# 434816               0     3.0
# 434817               0     2.0
# 434818               0     2.0
# 434819               0     2.0
# 434820               3     3.0
# 434821               0     2.0
# 434822               0     2.0
# 434823              12     3.0
# 434824              21     3.0
# 434825               0     3.0
# 434826               2     3.0
# 434827               6     3.0
# 434828               6     5.0
# 434829               6     5.0
# 434830               0     3.0
# 434831               0     2.0
# 434832              22     3.0
# 434833               2     5.0
# 434834               0     3.0
# 434835               0     2.0
# 434836               9     3.0
# 434837               0     2.0
# 434838              22     3.0
# 434839               0     3.0
# 434840               0     2.0
# 434841               0     2.0
#
# [6047 rows x 28 columns]

# %%
# %pylab inline

from datetime import datetime
df['Date Local'] = pd.to_datetime(df['Date Local'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
type(df['Date Local'])
# Out:
# pandas.core.series.Series

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 436876 entries, 0 to 436875
# Data columns (total 28 columns):
# State Code           436876 non-null int64
# County Code          436876 non-null int64
# Site Num             436876 non-null int64
# Address              436876 non-null object
# State                436876 non-null object
# County               436876 non-null object
# City                 436876 non-null object
# Date Local           436876 non-null datetime64[ns]
# NO2 Units            436876 non-null object
# NO2 Mean             436876 non-null float64
# NO2 1st Max Value    436876 non-null float64
# NO2 1st Max Hour     436876 non-null int64
# NO2 AQI              436876 non-null int64
# O3 Units             436876 non-null object
# O3 Mean              436876 non-null float64
# O3 1st Max Value     436876 non-null float64
# O3 1st Max Hour      436876 non-null int64
# O3 AQI               436876 non-null int64
# SO2 Units            436876 non-null object
# SO2 Mean             436876 non-null float64
# SO2 1st Max Value    436876 non-null float64
# SO2 1st Max Hour     436876 non-null int64
# SO2 AQI              436876 non-null float64
# CO Units             436876 non-null object
# CO Mean              436876 non-null float64
# CO 1st Max Value     436876 non-null float64
# CO 1st Max Hour      436876 non-null int64
# CO AQI               436876 non-null float64
# dtypes: datetime64[ns](1), float64(10), int64(9), object(8)
# memory usage: 93.3+ MB

# %%
df_Queens = df[df['County'] == 'Queens']

# %%
df_Queens_2000 = df_Queens[df_Queens['Date Local'].dt.year == 2000]

# %%
df_Queens_2000['NO2 Mean'].groupby(df_Queens_2000['Date Local'].dt.month).mean()
# Out:
# Date Local
# 1     26.125948
# 2     31.132626
# 3     27.974982
# 4     22.449245
# 5     25.126116
# 6     24.926126
# 7     22.789881
# 8     23.449218
# 9     23.094957
# 10    29.664284
# 11    24.721150
# 12    27.156692
# Name: NO2 Mean, dtype: float64

# %%
(df_Queens_2000['NO2 Mean'].groupby(df_Queens_2000['Date Local'].dt.month).mean()).plot(kind='line', figsize=[10,5], legend=True, title='NO2 Mean of Queens in 2000 ', grid=True)

# %%
(df_Queens_2000['O3 Mean'].groupby(df_Queens_2000['Date Local'].dt.month).mean()).plot(kind='line', figsize=[10,5], legend=True, title='O3 Mean of Queens in 2000 ', grid=True)

# %%
(df_Queens_2000['SO2 Mean'].groupby(df_Queens_2000['Date Local'].dt.month).mean()).plot(kind='line', figsize=[10,5], legend=True, title='SO2 Mean of Queens in 2000 ', grid=True)

# %%
(df_Queens_2000['CO Mean'].groupby(df_Queens_2000['Date Local'].dt.month).mean()).plot(kind='line', figsize=[10,5], legend=True, title='CO Mean of Queens in 2000 ', grid=True)

# %%
(df_Queens['NO2 Mean'].groupby(df_Queens['Date Local'].dt.year).mean()).plot(kind='line', figsize=[10,5], legend=True, title='NO2 Mean of Queens in 2000-2016 ', grid=True)

# %%
(df_Queens['O3 Mean'].groupby(df_Queens['Date Local'].dt.year).mean()).plot(kind='line', figsize=[10,5], legend=True, title='O3 Mean of Queens in 2000-2016 ', grid=True)

# %%
(df_Queens['SO2 Mean'].groupby(df_Queens['Date Local'].dt.year).mean()).plot(kind='line', figsize=[10,5], legend=True, title='SO2 Mean of Queens in 2000-2016 ', grid=True)

# %%
(df_Queens['CO Mean'].groupby(df_Queens['Date Local'].dt.year).mean()).plot(kind='line', figsize=[10,5], legend=True, title='CO Mean of Queens in 2000-2016 ', grid=True)

# %% [markdown]
# 取整即得AQI=158。各种污染物的AQI值分别算出来后，取数值最大的那个即为最终报告的AQI值。比如SO2浓度为20.5μg/m3，算出来对应的AQI为29；PM10浓度为150.8μg/m3，对应的AQI为98；PM2.5浓度为130.7μg/m3，对应的AQI为190。最终报告的AQI值就是190，而贡献了那个最大值的PM2.5则称为首要污染物。

# %%
df_Queens['AQI'] = df_Queens[['NO2 AQI','O3 AQI','SO2 AQI','CO AQI']].apply(lambda x:max(x),axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Queens['AQI'].head()
# Out:
# 16079    37.0
# 16080    42.0
# 16081    39.0
# 16082    39.0
# 16083    22.0
# Name: AQI, dtype: float64

# %%
df_Queens.tail()
# Out:
#         State Code  County Code  Site Num  \
# 434837          36           81       124
# 434838          36           81       124
# 434839          36           81       124
# 434840          36           81       124
# 434841          36           81       124
#
#                                                   Address     State  County  \
# 434837  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434838  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434839  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434840  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
# 434841  Queens College   65-30 Kissena Blvd  Parking L...  New York  Queens
#
#             City Date Local          NO2 Units   NO2 Mean  ...   SO2 Mean  \
# 434837  New York 2016-04-26  Parts per billion  11.462500  ...   0.012500
# 434838  New York 2016-04-27  Parts per billion  13.480000  ...   0.157143
# 434839  New York 2016-04-28  Parts per billion  11.989474  ...   0.287500
# 434840  New York 2016-04-29  Parts per billion   9.041667  ...   0.170833
# 434841  New York 2016-04-30  Parts per billion   8.204167  ...   0.245833
#
#         SO2 1st Max Value  SO2 1st Max Hour SO2 AQI           CO Units  \
# 434837                0.1                 2     0.0  Parts per million
# 434838                0.4                16     0.0  Parts per million
# 434839                0.7                19     0.0  Parts per million
# 434840                0.5                 5     0.0  Parts per million
# 434841                0.9                20     0.0  Parts per million
#
#          CO Mean  CO 1st Max Value  CO 1st Max Hour CO AQI   AQI
# 434837  0.200000               0.2                0    2.0  31.0
# 434838  0.208333               0.3               22    3.0  28.0
# 434839  0.229167               0.3                0    3.0  40.0
# 434840  0.187500               0.2                0    2.0  42.0
# 434841  0.195833               0.2                0    2.0  43.0
#
# [5 rows x 29 columns]

# %%
df_Queens['AQI'].describe()
# Out:
# count    6047.000000
# mean       41.809162
# std        17.105014
# min        12.000000
# 25%        31.000000
# 50%        39.000000
# 75%        47.000000
# max       201.000000
# Name: AQI, dtype: float64

# %%
def AQI_level(e):
    if e<=50:
        return 'Good'
    elif e>50 and e<=100:
        return 'Moderate'
    elif e>100 and e<=150:
        return 'Unhealthy for Sensitive Groups'
    elif e>150 and e<=200:
        return 'Unhealthy'
    elif e>200 and e<=300:
        return 'Very Unhealthy'
    else:
        return 'Hazardous'

AQI_level(144)
# Out:
# 'Unhealthy for Sensitive Groups'

# %%
df_Queens['AQI_level'] = df_Queens['AQI'].map(AQI_level)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_Queens['AQI_level'].head()
# Out:
# 16079    Good
# 16080    Good
# 16081    Good
# 16082    Good
# 16083    Good
# Name: AQI_level, dtype: object

# %%
df_Queens['AQI_level'].value_counts()
# Out:
# Good                              4948
# Moderate                           998
# Unhealthy for Sensitive Groups      91
# Unhealthy                            9
# Very Unhealthy                       1
# Name: AQI_level, dtype: int64

# %%
df_Queens['AQI'].plot(kind='hist', figsize=[5,5], legend=False, title='AQI 2000-2016')

# %%
df_Queens['AQI_level'].value_counts().plot(kind='pie', figsize=[5,5], counterclock=True, startangle = 0, legend=False, title='AQI 2000-2016')
