# %% [markdown]
# # ARIMA模型

# %% [markdown]
# ## 平稳性

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# 构造时间时间序列
df_obj = pd.DataFrame(np.random.randn(1000, 1), 
                       index=pd.date_range('20170101', periods=1000),
                       columns=['data'])
df_obj['data'] = df_obj['data'].cumsum()
print(df_obj.head())
# Out:
#                 data
# 2017-01-01 -0.206464
# 2017-01-02 -1.059900
# 2017-01-03  0.151553
# 2017-01-04 -0.222269
# 2017-01-05 -1.455043

# %%
# 一阶差分处理
df_obj['diff_1'] = df_obj['data'].diff(1)

# 二阶差分处理
df_obj['diff_2'] = df_obj['diff_1'].diff(1)

# 查看图像
df_obj.plot(subplots=True, figsize=(18, 12))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000000000BCCAFD0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BD14CF8>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000000000BD60F28>], dtype=object)

# %% [markdown]
# ## ACF 和 PACF

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy import  stats
import statsmodels.api as sm
from pandas import TimeSeries

sm.graphics.tsa.plot_acf(df_obj['data'], lags=20)
sm.graphics.tsa.plot_pacf(df_obj['data'], lags=20)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-5dc79df23520> in <module>()
#       5
#       6 from scipy import  stats
# ----> 7 import statsmodels.api as sm
#       8 from pandas import TimeSeries
#       9
#
# C:\Anaconda3\lib\site-packages\statsmodels\api.py in <module>()
#       3 from . import tools
#       4 from .tools.tools import add_constant, categorical
# ----> 5 from . import regression
#       6 from .regression.linear_model import OLS, GLS, WLS, GLSAR
#       7 from .regression.quantile_regression import QuantReg
#
# C:\Anaconda3\lib\site-packages\statsmodels\regression\__init__.py in <module>()
# ----> 1 from .linear_model import yule_walker
#       2
#       3 from statsmodels import NoseWrapper as Tester
#       4 test = Tester().test
#
# C:\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py in <module>()
#      50                                           cache_readonly,
#      51                                           cache_writable)
# ---> 52 import statsmodels.base.model as base
#      53 import statsmodels.base.wrapper as wrap
#      54 from statsmodels.emplike.elregress import _ELRegOpts
#
# C:\Anaconda3\lib\site-packages\statsmodels\base\model.py in <module>()
#       3 import numpy as np
#       4 from scipy import stats
# ----> 5 from statsmodels.base.data import handle_data
#       6 from statsmodels.tools.tools import recipr, nan_dot
#       7 from statsmodels.stats.contrast import ContrastResults
#
# C:\Anaconda3\lib\site-packages\statsmodels\base\data.py in <module>()
#       6 from statsmodels.compat.numpy import np_matrix_rank
#       7 import numpy as np
# ----> 8 from pandas import DataFrame, Series, TimeSeries, isnull
#       9 from statsmodels.tools.decorators import (resettable_cache, cache_readonly,
#      10                                           cache_writable)
#
# ImportError: cannot import name 'TimeSeries'

# %%
import sklearn

# %%
from sklearn import TimeSeries

# %%
from pandas import DataFrame, Series, TimeSeries, isnull
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-468eae11df32> in <module>()
# ----> 1 from pandas import DataFrame, Series, TimeSeries, isnull
#
# ImportError: cannot import name 'TimeSeries'

# %%
from pandas import DataFrame, Series, TimeSeries
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-8a4d103b850e> in <module>()
# ----> 1 from pandas import DataFrame, Series, TimeSeries
#
# ImportError: cannot import name 'TimeSeries'

# %%
from pandas import  TimeSeries
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-d6ba45e7514d> in <module>()
# ----> 1 from pandas import  TimeSeries
#
# ImportError: cannot import name 'TimeSeries'

# %%
from pandas import TimeSeries
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-35-3b7fb03d82a3> in <module>()
# ----> 1 from pandas import TimeSeries
#
# ImportError: cannot import name 'TimeSeries'

# %%
dir(pandas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-d405090e5c86> in <module>()
# ----> 1 dir(pandas)
#
# NameError: name 'pandas' is not defined
