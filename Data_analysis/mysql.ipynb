# %%
#检测是否安装好环境
import MySQLdb

# %%
#使用python连接数据库
conn = MySQLdb.connect(
    host = '127.0.0.1',#本地地址
    user = 'root',#一般默认用户名
    passwd = 'wangdawei',#本地数据库登录密码
    db = 'test',#数据库名称
    port = 3306,#安装mysql默认的端口号
    charset = 'utf8'#设置数据库统一编码
)

# %%
#获取数据
cursor = conn.cursor()
cursor.execute('SELECT * FROM `tdb_goods`;')
data = cursor.fetchone()#取一条数据
print(data)
# Out:
# (1, 'R510VC 15.6英寸笔记本', 5, 2, Decimal('3399.000'), 1, 0)

# %%
#关闭连接

conn.close()

# %%
#使用python连接数据库
#异常处理
try:
    conn = MySQLdb.connect(
        host = '127.0.0.2222',
        user = 'root',
        passwd = 'wangdawei',
        db = 'test',
        port = 3306,
        charset = 'utf8'
    )
except MySQLdb.Error as e:
    print('Error:%s' % e)
# Out:
# Error:(2005, "Unknown MySQL server host '127.0.0.2222' (0)")

# %%
#也可以全部放进来

#检测是否安装好环境
import MySQLdb

#使用python连接数据库
#异常处理
try:
    conn = MySQLdb.connect(
        host = '127.0.0.1',
        user = 'root',
        passwd = 'wangdawei',
        db = 'test',
        port = 3306,
        charset = 'utf8'
    )
    
    #获取数据
    cursor = conn.cursor()
    cursor.execute('SELECT * FROM `tdb_goods`;')
    data = cursor.fetchall()#取一条数据
    print(data)
    
    #关闭连接

    conn.close()
except MySQLdb.Error as e:
    print('Error:%s' % e)
# Out:
# ((1, 'R510VC 15.6英寸笔记本', 5, 2, Decimal('3399.000'), 1, 0), (2, 'Y400N 14.0英寸笔记本电脑', 5, 7, Decimal('4899.000'), 1, 0), (3, 'G150TH 15.6英寸游戏本', 4, 9, Decimal('8499.000'), 1, 0), (4, 'X550CC 15.6英寸笔记本', 5, 2, Decimal('2799.000'), 1, 0), (5, 'X240(20ALA0EYCD) 12.5英寸超极本', 7, 7, Decimal('4999.000'), 1, 0), (6, 'U330P 13.3英寸超极本', 7, 7, Decimal('4299.000'), 1, 0), (7, 'SVP13226SCB 13.3英寸触控超极本', 7, 6, Decimal('7999.000'), 1, 0), (8, 'iPad mini MD531CH/A 7.9英寸平板电脑', 2, 8, Decimal('1998.000'), 1, 0), (9, 'iPad Air MD788CH/A 9.7英寸平板电脑 （16G WiFi版）', 2, 8, Decimal('3388.000'), 1, 0), (10, ' iPad mini ME279CH/A 配备 Retina 显示屏 7.9英寸平板电脑 （16G WiFi版）', 2, 8, Decimal('2788.000'), 1, 0), (11, 'IdeaCentre C340 20英寸一体电脑 ', 1, 7, Decimal('3499.000'), 1, 0), (12, 'Vostro 3800-R1206 台式电脑', 1, 5, Decimal('2899.000'), 1, 0), (13, 'iMac ME086CH/A 21.5英寸一体电脑', 1, 8, Decimal('9188.000'), 1, 0), (14, 'AT7-7414LP 台式电脑 （i5-3450四核 4G 500G 2G独显 DVD 键鼠 Linux ）', 1, 3, Decimal('3699.000'), 1, 0), (15, 'Z220SFF F4F06PA工作站
# ...

# %%
#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class Mysql(object):
    
    def __init__(self):
        self.connect()#初始化时候调用
    
    def connect(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_a(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('1',))
        #拿到结果
        data = cursor.fetchone()
        #处理数据
        print(data)
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        
def main():
    object = Mysql()#创建对象
    object.get_a()
    
if __name__ == '__main__':
    main()
# Out:
# (11, 'IdeaCentre C340 20英寸一体电脑 ', 1, 7, Decimal('3499.000'), 1, 0)

# %%
#深入

# %%
class Mysql(object):
    
    def __init__(self):
        self.connect()
    
    def connect(self):

        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_a(self):
   
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        cursor = self.conn.cursor()
        cursor.execute(sql,('1',))
        data = cursor.fetchone()
        print(data)
        cursor.close()
        self.close_conn()
    
    def add_a(self):
        sql = "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value (%s,%s,%s,%s,%s,%s);"
        cursor = self.conn.cursor()
        cursor.execute(sql,('伟哥牌notebook','8','1','66666','1','0'))
        cursor.close()
        self.close_conn()
        
def main():
    object = Mysql()
    object.add_a()
    
if __name__ == '__main__':
    main()

# %%
#ceshi
import MySQLdb

class Mysql(object):
    
    def __init__(self):
        self.connect()
    
    def connect(self):

        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_a(self):
   
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        cursor = self.conn.cursor()
        cursor.execute(sql,('1',))
        data = cursor.fetchone()
        print(data)
        cursor.close()
        self.close_conn()
    
    def add_a(self):
        #准备SQL
        sql = "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value (%s,%s,%s,%s,%s,%s);" 
        #sql = ( #拼接成一个语句
        #    "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
        #    "('伟哥牌notebook','8','1','66666','1','0');"
        #)
        #获取连接和cursor
        cursor = self.conn.cursor()
        #执行sql
        cursor.execute(sql,('伟哥牌notebook','8','1','66666','1','0'))
        #cursor.execute(sql)
        #提交数据到数据库
        self.conn.commit()
        #提交事务
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        
def main():
    object = Mysql()
    object.add_a()
    
if __name__ == '__main__':
    main()

# %%
#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        print(cursor.rowcount)#获取行数，结果显示3行
        print('--------------------------')
        print(dir(cursor))#查看cursor的所有方法
        print('--------------------------')
        print(cursor.description)
        print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        print(rest)
        print('-----------------------------------')
        print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        
def main():
    obj = MysqlSearch()#创建对象
    obj.get_one()
    
if __name__ == '__main__':
    main()
# Out:
# 3
# --------------------------
# ...

# %%
#加入return
#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
        
def main():
    obj = MysqlSearch()#创建对象
    rest = obj.get_one()
    print(rest['goods_name'])
    
if __name__ == '__main__':
    main()
# Out:
# R510VC 15.6英寸笔记本

# %%
#获取多条数据

#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
    
    def get_more(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = [dict(zip([k[0] for k in cursor.description],row)) 
                for row in cursor.fetchall()]
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
        
def main():
    obj = MysqlSearch()#创建对象
    #rest = obj.get_one()
    #print(rest['goods_name'])
    rest = obj.get_more()
    for item in rest:
        print(item)
        print('-----------')
        

    
if __name__ == '__main__':
    main()
# Out:
# {'goods_id': 1, 'goods_name': 'R510VC 15.6英寸笔记本', 'cate_id': 5, 'brand_id': 2, 'goods_price': Decimal('3399.000'), 'is_show': 1, 'is_saleoff': 0}
# -----------
# {'goods_id': 2, 'goods_name': 'Y400N 14.0英寸笔记本电脑', 'cate_id': 5, 'brand_id': 7, 'goods_price': Decimal('4899.000'), 'is_show': 1, 'is_saleoff': 0}
# -----------
# {'goods_id': 4, 'goods_name': 'X550CC 15.6英寸笔记本', 'cate_id': 5, 'brand_id': 2, 'goods_price': Decimal('2799.000'), 'is_show': 1, 'is_saleoff': 0}
# -----------

# %%
#测试、

# %%
#获取多条数据,加翻页功能，没补完整

#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
    
    def get_more(self,page,page_size):
        #目的：获取一条数据
        #准备SQL
        offset = (page - 1)*page_size
        sql = 'select * from `tdb_goods` where `cate_id` = %s limit %s %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = [dict(zip([k[0] for k in cursor.description],row)) 
                for row in cursor.fetchall()]
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
        
def main():
    obj = MysqlSearch()#创建对象
    #rest = obj.get_one()
    #print(rest['goods_name'])
    rest = obj.get_more()
    for item in rest:
        print(item)
        print('-----------')
        

    
if __name__ == '__main__':
    main()

# %%
#获取多条数据

#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
    
    def get_more(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = [dict(zip([k[0] for k in cursor.description],row)) 
                for row in cursor.fetchall()]
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest

    def add_one(self):
        #准备SQL
        #sql = ( #拼接成一个语句
        #    "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
        #    "(%s,%s,%s,%s,%s,%s);"
        #） 
        sql = ( #拼接成一个语句
            "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
            "('伟哥牌notebook','8','1','66666','1','0');"
        )
        #获取连接和cursor
        cursor = self.conn.cursor()
        #执行sql
        #cursor.execute(sql,('伟哥牌notebook','8','1','66666','1','0'))
        cursor.execute(sql)
        #提交数据到数据库
        self.conn.commit()
        #提交事务
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        
def main():
    obj = MysqlSearch()#创建对象
    #rest = obj.get_one()
    #print(rest['goods_name'])
    #rest = obj.get_more()
    #for item in rest:
    #    print(item)
    #    print('-----------')
    obj.add_one()   

    
if __name__ == '__main__':
    main()

# %%
#插入一条数据 并且用到 %s 

#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
    
    def get_more(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = [dict(zip([k[0] for k in cursor.description],row)) 
                for row in cursor.fetchall()]
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest

    def add_one(self):
        #准备SQL
        sql = ( #拼接成一个语句
            "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
            "(%s,%s,%s,%s,%s,%s);"
        ) 
        #sql = ( #拼接成一个语句
        #    "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
        #    "('伟哥牌notebook','8','1','66666','1','0');"
        #)
        #获取连接和cursor
        cursor = self.conn.cursor()
        #执行sql
        cursor.execute(sql,('伟哥牌notebook','8','1','66666','1','0'))
        #cursor.execute(sql)
        #提交数据到数据库
        self.conn.commit()
        #提交事务
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        
def main():
    obj = MysqlSearch()#创建对象
    #rest = obj.get_one()
    #print(rest['goods_name'])
    #rest = obj.get_more()
    #for item in rest:
    #    print(item)
    #    print('-----------')
    obj.add_one()   

    
if __name__ == '__main__':
    main()

# %%
#插入一条数据 并且用到 %s 

#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
    
    def get_more(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = [dict(zip([k[0] for k in cursor.description],row)) 
                for row in cursor.fetchall()]
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest

    def add_one(self):
        #准备SQL
        sql = ( #拼接成一个语句
            "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
            "(%s,%s,%s,%s,%s,%s);"
        ) 
        #sql = ( #拼接成一个语句
        #    "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
        #    "('伟哥牌notebook','8','1','66666','1','0');"
        #)
        #获取连接和cursor
        cursor = self.conn.cursor()
        #执行sql
        cursor.execute(sql,('伟哥牌notebook','8','1','66666','1','0'))
        #cursor.execute(sql)
        #提交数据到数据库
        self.conn.commit()
        #提交事务
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        
def main():
    obj = MysqlSearch()#创建对象
    #rest = obj.get_one()
    #print(rest['goods_name'])
    #rest = obj.get_more()
    #for item in rest:
    #    print(item)
    #    print('-----------')
    obj.add_one()   

    
if __name__ == '__main__':
    main()

# %%
#插入多条数据 并且用到 %s 

#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
    
    def get_more(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = [dict(zip([k[0] for k in cursor.description],row)) 
                for row in cursor.fetchall()]
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest

    def add_one(self):
        #准备SQL
        sql = ( #拼接成一个语句
            "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
            "(%s,%s,%s,%s,%s,%s);"
        ) 
        #sql = ( #拼接成一个语句
        #    "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
        #    "('伟哥牌notebook','8','1','66666','1','0');"
        #)
        #获取连接和cursor
        cursor = self.conn.cursor()
        #执行sql
        cursor.execute(sql,('伟哥牌notebook','8','1','66666','1','0'))
        cursor.execute(sql,('伟哥牌Mac','8','1','66666','1','0'))
        #cursor.execute(sql)
        #提交数据到数据库
        self.conn.commit()
        #提交事务
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        
def main():
    obj = MysqlSearch()#创建对象
    #rest = obj.get_one()
    #print(rest['goods_name'])
    #rest = obj.get_more()
    #for item in rest:
    #    print(item)
    #    print('-----------')
    obj.add_one()   

    
if __name__ == '__main__':
    main()

# %%
#插入多条数据  报错处理（因为多了一个列） 保证出错数据不会写入  并且用到 %s 

#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
    
    def get_more(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = [dict(zip([k[0] for k in cursor.description],row)) 
                for row in cursor.fetchall()]
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest

    def add_one(self):
        
        try：
            #准备SQL
            sql = ( #拼接成一个语句
                "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
                "(%s,%s,%s,%s,%s,%s);"
            ) 
            #sql = ( #拼接成一个语句
            #    "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
            #    "('伟哥牌notebook','8','1','66666','1','0');"
            #)
            #获取连接和cursor
            cursor = self.conn.cursor()
            #执行sql
            cursor.execute(sql,('伟哥牌notebook','8','1','66666','11','10'))
            cursor.execute(sql,('伟哥Mac','8','1','66666','11','10','报错吧'))
            #cursor.execute(sql)
            #提交数据到数据库
            self.conn.commit()
            #提交事务
            #关闭cursor和连接
            cursor.close()
            self.close_conn()
        except:
            print('error')
        
def main():
    obj = MysqlSearch()#创建对象
    #rest = obj.get_one()
    #print(rest['goods_name'])
    #rest = obj.get_more()
    #for item in rest:
    #    print(item)
    #    print('-----------')
    obj.add_one()   

    
if __name__ == '__main__':
    main()
# Out:
# error

# %%
#插入多条数据  报错处理（因为多了一个列）  self.conn.commit()加上之后提交正确部分   并且用到 %s 

#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
    
    def get_more(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = [dict(zip([k[0] for k in cursor.description],row)) 
                for row in cursor.fetchall()]
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest

    def add_one(self):
        
        try:
            #准备SQL
            sql = ( #拼接成一个语句
                "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
                "(%s,%s,%s,%s,%s,%s);"
            ) 
            #sql = ( #拼接成一个语句
            #    "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
            #    "('伟哥牌notebook','8','1','66666','1','0');"
            #)
            #获取连接和cursor
            cursor = self.conn.cursor()
            #执行sql
            cursor.execute(sql,('伟哥牌notebook','8','1','66666','11','10'))
            cursor.execute(sql,('伟哥Mac','8','1','66666','11','10','报错吧'))
            #cursor.execute(sql)
            #提交数据到数据库
            self.conn.commit()
            #提交事务
            #关闭cursor和连接
            cursor.close()
            self.close_conn()
        except:
            print('error')
            self.conn.commit()
        
def main():
    obj = MysqlSearch()#创建对象
    #rest = obj.get_one()
    #print(rest['goods_name'])
    #rest = obj.get_more()
    #for item in rest:
    #    print(item)
    #    print('-----------')
    obj.add_one()   

    
if __name__ == '__main__':
    main()
# Out:
# error

# %%
#插入多条数据  报错处理（因为多了一个列）  self.conn.rollback()  回滚    加上之后报错不提交所有   并且用到 %s 

#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
    
    def get_more(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = [dict(zip([k[0] for k in cursor.description],row)) 
                for row in cursor.fetchall()]
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest

    def add_one(self):
        
        try:
            #准备SQL
            sql = ( #拼接成一个语句
                "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
                "(%s,%s,%s,%s,%s,%s);"
            ) 
            #sql = ( #拼接成一个语句
            #    "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
            #    "('伟哥牌notebook','8','1','66666','1','0');"
            #)
            #获取连接和cursor
            cursor = self.conn.cursor()
            #执行sql
            cursor.execute(sql,('伟哥牌notebook','8','1','66666','11','10'))
            cursor.execute(sql,('伟哥Mac','8','1','66666','11','10','报错吧'))
            #cursor.execute(sql)
            #提交数据到数据库
            self.conn.commit()
            #提交事务
            #关闭cursor和连接
            cursor.close()
            self.close_conn()
        except:
            print('error')
            self.conn.rollback()
        
def main():
    obj = MysqlSearch()#创建对象
    #rest = obj.get_one()
    #print(rest['goods_name'])
    #rest = obj.get_more()
    #for item in rest:
    #    print(item)
    #    print('-----------')
    obj.add_one()   

    
if __name__ == '__main__':
    main()

# %%
#self.conn.commit() 是缓存数据提交到数据库

# %%
#close放在最后

#插入多条数据  报错处理（因为多了一个列）  self.conn.rollback()  回滚    加上之后报错不提交所有   并且用到 %s 

#也可以全部放进来

#检测是否安装好环境
import MySQLdb

class MysqlSearch(object):
    
    def __init__(self):
        self.get_conn()#初始化时候调用
    
    def get_conn(self):
        #使用python连接数据库
        #异常处理
        try:
            self.conn = MySQLdb.connect(
                host = '127.0.0.1',
                user = 'root',
                passwd = 'wangdawei',
                db = 'test',
                port = 3306,
                charset = 'utf8'
            )
            
        except MySQLdb.Error as e:
            print('Error:%s' % e)

    def close_conn(self):
        try:
            if self.conn:
                #关闭连接
                self.conn.close()
        except MySQLdb.Error as e:
            print('Error:%s' % e)     
        
    def get_one(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = dict(zip([k[0] for k in cursor.description],cursor.fetchone()))
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest
    
    def get_more(self):
        #目的：获取一条数据
        #准备SQL
        sql = 'select * from `tdb_goods` where `cate_id` = %s;' 
        #找到cursor
        cursor = self.conn.cursor()
        #执行SQL
        cursor.execute(sql,('5',))
        #print(cursor.rowcount)#获取行数，结果显示3行
        #print('--------------------------')
        #print(dir(cursor))#查看cursor的所有方法
        #print('--------------------------')
        #print(cursor.description)
        #print('--------------------------')#还是元组
        #拿到结果
        #转为字典打印
        rest = [dict(zip([k[0] for k in cursor.description],row)) 
                for row in cursor.fetchall()]
        #处理数据
        #print(rest)
        #print('-----------------------------------')
        #print(rest['goods_name'])
        #关闭cursor和连接
        cursor.close()
        self.close_conn()
        return rest

    def add_one(self):
        
        try:
            #准备SQL
            sql = ( #拼接成一个语句
                "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
                "(%s,%s,%s,%s,%s,%s);"
            ) 
            #sql = ( #拼接成一个语句
            #    "insert into `tdb_goods`(`goods_name`,`cate_id`,`brand_id`,`goods_price`,`is_show`,`is_saleoff`) value"
            #    "('伟哥牌notebook','8','1','66666','1','0');"
            #)
            #获取连接和cursor
            cursor = self.conn.cursor()
            #执行sql
            cursor.execute(sql,('伟哥牌notebook','8','1','66666','11','10'))
            cursor.execute(sql,('伟哥Mac','8','1','66666','11','10','报错吧'))
            #cursor.execute(sql)
            #提交数据到数据库
            self.conn.commit()
            #提交事务
            #关闭cursor和连接
            cursor.close()
            
        except:
            print('error')
            self.conn.rollback()
            
        self.close_conn()
        
def main():
    obj = MysqlSearch()#创建对象
    #rest = obj.get_one()
    #print(rest['goods_name'])
    #rest = obj.get_more()
    #for item in rest:
    #    print(item)
    #    print('-----------')
    obj.add_one()   

    
if __name__ == '__main__':
    main()
