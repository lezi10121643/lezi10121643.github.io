# %%
import pandas as pd

# %%
df = pd.read_csv("record1500.csv")

# %%
df.head()
# Out:
#   Sequence                                            Company          City  \
# 0        1  \u56DB\u5DDD\u7701\u94F6\u6CB3\u5316\u5B66\u80...  \u7EF5\u9633
# 1        2  \u56DB\u5DDD\u897F\u5357\u4E0D\u9508\u94A2\u67...  \u4E50\u5C71
# 2        3  \u56DB\u5DDD\u7701\u661F\u8239\u57CE\u6C34\u6C...  \u5185\u6C5F
# 3        4  \u56DB\u5DDD\u6CF8\u5B9A\u5C71\u76DB\u6C34\u6C...  \u7518\u5B5C
# 4        5  \u90A2\u53F0\u5E02\u6C38\u51A0\u7EBF\u7F06\u67...  \u90A2\u53F0
#
#        Province  Year  record
# 0  \u56DB\u5DDD  2016       1
# 1  \u56DB\u5DDD  2017       2
# 2  \u56DB\u5DDD  2016       3
# 3  \u56DB\u5DDD  2017       1
# 4  \u6CB3\u5317  2015       2

# %%
for i in df['City']:
    ''.join(i.split('\\u')
# Out:
# 7EF59633
# 4E505C71
# 51856C5F
# 75185B5C
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# 90A253F0
# ...

# %%
e = '\u56DB\u5DDD\u7701\u661F\u8239\u57CE\u6C34'

# %%
e = ''.join(e.split('\\u'))

# %%
e
# Out:
# '四川省星船城水'

# %%
c = e.encode('utf-16')
c.decode('utf-16')
# Out:
# '四川省星船城水'

# %%
c = e.encode('utf-8')
c.decode('utf-8')
# Out:
# '四川省星船城水'

# %%
def zhuanma(e):
    c = e.encode('utf-16')
    a = c.decode('utf-16')
    return a

# %%
e.encode('gbk')
# Out:
# b'\xcb\xc4\xb4\xa8\xca\xa1\xd0\xc7\xb4\xac\xb3\xc7\xcb\xae'

# %%
def zhuanma(e):
    return ''.join(e.split('\\u'))

# %%
print(df['City'].apply(zhuanma))
# Out:
# 0       \u7EF5\u9633
# 1       \u4E50\u5C71
# 2       \u5185\u6C5F
# 3       \u7518\u5B5C
# 4       \u90A2\u53F0
# 5       \u90A2\u53F0
# 6       \u90A2\u53F0
# 7       \u90A2\u53F0
# 8       \u90A2\u53F0
# 9       \u90A2\u53F0
# 10      \u90A2\u53F0
# 11      \u90A2\u53F0
# 12      \u90A2\u53F0
# 13      \u90A2\u53F0
# 14      \u90A2\u53F0
# 15      \u90A2\u53F0
# 16      \u90A2\u53F0
# 17      \u90A2\u53F0
# 18      \u90A2\u53F0
# 19      \u90A2\u53F0
# 20      \u90A2\u53F0
# 21      \u90A2\u53F0
# 22      \u90A2\u53F0
# 23      \u90A2\u53F0
# 24      \u90A2\u53F0
# 25      \u90A2\u53F0
# 26      \u90A2\u53F0
# 27      \u90A2\u53F0
# 28      \u90A2\u53F0
# 29      \u90A2\u53F0
#             ...
# 1465    \u90A2\u53F0
# 1466    \u90A2\u53F0
# 1467    \u90A2\u53F0
# 1468    \u90A2\u53F0
# 1469    \u90A2\u53F0
# 1470    \u90A2\u53F0
# 1471    \u90A2\u53F0
# 1472    \u90A2\u53F0
# 1473    \u90A2\u53F0
# 1474    \u90A2\u53F0
# 1475    \u90A2\u53F0
# 1476    \u90A2\u53F0
# ...

# %%
#df['City'].map(zhuanma)

# %%
df1.to_csv('ceshi.csv')

# %%
df1.head()
# Out:
# 0    \u7EF5\u9633
# 1    \u4E50\u5C71
# 2    \u5185\u6C5F
# 3    \u7518\u5B5C
# 4    \u90A2\u53F0
# Name: City, dtype: object

# %%
type(df1)
# Out:
# pandas.core.series.Series

# %%
df1.apply(zhuanma)
# Out:
# 0       7EF59633
# 1       4E505C71
# 2       51856C5F
# 3       75185B5C
# 4       90A253F0
# 5       90A253F0
# 6       90A253F0
# 7       90A253F0
# 8       90A253F0
# 9       90A253F0
# 10      90A253F0
# 11      90A253F0
# 12      90A253F0
# 13      90A253F0
# 14      90A253F0
# 15      90A253F0
# 16      90A253F0
# 17      90A253F0
# 18      90A253F0
# 19      90A253F0
# 20      90A253F0
# 21      90A253F0
# 22      90A253F0
# 23      90A253F0
# 24      90A253F0
# 25      90A253F0
# 26      90A253F0
# 27      90A253F0
# 28      90A253F0
# 29      90A253F0
#           ...
# 1465    90A253F0
# 1466    90A253F0
# 1467    90A253F0
# 1468    90A253F0
# 1469    90A253F0
# 1470    90A253F0
# 1471    90A253F0
# 1472    90A253F0
# 1473    90A253F0
# 1474    90A253F0
# 1475    90A253F0
# 1476    90A253F0
# 1477    90A253F0
# 1478    90A253F0
# 1479    90A253F0
# 1480    90A253F0
# 1481    90A253F0
# 1482    90A253F0
# 1483    90A253F0
# 1484    90A253F0
# 1485    90A253F0
# ...

# %%
import chardet

# %%
chardet.detect('\u56DB\u5DDD\u7701\u661F\u8239\u57CE\u6C34')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-97-51d92d50629b> in <module>()
# ----> 1 chardet.detect('\u56DB\u5DDD\u7701\u661F\u8239\u57CE\u6C34')
#
# C:\ProgramData\Anaconda3\lib\site-packages\chardet\__init__.py in detect(byte_str)
#      32         if not isinstance(byte_str, bytes):
#      33             raise TypeError('Expected object of type bytes or bytearray, got: '
# ---> 34                             '{0}'.format(type(byte_str)))
#      35         else:
#      36             byte_str = bytearray(byte_str)
#
# TypeError: Expected object of type bytes or bytearray, got: <class 'str'>
