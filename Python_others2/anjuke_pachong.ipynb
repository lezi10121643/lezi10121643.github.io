# %%
import requests
import time
res=requests.get('http://beijing.anjuke.com/tycoon/?from=navigation').add_header('User-Agent','Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36')#res.text#显示内容
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-edb70fe24fec> in <module>()
#       1 import requests
#       2 import time
# ----> 3 res=requests.get('http://beijing.anjuke.com/tycoon/?from=navigation').add_header('User-Agent','Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36')#res.text#显示内容
#
# AttributeError: 'Response' object has no attribute 'add_header'

# %%
from bs4 import BeautifulSoup
#domain='http://beijing.anjuke.com/tycoon/?from=navigation'
soup = BeautifulSoup(res.text,'html.parser')

print(soup)

#for house in soup.select('.jjr-title a'):#定位到class等于jjr-title,后面是<dl ......
    #print(house)
    #time.sleep(3)
    #print(house.select('.title')[0].text.strip())#strip()清除换行
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-61a72966abc4> in <module>()
#       1 from bs4 import BeautifulSoup
#       2 #domain='http://beijing.anjuke.com/tycoon/?from=navigation'
# ----> 3 soup = BeautifulSoup(res.text,'html.parser').add_header('User-Agent','Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36')
#       4
#       5 print(soup)
#
# TypeError: 'NoneType' object is not callable

# %%
title=house.select('.title')[0].text.strip()#strip()清除换行
    url=domain+house.select('.title a')[0]['href']#title下面的a链接里面的href(这里抓到的是相对链接)要+主域名
    print(url)
    print('===============================================================')

# %%
import urllib.request
import re

pat1='<a target="_blank" title="(.*?)" href'
pat2='" target="_blank" >(.*?)</a>'
#pat3='" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;</p>'
pat4='熟悉<a href=".*?" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;<a href=".*?" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;<a href=".*?" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;</p>'
pat5='<i class="tel-icon"></i>(.*?)                        </div>'               
  
result4aa=[]
result4ab=[]
result4ac=[]    

for i in range(1,422):
    
    url='http://beijing.anjuke.com/tycoon/p'+str(i)
    req=urllib.request.Request(url)
    req.add_header('User-Agent','Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36')
    data=urllib.request.urlopen(req).read().decode('utf-8')
#print(data)
           

    result1 = re.compile(pat1).findall(str(data))
    result2 = re.compile(pat2).findall(str(data))
    #result3 = re.compile(pat3).findall(str(data))
    result4 = re.compile(pat4).findall(str(data))
    result5= re.compile(pat5).findall(str(data))

    result2a=result2[1:]
    result2aa=result2a[0::2]
    result2ab=result2a[1::2]
#result4a=result4

    
    b=len(result4)
#print(b)

    for a in range(b):
        result4a=result4[a]
        
        for c in range(3):
            if c==0:
                result4aa.append(result4a[c])
            if c==1:   
                result4ab.append(result4a[c])
            if c==2:
                result4ac.append(result4a[c])
            
print(result1)
#print(result2)
#print(result2a)
print(result2aa)
print(result2ab)
#print(result3a)

#print(result4)
#print(result4a)
print(result4aa)
print(result4ab)
print(result4ac)
print(result5)

# %%
import urllib.request
import re
import os,glob
import xlwt

book = xlwt.Workbook()
sheet = book.add_sheet('sheet', cell_overwrite_ok=True)
path = 'D:\\work'
os.chdir(path)

pat1='<a target="_blank" title="(.*?)" href'
pat2='" target="_blank" >(.*?)</a>'
#pat3='" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;</p>'
pat4='熟悉<a href=".*?" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;<a href=".*?" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;<a href=".*?" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;</p>'
pat5='<i class="tel-icon"></i>(.*?)                        </div>'               
  

    
result11=[]
result22a=[]
result22b=[]
result44=[]
#result4aa=[]
#result4ab=[]
#result4ac=[] 
result55=[]

for i in range(422):#422
    
    url='http://beijing.anjuke.com/tycoon/p'+str(i)
    req=urllib.request.Request(url)
    req.add_header('User-Agent','Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36')
    data=urllib.request.urlopen(req).read().decode('utf-8')
#print(data)
           

    result1 = re.compile(pat1).findall(str(data))
    result11.extend(result1)
    result2 = re.compile(pat2).findall(str(data))

    
    #result3 = re.compile(pat3).findall(str(data))
    result4 = re.compile(pat4).findall(str(data))
    result5= re.compile(pat5).findall(str(data))
    result55.extend(result5)

    result2a=result2[1:]
    result2aa=result2a[0::2]
    result22a.extend(result2aa)
    result2ab=result2a[1::2]
    result22b.extend(result2ab)
    result44.extend(result4)
#result4a=result4

    
    #b=len(result4)
#print(b)

    #for a in range(5):
'''      
    result4a=result44[i]
        
    for c in range(3):
        if c==0:
             result4aa.extend(result4a[c])
        if c==1:   
             result4ab.extend(result4a[c])
        if c==2:
             result4ac.extend(result4a[c])
'''
print('result11  ======================================================================')
print(result11)
print('result22a =======================================================================')
#print(result2)
#print(result2a)
print(result22a)
print('result22b  =======================================================================')
print(result22b)
#print(result3a)
#print('result4  =======================================================================')
#print(result4)
print('result44  =======================================================================')
print(result44)
#print('result4a  =======================================================================')
#print(result4a)
#print('result4aa  =======================================================================')
#print(result4aa)
#print('result4ab  =======================================================================')
#print(result4ab)
#print('result4ac  =======================================================================')
#print(result4ac)
print('result55  =======================================================================')
print(result55)
# Out:
# result11  ======================================================================
# ...

# %%
j = 0
for i in range(0,len(50)):
    try:
        zhiwei = result11[i]
        wangzhi = result21[i]
        gongzi = result31[i]
        gongzuodidian = result41[i]
        gongsimingcheng = result51[i]
    
        sheet.write(i + 1, j, zhiwei)
        sheet.write(i + 1, j + 1, wangzhi)
        sheet.write(i + 1, j + 2, gongzi)
        sheet.write(i + 1, j + 3, gongzuodidian)
        sheet.write(i + 1, j + 4, gongsimingcheng)

    except Exception as e:
        print('出现异常：' + str(e))
        continue

book.save('d:\\shujufenxishi.xls')

最后把列表文件循环写到本地xls文件中

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-

import urllib.request
import re
import os,glob
import xlwt

book = xlwt.Workbook()
sheet = book.add_sheet('sheet', cell_overwrite_ok=True)
path = 'D:\\work'
os.chdir(path)

pat1='<a target="_blank" title="(.*?)" href'
pat2='" target="_blank" >(.*?)</a>'
#pat3='" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;</p>'
pat4='熟悉<a href=".*?" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;<a href=".*?" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;<a href=".*?" target="_blank">(.*?)</a>&nbsp;&nbsp;&nbsp;</p>'
pat5='<i class="tel-icon"></i>(.*?)                        </div>'               
  

    
result11=[]
result22a=[]
result22b=[]
result44=[]
#result4aa=[]
#result4ab=[]
#result4ac=[] 
result55=[]

for i in range(2):#422
    
    url='http://beijing.anjuke.com/tycoon/p'+str(i)
    req=urllib.request.Request(url)
    req.add_header('User-Agent','Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36')
    data=urllib.request.urlopen(req).read().decode('utf-8')
#print(data)
           

    result1 = re.compile(pat1).findall(str(data))
    result11.extend(result1)
    result2 = re.compile(pat2).findall(str(data))

    
    #result3 = re.compile(pat3).findall(str(data))
    result4 = re.compile(pat4).findall(str(data))
    result5= re.compile(pat5).findall(str(data))
    result55.extend(result5)

    result2a=result2[1:]
    result2aa=result2a[0::2]
    result22a.extend(result2aa)
    result2ab=result2a[1::2]
    result22b.extend(result2ab)
    result44.extend(result4)
#result4a=result4

    
    #b=len(result4)
#print(b)

    #for a in range(5):
'''      
    result4a=result44[i]
        
    for c in range(3):
        if c==0:
             result4aa.extend(result4a[c])
        if c==1:   
             result4ab.extend(result4a[c])
        if c==2:
             result4ac.extend(result4a[c])
'''
print('result11  ======================================================================')
print(result11)
print('result22a =======================================================================')
#print(result2)
#print(result2a)
print(result22a)
print('result22b  =======================================================================')
print(result22b)
#print(result3a)
#print('result4  =======================================================================')
#print(result4)
print('result44  =======================================================================')
print(result44)
#print('result4a  =======================================================================')
#print(result4a)
#print('result4aa  =======================================================================')
#print(result4aa)
#print('result4ab  =======================================================================')
#print(result4ab)
#print('result4ac  =======================================================================')
#print(result4ac)
print('result55  =======================================================================')
print(result55)



j = 0
for k in range(1,3):
    try:
        name = result11[k]
        company = result22a[k]
        location = result22b[k]
        area = result44[k]
        tele = result55[k]
    
        sheet.write(k + 1, j, name)
        sheet.write(k + 1, j + 1, company)
        sheet.write(k + 1, j + 2, location)
        sheet.write(k + 1, j + 3, area)
        sheet.write(k + 1, j + 4, tele)

    except Exception as e:
        print('出现异常：' + str(e))
        continue

book.save('D:\\anjuke.xls')
book.close()
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-91-c1f3f2065890> in <module>()
#      34     req=urllib.request.Request(url)
#      35     req.add_header('User-Agent','Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36')
# ---> 36     data=urllib.request.urlopen(req).read().decode('utf-8')
#      37 #print(data)
#      38
#
# C:\Anaconda3\lib\urllib\request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     161     else:
#     162         opener = _opener
# --> 163     return opener.open(url, data, timeout)
#     164
#     165 def install_opener(opener):
#
# C:\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     464             req = meth(req)
#     465
# --> 466         response = self._open(req, data)
#     467
# ...

# %%
list((1,2,3))
# Out:
# [1, 2, 3]

# %%
list(('1','2','3'))
# Out:
# ['1', '2', '3']
