# %% [markdown]
# # 正则表达式

# %% [markdown]
# ## 常见匹配模式

# %% [markdown]
# | 模式| 描述|
# |----|----|
# | \w	| 匹配字母数字及下划线 |
# | \W	| 匹配非字母数字下划线 |
# | \s	| 匹配任意空白字符，等价于 [\t\n\r\f]. |
# | \S	| 匹配任意非空字符 |
# | \d	| 匹配任意数字，等价于 [0-9] |
# | \D	| 匹配任意非数字 |
# | \A	| 匹配字符串开始 |
# | \Z	| 匹配字符串结束，如果是存在换行，只匹配到换行前的结束字符串 |
# | \z	| 匹配字符串结束 |
# | \G	| 匹配最后匹配完成的位置 |
# | \n | 匹配一个换行符 |
# | \t | 匹配一个制表符 |
# | ^	| 匹配字符串的开头 |
# | $	| 匹配字符串的末尾。|
# | .	| 匹配任意字符，除了换行符，当re.DOTALL标记被指定时，则可以匹配包括换行符的任意字符。|
# | [...]	| 用来表示一组字符,单独列出：[amk] 匹配 'a'，'m'或'k' |
# | [^...]	| 不在[]中的字符：[^abc] 匹配除了a,b,c之外的字符。|
# | *	| 匹配0个或多个的表达式。|
# | +	| 匹配1个或多个的表达式。|
# | ?	| 匹配0个或1个由前面的正则表达式定义的片段，非贪婪方式|
# | {n}	| 精确匹配n个前面表达式。|
# | {n, m} | 匹配 n 到 m 次由前面的正则表达式定义的片段，贪婪方式|
# | a&#124;b | 匹配a或b |
# | ( )	| 匹配括号内的表达式，也表示一个组 |

# %% [markdown]
# ## re.match
# re.match 尝试从字符串的起始位置匹配一个模式，如果不是起始位置匹配成功的话，match()就返回none。

# %% [raw]
# re.match(pattern, string, flags=0)

# %% [markdown]
# ### 最常规的匹配

# %%
import re

content = 'Hello 123 4567 World_This is a Regex Demo'
print(len(content))
result = re.match('^Hello\s\d\d\d\s\d{4}\s\w{10}.*Demo$', content)
#^字符串开头   $字符串结尾
print(result)
print(result.group())#输出匹配结果
print(result.span())#输出匹配结果范围，整个字符串
# Out:
# 41
# <_sre.SRE_Match object; span=(0, 41), match='Hello 123 4567 World_This is a Regex Demo'>
# Hello 123 4567 World_This is a Regex Demo
# (0, 41)

# %% [markdown]
# ### 泛匹配

# %%
import re

content = 'Hello 123 4567 World_This is a Regex Demo'
result = re.match('^Hello.*Demo$', content)
print(result)
print(result.group())
print(result.span())
# Out:
# <_sre.SRE_Match object; span=(0, 41), match='Hello 123 4567 World_This is a Regex Demo'>
# Hello 123 4567 World_This is a Regex Demo
# (0, 41)

# %% [markdown]
# ### 匹配目标

# %%
#用小括号
import re

content = 'Hello 1234567 World_This is a Regex Demo'
result = re.match('^Hello\s(\d+)\sWorld.*Demo$', content)
print(result)
print(result.group(1))#选取部分结果
print(result.span())
# Out:
# <_sre.SRE_Match object; span=(0, 40), match='Hello 1234567 World_This is a Regex Demo'>
# 1234567
# (0, 40)

# %% [markdown]
# ### 贪婪匹配

# %%
import re

content = 'Hello 1234567 World_This is a Regex Demo'
result = re.match('^He.*(\d+).*Demo$', content)
print(result)
print(result.group(1))
#贪婪：.*匹配尽可能多的
# Out:
# <_sre.SRE_Match object; span=(0, 40), match='Hello 1234567 World_This is a Regex Demo'>
# 7

# %% [markdown]
# ### 非贪婪匹配

# %%
import re

content = 'Hello 1234567 World_This is a Regex Demo'
result = re.match('^He.*?(\d+).*Demo$', content)
print(result)
print(result.group(1))
#非贪婪：加了？之后匹配尽可能少
# Out:
# <_sre.SRE_Match object; span=(0, 40), match='Hello 1234567 World_This is a Regex Demo'>
# 1234567

# %%
import re

content = '''Hello 1234567 World_This
is a Regex Demo
'''
result = re.match('^He.*?(\d+).*?Demo$', content)
print(result)
#点不能匹配换行符
# Out:
# None

# %% [markdown]
# ### 匹配模式

# %%
import re

content = '''Hello 1234567 World_This
is a Regex Demo
'''
result = re.match('^He.*?(\d+).*?Demo$', content, re.S)
print(result.group(0))
print('------------------------')
print(result.group(1))
# Out:
# Hello 1234567 World_This
# is a Regex Demo
# ------------------------
# 1234567

# %% [markdown]
# ### 转义

# %%
import re

content = 'price is $5.00'
result = re.match('price is $5.00', content)
print(result)
# Out:
# None

# %%
import re

content = 'price is $5.00'
result = re.match('price is \$5\.00', content)
print(result)
print(result.group(0))
# Out:
# <_sre.SRE_Match object; span=(0, 14), match='price is $5.00'>
# price is $5.00

# %% [markdown]
# 总结：尽量使用泛匹配、使用括号得到匹配目标、尽量使用非贪婪模式、有换行符就用re.S

# %% [markdown]
# ## re.search
# re.search 扫描整个字符串并返回第一个成功的匹配。

# %%
import re

content = 'Extra stings Hello 1234567 World_This is a Regex Demo Extra stings'
result = re.match('Hello.*?(\d+).*?Demo', content)
print(result)
#match是从字符串第一个开始匹配的
# Out:
# None

# %%
import re

content = 'Extra stings Hello 1234567 World_This is a Regex Demo Extra stings'
result = re.search('Hello.*?(\d+).*?Demo', content)
print(result)
print(result.group(1))
# Out:
# <_sre.SRE_Match object; span=(13, 53), match='Hello 1234567 World_This is a Regex Demo'>
# 1234567

# %% [markdown]
# 总结：为匹配方便，能用search就不用match

# %% [markdown]
# ### 匹配演练

# %%
import re

html = '''<div id="songs-list">
    <h2 class="title">经典老歌</h2>
    <p class="introduction">
        经典老歌列表
    </p>
    <ul id="list" class="list-group">
        <li data-view="2">一路上有你</li>
        <li data-view="7">
            <a href="/2.mp3" singer="任贤齐">沧海一声笑</a>
        </li>
        <li data-view="4" class="active">
            <a href="/3.mp3" singer="齐秦">往事随风</a>
        </li>
        <li data-view="6"><a href="/4.mp3" singer="beyond">光辉岁月</a></li>
        <li data-view="5"><a href="/5.mp3" singer="陈慧琳">记事本</a></li>
        <li data-view="5">
            <a href="/6.mp3" singer="邓丽君"><i class="fa fa-user"></i>但愿人长久</a>
        </li>
    </ul>
</div>'''
result = re.search('<li.*?active.*?singer="(.*?)">(.*?)</a>', html, re.S)
if result:
    print(result.group(1), result.group(2))#group（1）第一个小括号匹配的内容
# Out:
# 齐秦 往事随风

# %%
import re

html = '''<div id="songs-list">
    <h2 class="title">经典老歌</h2>
    <p class="introduction">
        经典老歌列表
    </p>
    <ul id="list" class="list-group">
        <li data-view="2">一路上有你</li>
        <li data-view="7">
            <a href="/2.mp3" singer="任贤齐">沧海一声笑</a>
        </li>
        <li data-view="4" class="active">
            <a href="/3.mp3" singer="齐秦">往事随风</a>
        </li>
        <li data-view="6"><a href="/4.mp3" singer="beyond">光辉岁月</a></li>
        <li data-view="5"><a href="/5.mp3" singer="陈慧琳">记事本</a></li>
        <li data-view="5">
            <a href="/6.mp3" singer="邓丽君">但愿人长久</a>
        </li>
    </ul>
</div>'''
result = re.search('<li.*?singer="(.*?)">(.*?)</a>', html, re.S)
if result:
    print(result.group(1), result.group(2))
#搜索到第一个匹配结果，输出
# Out:
# 任贤齐 沧海一声笑

# %%
import re

html = '''<div id="songs-list">
    <h2 class="title">经典老歌</h2>
    <p class="introduction">
        经典老歌列表
    </p>
    <ul id="list" class="list-group">
        <li data-view="2">一路上有你</li>
        <li data-view="7">
            <a href="/2.mp3" singer="任贤齐">沧海一声笑</a>
        </li>
        <li data-view="4" class="active">
            <a href="/3.mp3" singer="齐秦">往事随风</a>
        </li>
        <li data-view="6"><a href="/4.mp3" singer="beyond">光辉岁月</a></li>
        <li data-view="5"><a href="/5.mp3" singer="陈慧琳">记事本</a></li>
        <li data-view="5">
            <a href="/6.mp3" singer="邓丽君">但愿人长久</a>
        </li>
    </ul>
</div>'''
result = re.search('<li.*?singer="(.*?)">(.*?)</a>', html)
if result:
    print(result.group(1), result.group(2))
#re.S去掉，只能匹配到在一行上的
# Out:
# beyond 光辉岁月

# %% [markdown]
# ## re.findall
# 搜索字符串，以列表形式返回全部能匹配的子串。

# %%
import re

html = '''<div id="songs-list">
    <h2 class="title">经典老歌</h2>
    <p class="introduction">
        经典老歌列表
    </p>
    <ul id="list" class="list-group">
        <li data-view="2">一路上有你</li>
        <li data-view="7">
            <a href="/2.mp3" singer="任贤齐">沧海一声笑</a>
        </li>
        <li data-view="4" class="active">
            <a href="/3.mp3" singer="齐秦">往事随风</a>
        </li>
        <li data-view="6"><a href="/4.mp3" singer="beyond">光辉岁月</a></li>
        <li data-view="5"><a href="/5.mp3" singer="陈慧琳">记事本</a></li>
        <li data-view="5">
            <a href="/6.mp3" singer="邓丽君">但愿人长久</a>
        </li>
    </ul>
</div>'''
results = re.findall('<li.*?href="(.*?)".*?singer="(.*?)">(.*?)</a>', html, re.S)
print(results)
print('----------------')
print(type(results))
print('----------------')
for result in results:
    print(result)
    print('---------')
    print(result[0], result[1], result[2])
    print('=========')
# Out:
# [('/2.mp3', '任贤齐', '沧海一声笑'), ('/3.mp3', '齐秦', '往事随风'), ('/4.mp3', 'beyond', '光辉岁月'), ('/5.mp3', '陈慧琳', '记事本'), ('/6.mp3', '邓丽君', '但愿人长久')]
# ----------------
# <class 'list'>
# ----------------
# ('/2.mp3', '任贤齐', '沧海一声笑')
# ---------
# /2.mp3 任贤齐 沧海一声笑
# =========
# ('/3.mp3', '齐秦', '往事随风')
# ---------
# /3.mp3 齐秦 往事随风
# =========
# ('/4.mp3', 'beyond', '光辉岁月')
# ---------
# /4.mp3 beyond 光辉岁月
# =========
# ('/5.mp3', '陈慧琳', '记事本')
# ---------
# /5.mp3 陈慧琳 记事本
# =========
# ('/6.mp3', '邓丽君', '但愿人长久')
# ---------
# /6.mp3 邓丽君 但愿人长久
# =========

# %%
#第一首歌没有超链接，也需要匹配
import re

html = '''<div id="songs-list">
    <h2 class="title">经典老歌</h2>
    <p class="introduction">
        经典老歌列表
    </p> 
    <ul id="list" class="list-group">
        <li data-view="2">一路上有你</li>
        <li data-view="7">
            <a href="/2.mp3" singer="任贤齐">沧海一声笑</a>
        </li>
        <li data-view="4" class="active">
            <a href="/3.mp3" singer="齐秦">往事随风</a>
        </li>
        <li data-view="6"><a href="/4.mp3" singer="beyond">光辉岁月</a></li>
        <li data-view="5"><a href="/5.mp3" singer="陈慧琳">记事本</a></li>
        <li data-view="5">
            <a href="/6.mp3" singer="邓丽君">但愿人长久</a>
        </li>
    </ul>
</div>'''
results = re.findall('<li.*?>\s*?(<a.*?>)?(\w+)(</a>)?\s*?</li>', html, re.S)
print(results)
for result in results:
    print(result[1])
#\s*? 匹配是否有换行符
#(<a.*?>)?  ？是匹配0个或者一个
# Out:
# [('', '一路上有你', ''), ('<a href="/2.mp3" singer="任贤齐">', '沧海一声笑', '</a>'), ('<a href="/3.mp3" singer="齐秦">', '往事随风', '</a>'), ('<a href="/4.mp3" singer="beyond">', '光辉岁月', '</a>'), ('<a href="/5.mp3" singer="陈慧琳">', '记事本', '</a>'), ('<a href="/6.mp3" singer="邓丽君">', '但愿人长久', '</a>')]
# 一路上有你
# 沧海一声笑
# 往事随风
# 光辉岁月
# 记事本
# 但愿人长久

# %% [markdown]
# ### re.sub
# 替换字符串中每一个匹配的子串后返回替换后的字符串。

# %%
import re

content = 'Extra stings Hello 1234567 World_This is a Regex Demo Extra stings'
content = re.sub('\d+', '', content)#三个参数：正则表达式，替换成的字符串，原字符串
print(content)
# Out:
# Extra stings Hello  World_This is a Regex Demo Extra stings

# %%
import re

content = 'Extra stings Hello 1234567 World_This is a Regex Demo Extra stings'
content = re.sub('\d+', 'Replacement', content)
print(content)
# Out:
# Extra stings Hello Replacement World_This is a Regex Demo Extra stings

# %%
# Out:
# Extra stings Hello 1234567 8910 World_This is a Regex Demo Extra stings

# %%
import re

html = '''<div id="songs-list">
    <h2 class="title">经典老歌</h2>
    <p class="introduction">
        经典老歌列表
    </p>
    <ul id="list" class="list-group">
        <li data-view="2">一路上有你</li>
        <li data-view="7">
            <a href="/2.mp3" singer="任贤齐">沧海一声笑</a>
        </li>
        <li data-view="4" class="active">
            <a href="/3.mp3" singer="齐秦">往事随风</a>
        </li>
        <li data-view="6"><a href="/4.mp3" singer="beyond">光辉岁月</a></li>
        <li data-view="5"><a href="/5.mp3" singer="陈慧琳">记事本</a></li>
        <li data-view="5">
            <a href="/6.mp3" singer="邓丽君">但愿人长久</a>
        </li>
    </ul>
</div>'''

# %%
import re

html = '''<div id="songs-list">
    <h2 class="title">经典老歌</h2>
    <p class="introduction">
        经典老歌列表
    </p>
    <ul id="list" class="list-group">
        <li data-view="2">一路上有你</li>
        <li data-view="7">
            <a href="/2.mp3" singer="任贤齐">沧海一声笑</a>
        </li>
        <li data-view="4" class="active">
            <a href="/3.mp3" singer="齐秦">往事随风</a>
        </li>
        <li data-view="6"><a href="/4.mp3" singer="beyond">光辉岁月</a></li>
        <li data-view="5"><a href="/5.mp3" singer="陈慧琳">记事本</a></li>
        <li data-view="5">
            <a href="/6.mp3" singer="邓丽君">但愿人长久</a>
        </li>
    </ul>
</div>'''
html = re.sub('<a.*?>|</a>', '', html)#删除a标签
print(html)
print('----------')
results = re.findall('<li.*?>(.*?)</li>', html, re.S)
print(results)
print('----------')
for result in results:
    print(result.strip())#去除换行符等
# Out:
# <div id="songs-list">
#     <h2 class="title">经典老歌</h2>
#     <p class="introduction">
#         经典老歌列表
#     </p>
#     <ul id="list" class="list-group">
#         <li data-view="2">一路上有你</li>
#         <li data-view="7">
#             沧海一声笑
#         </li>
#         <li data-view="4" class="active">
#             往事随风
#         </li>
#         <li data-view="6">光辉岁月</li>
#         <li data-view="5">记事本</li>
#         <li data-view="5">
#             但愿人长久
#         </li>
#     </ul>
# </div>
# ----------
# ['一路上有你', '\n            沧海一声笑\n        ', '\n            往事随风\n        ', '光辉岁月', '记事本', '\n            但愿人长久\n        ']
# ----------
# 一路上有你
# 沧海一声笑
# 往事随风
# 光辉岁月
# 记事本
# 但愿人长久

# %% [markdown]
# ## re.compile
# 将正则字符串编译成正则表达式对象

# %%
将一个正则表达式串编译成正则对象，以便于复用该匹配模式

# %%
import re

content = '''Hello 1234567 World_This
is a Regex Demo'''
pattern = re.compile('Hello.*Demo', re.S)
result = re.match(pattern, content)
#result = re.match('Hello.*Demo', content, re.S)
print(result)
# Out:
# <_sre.SRE_Match object; span=(0, 40), match='Hello 1234567 World_This\nis a Regex Demo'>

# %% [markdown]
# ## 实战练习

# %%
import requests
import re
content = requests.get('https://book.douban.com/').text
print(content)
# Out:
# <!DOCTYPE html>
# <html lang="zh-CN" class=" book-new-nav">
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="Pragma" content="no-cache">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta http-equiv="Expires" content="Sun, 6 Mar 2005 01:00:00 GMT">
#
#   <meta http-equiv="mobile-agent" content="format=xhtml; url=http://m.douban.com/book/">
#   <meta name="keywords" content="豆瓣读书,新书速递,畅销书,书评,书单"/>
#   <meta name="description" content="记录你读过的、想读和正在读的书，顺便打分，添加标签及个人附注，写评论。根据你的口味，推荐适合的书给你。" />
#   <meta name="verify-v1" content="EYARGSAVd5U+06FeTmxO8Mj28Fc/hM/9PqMfrlMo8YA=">
#   <meta property="wb:webmaster" content="7c86191e898cd20d">
#   <meta property="qc:admins" content="1520412177364752166375">
#
#     <title>
#     豆瓣读书
# </title>
#     <link rel="shortcut icon" href="https://img3.doubanio.com/favicon.ico"
#       type="image/x-icon">
#     <script src="https://img3.doubanio.com/f/book/0495cb173e298c28593766009c7b0a953246c5b5/js/book/lib/jquery/jquery.js"></script>
#     <script>
#       var Douban = {}, Book = {}
#       var Do=function(){Do.actions.push([].slice.call(arguments))};Do.ready=function(){Do.actions.push([].slice.call(arguments))},Do.add=Do.define=function(o,l){Do.mods[o]=l},Do.global=function(){Do.global.mods=Array.concat(Do.global.mods,[].slice.call(arguments))},Do.global.mods=[],Do.mods={},Do.actions=[];
#     </script>
#
#
# <script src="https://img3.doubanio.com/f/book/6a411a14e088636db2bc428ec7125b476791e3fd/js/book/lib/define.js"></script>
# <script>
#   define.ns('Book')
#   define.config({
#     'jquery': '$'
#   , 'piwik': 'Piwik'
#   , 'mod/ga': 'Book.ga'
#   , 'mod/ajax': 'Book.ajax'
#   , 'mod/cookie': 'Book.cookie'
#   })
#
#   Do.add('mod/cookie', {
#     path: 'https://img3.doubanio.com/f/book/6542b92d560cd64f30c9248e6c35499cc11c0d29/js/book/mod/cookie.js'
#   , type: 'js'
#   })
#
#   Do.add('mod/ajax', {
#     path: 'https://img3.doubanio.com/f/book/b455e168dbfaa03597d2e336c3f56e32843361c9/js/book/mod/ajax.js'
#   , requires: ['mod/cookie']
#   , type: 'js'
#   })
#
#   Do.add('mod/ga', {
#     path: 'https://img3.doubanio.com/f/book/42544a42ebd9be4aee64b3a8c6df1a15a8c8e020/js/book/mod/ga.js'
#   , type: 'js'
#   })
# </script>
#
#
# <script>!function(e){var o=function(o,n,t){var c,i,r=new Date;n=n||30,t=t||"/",r.setTime(r.getTime()+24*n*60*60*1e3),c="; expires="+r.toGMTString();for(i in o)e.cookie=i+"="+o[i]+c+"; path="+t},n=function(o){var n,t,c,i=o+"=",r=e.cookie.split(";");for(t=0,c=r.length;t<c;t++)if(n=r[t].replace(/^\s+|\s+$/g,""),0==n.indexOf(i))return n.substring(i.length,n.length).replace(/\"/g,"");return null},t=e.write,c={"douban.com":1,"douban.fm":1,"google.com":1,"google.cn":1,"googleapis.com":1,"gmaptiles.co.kr":1,"gstatic.com":1,"gstatic.cn":1,"google-analytics.com":1,"googleadservices.com":1},i=function(e,o){var n=new Image;n.onload=function(){},n.src="https://www.douban.com/j/except_report?kind=ra022&reason="+encodeURIComponent(e)+"&environment="+encodeURIComponent(o)},r=function(o){try{t.call(e,o)}catch(e){t(o)}},a=/<script.*?src\=["']?([^"'\s>]+)/gi,g=/http:\/\/(.+?)\.([^\/]+).+/i;e.writeln=e.write=function(e){var t,l=a.exec(e);return l&&(t=g.exec(l[1]))?c[t[2]]?void r(e):void("tqs"!==n("hj")&&(i(l[1],location.href),o({hj:"tqs"},1),setTimeout(function(){location.replace(location.href)},50))):void r(e)}}(document);
# </script>
#
#
#
#   <link href="https://img3.doubanio.com/f/book/0189db91698906cb9337fc8ec5be6f547a7779a0/css/book/master.css" rel="stylesheet" type="text/css">
#
#   <style type="text/css"></style>
#   <script>var _head_start = new Date();</script>
#
#
#
#   <script>
#     define.config({
#       'ui/slide': 'Book.slide'
#     , 'ui/bubble': 'Book.Bubble'
#     })
#     Do.add('book/index', { path: 'https://img3.doubanio.com/f/book/f1e2f99e54fb81741b67c9fbf7a5c2d95dfc9eb7/js/book/index.js' })
#     Do.add('ui/slide', { path: 'https://img3.doubanio.com/f/book/2f473e3eae1803f9e743ea632607ad4f9677fb3b/js/book/ui/slide.js' })
#     Do.add('ui/bubble', { path: 'https://img3.doubanio.com/f/book/95c407df830e0ab6119ed622ee42033acf0af414/js/book/ui/bubble.js' })
#     Do.add('widget/tabs', { path: 'https://img3.doubanio.com/f/book/1c240c18b397f6c8583254c27b9c1f1ecebb6075/js/book/widget/tabs.js' })
#     Do('book/index')
#   </script>
#   <script type='text/javascript'>
#     var _vds = _vds || [];
#     (function(){ _vds.push(['setAccountId', '22c937bbd8ebd703f2d8e9445f7dfd03']);
#         _vds.push(['setCS1','user_id','0']);
#             (function() {var vds = document.createElement('script');
#                 vds.type='text/javascript';
#                 vds.async = true;
#                 vds.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'dn-growing.qbox.me/vds.js';
#                 var s = document.getElementsByTagName('script')[0];
#                 s.parentNode.insertBefore(vds, s);
#             })();
#     })();
# </script>
#
#
#   <script type='text/javascript'>
#     var _vwo_code=(function(){
#       var account_id=249272,
#           settings_tolerance=2000,
#           library_tolerance=2500,
#           use_existing_jquery=false,
#           // DO NOT EDIT BELOW THIS LINE
#           f=false,d=document;return{use_existing_jquery:function(){return use_existing_jquery;},library_tolerance:function(){return library_tolerance;},finish:function(){if(!f){f=true;var a=d.getElementById('_vis_opt_path_hides');if(a)a.parentNode.removeChild(a);}},finished:function(){return f;},load:function(a){var b=d.createElement('script');b.src=a;b.type='text/javascript';b.innerText;b.onerror=function(){_vwo_code.finish();};d.getElementsByTagName('head')[0].appendChild(b);},init:function(){settings_timer=setTimeout('_vwo_code.finish()',settings_tolerance);var a=d.createElement('style'),b='body{opacity:0 !important;filter:alpha(opacity=0) !important;background:none !important;}',h=d.getElementsByTagName('head')[0];a.setAttribute('id','_vis_opt_path_hides');a.setAttribute('type','text/css');if(a.styleSheet)a.styleSheet.cssText=b;else a.appendChild(d.createTextNode(b));h.appendChild(a);this.load('//dev.visualwebsiteoptimizer.com/j.php?a='+account_id+'&u='+encodeURIComponent(d.URL)+'&r='+Math.random());return settings_timer;}};}());_vwo_settings_timer=_vwo_code.init();
#   </script>
#
#
#   <script></script>
#   <link rel="stylesheet" href="https://img3.doubanio.com/misc/mixed_static/160f2171a4f48ba2.css">
#
#   </head>
#   <body>
#
#   <script>var _body_start = new Date();</script>
#
#
#
#
#
#     <link href="//img3.doubanio.com/dae/accounts/resources/6034966/shire/bundle.css" rel="stylesheet" type="text/css">
#
#
#
# <div id="db-global-nav" class="global-nav">
#   <div class="bd">
#
# <div class="top-nav-info">
#   <a href="https://www.douban.com/accounts/login?source=book" class="nav-login" rel="nofollow">登录</a>
#   <a href="https://www.douban.com/accounts/register?source=book" class="nav-register" rel="nofollow">注册</a>
# </div>
#
#
#
# <div class="top-nav-doubanapp">
#   <a href="https://www.douban.com/doubanapp/app?channel=top-nav" class="lnk-doubanapp">下载豆瓣客户端</a>
#   <div id="top-nav-appintro" class="more-items">
#     <p class="appintro-title">豆瓣</p>
#     <p class="slogan">我们的精神角落</p>
#     <p class="qrcode">扫码直接下载</p>
#     <div class="download">
#       <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=iOS">iPhone</a>
#       <span>·</span>
#       <a href="https://www.douban.com/doubanapp/redirect?channel=top-nav&direct_dl=1&download=Android" class="download-android">Android</a>
#     </div>
#     <div id="doubanapp-tip">
#       <a href="https://www.douban.com/doubanapp/app?channel=qipao" class="tip-link">豆瓣 5.0 全新发布</a>
#       <a href="javascript: void 0;" class="tip-close">×</a>
#     </div>
#   </div>
# </div>
#
#
#
#
# <div class="global-nav-items">
#   <ul>
#     <li class="">
#       <a href="https://www.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-main&quot;,&quot;uid&quot;:&quot;0&quot;}">豆瓣</a>
#     </li>
#     <li class="on">
#       <a href="https://book.douban.com"  data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-book&quot;,&quot;uid&quot;:&quot;0&quot;}">读书</a>
#     </li>
#     <li class="">
#       <a href="https://movie.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-movie&quot;,&quot;uid&quot;:&quot;0&quot;}">电影</a>
#     </li>
#     <li class="">
#       <a href="https://music.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-music&quot;,&quot;uid&quot;:&quot;0&quot;}">音乐</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/location" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-location&quot;,&quot;uid&quot;:&quot;0&quot;}">同城</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/group" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-group&quot;,&quot;uid&quot;:&quot;0&quot;}">小组</a>
#     </li>
#     <li class="">
#       <a href="https://read.douban.com&#47;?dcs=top-nav&amp;dcm=douban" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-read&quot;,&quot;uid&quot;:&quot;0&quot;}">阅读</a>
#     </li>
#     <li class="">
#       <a href="https://douban.fm&#47;?from_=shire_top_nav" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-fm&quot;,&quot;uid&quot;:&quot;0&quot;}">FM</a>
#     </li>
#     <li class="">
#       <a href="https://www.douban.com/time&#47;?dt_time_source=douban-web_top_nav" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-time&quot;,&quot;uid&quot;:&quot;0&quot;}">时间</a>
#     </li>
#     <li class="">
#       <a href="https://dongxi.douban.com&#47;?dcs=top-nav&amp;dcm=douban" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-commodity&quot;,&quot;uid&quot;:&quot;0&quot;}">东西</a>
#     </li>
#     <li class="">
#       <a href="https://market.douban.com&#47;?utm_campaign=douban_top_nav&amp;utm_source=douban&amp;utm_medium=pc_web" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-market&quot;,&quot;uid&quot;:&quot;0&quot;}">市集</a>
#     </li>
#     <li>
#       <a href="#more" class="bn-more"><span>更多</span></a>
#       <div class="more-items">
#         <table cellpadding="0" cellspacing="0">
#           <tbody>
#             <tr>
#               <td>
#                 <a href="https://ypy.douban.com" target="_blank" data-moreurl-dict="{&quot;from&quot;:&quot;top-nav-click-ypy&quot;,&quot;uid&quot;:&quot;0&quot;}">豆瓣摄影</a>
#               </td>
#             </tr>
#           </tbody>
#         </table>
#       </div>
#     </li>
#   </ul>
# </div>
#
#   </div>
# </div>
# <script>
#   ;window._GLOBAL_NAV = {
#     DOUBAN_URL: "https://www.douban.com",
#     N_NEW_NOTIS: 0,
#     N_NEW_DOUMAIL: 0
#   };
# </script>
#
#
#
#     <script src="//img3.doubanio.com/dae/accounts/resources/6034966/shire/bundle.js" defer="defer"></script>
#
#
#
#
#
#
#
#
#     <link href="//img3.doubanio.com/dae/accounts/resources/c936707/book/bundle.css" rel="stylesheet" type="text/css">
#
#
#
#
# <div id="db-nav-book" class="nav">
#   <div class="nav-wrap">
#   <div class="nav-primary">
#     <div class="nav-logo">
#       <a href="https:&#47;&#47;book.douban.com">豆瓣读书</a>
#     </div>
#     <div class="nav-search">
#       <form action="https:&#47;&#47;book.douban.com/subject_search" method="get">
#         <fieldset>
#           <legend>搜索：</legend>
#           <label for="inp-query">
#           </label>
#           <div class="inp"><input id="inp-query" name="search_text" size="22" maxlength="60" placeholder="书名、作者、ISBN" value=""></div>
#           <div class="inp-btn"><input type="submit" value="搜索"></div>
#           <input type="hidden" name="cat" value="1001" />
#         </fieldset>
#       </form>
#     </div>
#   </div>
#   </div>
#   <div class="nav-secondary">
#
#
# <div class="nav-items">
#   <ul>
#     <li    ><a href="https://book.douban.com/cart/"
#      >购书单</a>
#     </li>
#     <li    ><a href="https://read.douban.com/ebooks/?dcs=book-nav&dcm=douban"
#             target="_blank"
#      >电子图书</a>
#     </li>
#     <li    ><a href="https://market.douban.com/book?utm_campaign=book_nav_freyr&utm_source=douban&utm_medium=pc_web"
#      >纸书</a>
#     </li>
#     <li    ><a href="https://book.douban.com/annual2016/?source=navigation"
#             target="_blank"
#      >2016年度榜单</a>
#     </li>
#     <li    ><a href="https://book.douban.com/standbyme/2016?source=navigation"
#             target="_blank"
#      >2016读书报告</a>
#     </li>
#     <li          class=" book-cart"
#     ><a href="https://market.douban.com/cart/?utm_campaign=book_nav_cart&utm_source=douban&utm_medium=pc_web"
#             target="_blank"
#      >购物车</a>
#     </li>
#   </ul>
# </div>
#
#   </div>
# </div>
#
# <script id="suggResult" type="text/x-jquery-tmpl">
#   <li data-link="{{= url}}">
#             <a href="{{= url}}" onclick="moreurl(this, {from:'book_search_sugg', query:'{{= keyword }}', subject_id:'{{= id}}', i: '{{= index}}', type: '{{= type}}'})">
#             <img src="{{= pic}}" width="40" />
#             <div>
#                 <em>{{= title}}</em>
#                 {{if year}}
#                     <span>{{= year}}</span>
#                 {{/if}}
#                 <p>
#                 {{if type == "b"}}
#                     {{= author_name}}
#                 {{else type == "a" }}
#                     {{if en_name}}
#                         {{= en_name}}
#                     {{/if}}
#                 {{/if}}
#                  </p>
#             </div>
#         </a>
#         </li>
#   </script>
#
#
#
#
#     <script src="//img3.doubanio.com/dae/accounts/resources/c936707/book/bundle.js" defer="defer"></script>
#
#
#
#
#
#   <div id="wrapper">
#
#   <!-- douban ad begin -->
#   <div id="dale_book_home_top_super_banner" class="ad-placeholder" style="margin: -18px 0 18px;">
#   </div>
#   <!-- douban ad end -->
#
#
#   <div id="content">
#
#
#     <div class="grid-16-8 clearfix">
#
#       <div class="article">
#
#
#
#
#
#   <div class="section books-express ">
#     <div class="hd">
#
#   <h2 class=''>
#     <span class="">新书速递</span>
#       <span class="link-more">
#         <a class="" href="/latest?icn=index-latestbook-all"
#           >更多»</a>
#       </span>
#   </h2>
#
#       <div class="slide-controls">
#         <ol class="slide-dots">
#           <li><a data-index="1" href="#" class=""></a></li>
#           <li><a data-index="2" href="#" class=""></a></li>
#           <li><a data-index="3" href="#" class=""></a></li>
#           <li><a data-index="4" href="#" class=""></a></li>
#         </ol>
#         <div class="slide-btns">
#           <a href="#" class="prev">&#8249;</a>
#           <a href="#" class="next">&#8250;</a>
#         </div>
#       </div>
#     </div>
#     <div class="bd">
#       <div class="carousel">
#         <div class="slide-list">
#
#
#     <ul class="list-col list-col5 list-express slide-item">
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27102647/?icn=index-editionrecommend" title="穿过生命中的泥泞时刻">
#                 <img src="https://img1.doubanio.com/lpic/s29522127.jpg" class=""
#                   width="106px" height="158px" alt="穿过生命中的泥泞时刻">
#               </a>
#             </div>
#                 <div class="intervenor-info">
#                     <img src="https://img3.doubanio.com/f/book/ef040178fab1770d60e3f2f12ba4c7aa70714396/pics/book/partner/jd_recommend.png" class='jd-icon' width="16" height="16"/>
#                     <span>推荐</span>
#                 </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27102647/?icn=index-editionrecommend"
#                   title="穿过生命中的泥泞时刻">穿过生命中的泥泞时刻</a>
#               </div>
#               <div class="author">
#                 真实故事计划
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   穿过生命中的泥泞时刻
#                 </h4>
#                 <p>
#                   <span class="author">
#                     真实故事计划
#                   </span>
#                   /
#                   <span class="year">
#                     2017-8
#                   </span>
#                   /
#                   <span class="publisher">
#                     百花洲文艺出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   《穿过生命中的泥泞时刻》是国内首个真实故事平台，百万粉丝大号“真实故事计划”人气故事集第1季，精选30个从生命里拿出来的既具有人气、又感动人心的硬派故事，组合成一幅中国人的心灵地图，标记出我们这一代人的爱与怕。
# 每个人生命中都曾有过饱受艰难、深陷泥泞的时刻，穿越生命中的苦难，让人生从容而辽阔！看见人间真相，看从生命里拿出来的故事，火遍微信、知...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27068494/?icn=index-editionrecommend" title="手帖：南朝岁月">
#                 <img src="https://img3.doubanio.com/lpic/s29474453.jpg" class=""
#                   width="106px" height="158px" alt="手帖：南朝岁月">
#               </a>
#             </div>
#                 <div class="intervenor-info">
#                     <img src="https://img3.doubanio.com/f/book/ef040178fab1770d60e3f2f12ba4c7aa70714396/pics/book/partner/jd_recommend.png" class='jd-icon' width="16" height="16"/>
#                     <span>推荐</span>
#                 </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27068494/?icn=index-editionrecommend"
#                   title="手帖：南朝岁月">手帖：南朝岁月</a>
#               </div>
#               <div class="author">
#                 蒋勋
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   手帖：南朝岁月
#                 </h4>
#                 <p>
#                   <span class="author">
#                     蒋勋
#                   </span>
#                   /
#                   <span class="year">
#                     2017-6
#                   </span>
#                   /
#                   <span class="publisher">
#                     九州出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   这些“手帖”──文人间的书信便条，因为书法之美，流传下来，成为后世临摹写字的“帖”。然而，“帖”更是同时具有“私密”、“随性”却又极为贴近“真实”、“率性”的文体。暧昧迷离、若即若离，构成读“帖”时奇特的一种魅惑力量。
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27000191/?icn=index-editionrecommend" title="自下而上">
#                 <img src="https://img3.doubanio.com/lpic/s29516322.jpg" class=""
#                   width="106px" height="158px" alt="自下而上">
#               </a>
#             </div>
#                 <div class="intervenor-info">
#                     <img src="https://img3.doubanio.com/f/book/ef040178fab1770d60e3f2f12ba4c7aa70714396/pics/book/partner/jd_recommend.png" class='jd-icon' width="16" height="16"/>
#                     <span>推荐</span>
#                 </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27000191/?icn=index-editionrecommend"
#                   title="自下而上">自下而上</a>
#               </div>
#               <div class="author">
#                 [英] 马特·里德利
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   自下而上
#                 </h4>
#                 <p>
#                   <span class="author">
#                     [英] 马特·里德利
#                   </span>
#                   /
#                   <span class="year">
#                     2017-7
#                   </span>
#                   /
#                   <span class="publisher">
#                     机械工业出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   Matt Ridley的新作《自下而上》讲的是一种“自下而上”的模式。人类惯常依赖SKY HOOKS（天钩，一种不存在的思维挂钩的意思），比如打仗靠将军，国家靠领导人，经济自由派依赖亚当·斯密等等，这都是一种“自上而下”的模式。但实际上，现实世界恰恰存在着“自下而上”的模式，正是这种模式主导了技术革命和亚洲崛起等。写作上，作者结合科普、历史、社科、经济等各...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27093233/?icn=index-editionrecommend" title="历史的温度">
#                 <img src="https://img3.doubanio.com/lpic/s29522135.jpg" class=""
#                   width="106px" height="158px" alt="历史的温度">
#               </a>
#             </div>
#                 <div class="intervenor-info">
#                     <img src="https://img3.doubanio.com/f/book/ef040178fab1770d60e3f2f12ba4c7aa70714396/pics/book/partner/jd_recommend.png" class='jd-icon' width="16" height="16"/>
#                     <span>推荐</span>
#                 </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27093233/?icn=index-editionrecommend"
#                   title="历史的温度">历史的温度</a>
#               </div>
#               <div class="author">
#                 张玮
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   历史的温度
#                 </h4>
#                 <p>
#                   <span class="author">
#                     张玮
#                   </span>
#                   /
#                   <span class="year">
#                     2017-8-1
#                   </span>
#                   /
#                   <span class="publisher">
#                     中信出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   历史是万花筒，每个人看到的不同，每个角度看到的也不同。有的人看到了残酷，有的人看到了温情。有的人看到了杀戮，有的人看到了救赎。有的人看见了别人，有的人看见了自己。有的人假作真，有的人真作假。
# 史书上的一段话、一个名字，在张玮的笔下呈现出一张张意想不到的面孔。
# 张玮书写的历史，亦正亦暖。正，是因为，在“馒头说”的一个个历史故事中，张玮都尽量用一...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27100549/?icn=index-editionrecommend" title="不知归处">
#                 <img src="https://img3.doubanio.com/lpic/s29522132.jpg" class=""
#                   width="106px" height="158px" alt="不知归处">
#               </a>
#             </div>
#                 <div class="intervenor-info">
#                     <img src="https://img3.doubanio.com/f/book/ef040178fab1770d60e3f2f12ba4c7aa70714396/pics/book/partner/jd_recommend.png" class='jd-icon' width="16" height="16"/>
#                     <span>推荐</span>
#                 </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27100549/?icn=index-editionrecommend"
#                   title="不知归处">不知归处</a>
#               </div>
#               <div class="author">
#                 双囍是朵花儿
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   不知归处
#                 </h4>
#                 <p>
#                   <span class="author">
#                     双囍是朵花儿
#                   </span>
#                   /
#                   <span class="year">
#                     2017-7
#                   </span>
#                   /
#                   <span class="publisher">
#                     电子工业出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   文艺风格人像写真画册，致敬日本人像大师筱山纪信写真作品集。模特为百万粉丝网红&#34;卧蚕儿”。摄影师与模特强强联合，远赴云南拍摄，推出该力作。随书附赠写真拍摄指导小册子，在作品欣赏之余，还能学到双囍的一手拍摄技术，对于本书的创作过程也会有更加深入的理解。
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27081783/?icn=index-latestbook-subject" title="樱桃青衣">
#                 <img src="https://img3.doubanio.com/lpic/s29487651.jpg" class=""
#                   width="106px" height="158px" alt="樱桃青衣">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27081783/?icn=index-latestbook-subject"
#                   title="樱桃青衣">樱桃青衣</a>
#               </div>
#               <div class="author">
#                 张怡微
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   樱桃青衣
#                 </h4>
#                 <p>
#                   <span class="author">
#                     张怡微
#                   </span>
#                   /
#                   <span class="year">
#                     2017-7
#                   </span>
#                   /
#                   <span class="publisher">
#                     华东师范大学出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   樱桃青衣是听心里的时间说话，蕉叶覆鹿是创造的本质。
# 它确确实实生产了快乐，也确确实实是一场短梦。
#
# ===============================================
# 《樱桃青衣》为上海青年作家张怡微“家族试验”写作计划的收官之作，收入获得第36届时报文学奖短篇小说组首奖作品《哀眠》。关于现代人的伤痛和宽容、失落和满足、记忆与遗忘。各自陪父母前来相亲的年轻男...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27062550/?icn=index-latestbook-subject" title="悠游小说林">
#                 <img src="https://img3.doubanio.com/lpic/s29499406.jpg" class=""
#                   width="106px" height="158px" alt="悠游小说林">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27062550/?icn=index-latestbook-subject"
#                   title="悠游小说林">悠游小说林</a>
#               </div>
#               <div class="author">
#                 [意] 安贝托·艾柯
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   悠游小说林
#                 </h4>
#                 <p>
#                   <span class="author">
#                     [意] 安贝托·艾柯
#                   </span>
#                   /
#                   <span class="year">
#                     2017-8
#                   </span>
#                   /
#                   <span class="publisher">
#                     广西师范大学出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   作品看点：
# ★ 如果你是一个小说爱好者，你该庆幸看到这本书；如果你以为虚构的世界与你无关，这本书会改变你的想法——六堂哈佛文学课，跟艾柯读懂小说。
# ★ 怎样做一个理想读者？如何正确地打开一本书？——影响几代学人，关于阅读与写作的经典指南。艾柯将文学理论变成一种知识的愉悦：阅读理解并非只是实用技能，更成为一种心智的练习。
# ★ 探究虚构世界与现实人生的...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27077752/?icn=index-latestbook-subject" title="温柔之歌">
#                 <img src="https://img3.doubanio.com/lpic/s29514221.jpg" class=""
#                   width="106px" height="158px" alt="温柔之歌">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27077752/?icn=index-latestbook-subject"
#                   title="温柔之歌">温柔之歌</a>
#               </div>
#               <div class="author">
#                 [法] 蕾拉·斯利玛尼
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   温柔之歌
#                 </h4>
#                 <p>
#                   <span class="author">
#                     [法] 蕾拉·斯利玛尼
#                   </span>
#                   /
#                   <span class="year">
#                     2017-8-1
#                   </span>
#                   /
#                   <span class="publisher">
#                     浙江文艺出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   张悦然、笛安、阿乙 倾情推荐！
# 80后天才女作家——蕾拉·斯利玛尼
# 法国最高文学奖项——2016龚古尔文学奖获奖作品
# 一个仙女般的保姆，为什么杀死她照看的两个孩子？凶杀案背后揭示了怎样的社会现实和女性生存困境？
# 蕾莱拉•斯利马尼违背了侦探小说的一般规律，她从结局起笔：“ 婴儿已经死了”，在无法忍受的案发现场，母亲发出的“母狼般的喊叫”。
# 米莉亚姆生育两个孩...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27087503/?icn=index-latestbook-subject" title="深度学习">
#                 <img src="https://img1.doubanio.com/lpic/s29518349.jpg" class=""
#                   width="106px" height="158px" alt="深度学习">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27087503/?icn=index-latestbook-subject"
#                   title="深度学习">深度学习</a>
#               </div>
#               <div class="author">
#                 [美] 伊恩·古德费洛&nbsp;/&nbsp;[加] 约书亚·本吉奥&nbsp;/&nbsp;[加] 亚伦·库维尔
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   深度学习
#                 </h4>
#                 <p>
#                   <span class="author">
#                     [美] 伊恩·古德费洛&nbsp;/&nbsp;[加] 约书亚·本吉奥&nbsp;/&nbsp;[加] 亚伦·库维尔
#                   </span>
#                   /
#                   <span class="year">
#                     2017-7-1
#                   </span>
#                   /
#                   <span class="publisher">
#                     人民邮电出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   《深度学习》由全球知名的三位专家Ian Goodfellow、Yoshua Bengio 和Aaron Courville撰写，是深度学习领域奠基性的经典教材。全书的内容包括3个部分：第1部分介绍基本的数学工具和机器学习的概念，它们是深度学习的预备知识；第2部分系统深入地讲解现今已成熟的深度学习方法和技术；第3部分讨论某些具有前瞻性的方向和想法，它们被公认为是深度学习未来的研究重点。
# ...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27069576/?icn=index-latestbook-subject" title="幻想曲">
#                 <img src="https://img1.doubanio.com/lpic/s29475567.jpg" class=""
#                   width="106px" height="158px" alt="幻想曲">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27069576/?icn=index-latestbook-subject"
#                   title="幻想曲">幻想曲</a>
#               </div>
#               <div class="author">
#                 Golo
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   幻想曲
#                 </h4>
#                 <p>
#                   <span class="author">
#                     Golo
#                   </span>
#                   /
#                   <span class="year">
#                     2017-7
#                   </span>
#                   /
#                   <span class="publisher">
#                     北京联合出版公司
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   著名漫画家Golo的奇异幻想
# 一段邂逅，一次错过的美好回忆
# 神秘的外星女孩、时空游戏与世界末日、不可见的传染病、午夜咖啡厅的奇遇……这一切是现实还是幻想？
# ………………
# ※编辑推荐※
# ☆ 著名漫画家Golo游历法国时的幻想之作
# 在他的笔下，平凡的生活细节也会因无限的想象力而变得惊险奇异、光怪陆离。
# ☆ 幻想与现实的更替，时间和空间的交错，神秘而独特的想象盛宴
# 一次...
#                 </p>
#               </div>
#             </div>
#           </li>
#     </ul>
#     <ul class="list-col list-col5 list-express slide-item">
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27078238/?icn=index-latestbook-subject" title="写作课">
#                 <img src="https://img3.doubanio.com/lpic/s29520306.jpg" class=""
#                   width="106px" height="158px" alt="写作课">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27078238/?icn=index-latestbook-subject"
#                   title="写作课">写作课</a>
#               </div>
#               <div class="author">
#                 [美] 艾丽斯·马蒂森
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   写作课
#                 </h4>
#                 <p>
#                   <span class="author">
#                     [美] 艾丽斯·马蒂森
#                   </span>
#                   /
#                   <span class="year">
#                     2017-8
#                   </span>
#                   /
#                   <span class="publisher">
#                     北京联合出版公司
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   ※英语界小小说最高荣誉“小推车奖”得主、 《纽约客》 《纽约时报》撰稿人带你上一堂既有料、又有趣的写作课，以22年写作课导师经验告诉你：关于写作这件事，何为好，为何写不好，如何能写好。
# ※在全民写作时代，每一个渴望写出好故事的人，都需要一个好“老师”。本书作者马蒂森拥有作家与写作课教师的双重身份，了解写作者最迫切的需要，书中所有指导性建议都来对...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27086857/?icn=index-latestbook-subject" title="妈妈离婚记">
#                 <img src="https://img3.doubanio.com/lpic/s29515254.jpg" class=""
#                   width="106px" height="158px" alt="妈妈离婚记">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27086857/?icn=index-latestbook-subject"
#                   title="妈妈离婚记">妈妈离婚记</a>
#               </div>
#               <div class="author">
#                 毛冷瞪
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   妈妈离婚记
#                 </h4>
#                 <p>
#                   <span class="author">
#                     毛冷瞪
#                   </span>
#                   /
#                   <span class="year">
#                     2017-7
#                   </span>
#                   /
#                   <span class="publisher">
#                     鹭江出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   ★豆瓣连载第一期，超60000+阅读量！
# ★根据小说改编的电影、电视剧正在筹备中。
# ★语言诙谐幽默，令你笑得停不下来！
# ★豆瓣人气作者毛冷瞪首次出版作品。
# ★这是一本幽默、可爱，又顽皮的都市情感小说，这是一本追寻两代人婚恋家庭幸福的小说。
# ★年龄只是个数字，而爱情才是一生的追寻。
# 一天，小五的母亲卢月突然向丈夫徐建国提出离婚，离婚原因竟是想为自己做件事。...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27092579/?icn=index-latestbook-subject" title="孤独的城市">
#                 <img src="https://img1.doubanio.com/lpic/s29510649.jpg" class=""
#                   width="106px" height="158px" alt="孤独的城市">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27092579/?icn=index-latestbook-subject"
#                   title="孤独的城市">孤独的城市</a>
#               </div>
#               <div class="author">
#                 [英] 奥利维娅·莱恩
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   孤独的城市
#                 </h4>
#                 <p>
#                   <span class="author">
#                     [英] 奥利维娅·莱恩
#                   </span>
#                   /
#                   <span class="year">
#                     2017-8
#                   </span>
#                   /
#                   <span class="publisher">
#                     北京联合出版公司
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   孤独意味着什么？
# 倘若我们不与另一个人紧密缠绕，我们该如何生活？
# 要是我们无法轻松地开口交谈，我们该如何与他人发生联系？
# 科技让我们更靠近彼此，还是将我们禁锢在屏幕背后 的牢笼里？
# -
# 逃不出的北上广，丢不掉的孤独感。
# 身处现代城市的人群中，却无法与他人发生联系
# 仿佛置身于一座孤岛，发出没人理解的呐喊。
# -
# 孤独不是光环，却也不是污点。
# 正视孤独，为饱经折磨的灵...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27107455/?icn=index-latestbook-subject" title="与情敌同居">
#                 <img src="https://img3.doubanio.com/lpic/s29511300.jpg" class=""
#                   width="106px" height="158px" alt="与情敌同居">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27107455/?icn=index-latestbook-subject"
#                   title="与情敌同居">与情敌同居</a>
#               </div>
#               <div class="author">
#                 方悄悄
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   与情敌同居
#                 </h4>
#                 <p>
#                   <span class="author">
#                     方悄悄
#                   </span>
#                   /
#                   <span class="year">
#                     2017-8-25
#                   </span>
#                   /
#                   <span class="publisher">
#                     中信出版集团
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   如果有一天，你必须跟你的情敌住在同一个屋檐下……看起来是一个爆炸新闻般的开头，却是温情治愈的爱情故事集。本书包括《与情敌同居》《蓝衬衫的女孩》《谁人是你一生中最爱》《我妻子的双重生活》《30、50、70》5个中篇故事。每一个故事都是一部正待被改编的影视剧。
# 《与情敌同居》讲述了刚毕业的郑华娟与男友何洋分手，却被迫与他爱慕的对象（“情敌”）周映晓...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27073266/?icn=index-latestbook-subject" title="知日：这就是三岛由纪夫">
#                 <img src="https://img3.doubanio.com/lpic/s29512710.jpg" class=""
#                   width="106px" height="158px" alt="知日：这就是三岛由纪夫">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27073266/?icn=index-latestbook-subject"
#                   title="知日：这就是三岛由纪夫">知日：这就是三岛由纪夫</a>
#               </div>
#               <div class="author">
#                 茶乌龙
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   知日：这就是三岛由纪夫
#                 </h4>
#                 <p>
#                   <span class="author">
#                     茶乌龙
#                   </span>
#                   /
#                   <span class="year">
#                     2017-8
#                   </span>
#                   /
#                   <span class="publisher">
#                     中信出版集团
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   专门关注日系内容的超人气品牌「知日 ZHIJAPAN」推出《知日》特集第45弹 《知日·这就是三岛由纪夫》特集！
# “你在放荡的孤独中闪光。”——三岛由纪夫
# ＊三岛由纪夫人生轨迹与人物关系，三岛爱慕的四大名伶，带你了解三岛的传奇人生；
# ＊三岛由纪夫珍贵手稿，土门拳、筱山纪信镜头下的三岛由纪夫，与川端康成的书信往来，为你展现最真实的三岛由纪夫；
# ＊从《金阁寺》...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27104286/?icn=index-latestbook-subject" title="寂寞的游戏">
#                 <img src="https://img3.doubanio.com/lpic/s29508790.jpg" class=""
#                   width="106px" height="158px" alt="寂寞的游戏">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27104286/?icn=index-latestbook-subject"
#                   title="寂寞的游戏">寂寞的游戏</a>
#               </div>
#               <div class="author">
#                 袁哲生
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   寂寞的游戏
#                 </h4>
#                 <p>
#                   <span class="author">
#                     袁哲生
#                   </span>
#                   /
#                   <span class="year">
#                     2017-9
#                   </span>
#                   /
#                   <span class="publisher">
#                     后浪丨北京联合出版公司
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   被张大春誉为撑起21世纪小说江山的两位作家之一
# 台湾吴浊流文学奖、联合报文学奖、时报文学奖得主
# 用纯真的双眼捕捉孤独的角落
# ………………
# ※编辑推荐※
# ☆ 袁哲生以冷静节制的短篇小说风格和骆以军并列为台湾1960年代最优秀的小说家，也是被张大春誉为“撑起21世纪小说江山 ”的两位作家之一，还影响童伟格、甘耀明、高翊峰、王聪威等一批台湾年轻作者，如果，袁哲生...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27077700/?icn=index-latestbook-subject" title="在故宫寻找苏东坡">
#                 <img src="https://img3.doubanio.com/lpic/s29483431.jpg" class=""
#                   width="106px" height="158px" alt="在故宫寻找苏东坡">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27077700/?icn=index-latestbook-subject"
#                   title="在故宫寻找苏东坡">在故宫寻找苏东坡</a>
#               </div>
#               <div class="author">
#                 祝勇
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   在故宫寻找苏东坡
#                 </h4>
#                 <p>
#                   <span class="author">
#                     祝勇
#                   </span>
#                   /
#                   <span class="year">
#                     2017-7
#                   </span>
#                   /
#                   <span class="publisher">
#                     湖南美术出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   继《故宫的风花雪月》《故宫的隐秘角落》后，祝勇2017 历史散文新作。
# 在故宫藏品中， 寻找苏东坡的生命印迹。
# 展阅宋元明书画，试图理解苏东坡与他的时代。
# 故宫授权高清详图，呈现苏东坡书法与绘画之美
# ◎本书从十个侧面——入仕、求生、书法、绘画、文学、交友、文人集团、家庭、为政、岭南， 书写了苏东坡一生的生命经历。在作者笔下，苏东坡是属于人间的。他是石，...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/26720634/?icn=index-latestbook-subject" title="安德鲁的大脑">
#                 <img src="https://img3.doubanio.com/lpic/s29484751.jpg" class=""
#                   width="106px" height="158px" alt="安德鲁的大脑">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/26720634/?icn=index-latestbook-subject"
#                   title="安德鲁的大脑">安德鲁的大脑</a>
#               </div>
#               <div class="author">
#                 [美] E.L.多克托罗
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   安德鲁的大脑
#                 </h4>
#                 <p>
#                   <span class="author">
#                     [美] E.L.多克托罗
#                   </span>
#                   /
#                   <span class="year">
#                     2017-7
#                   </span>
#                   /
#                   <span class="publisher">
#                     上海文艺出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   E.L.多克托罗最后一本极富实验性的小说。 安德鲁在叙述中流露出对大脑（认知） 、对自我的怀疑和绝望，无法信任自己的理智。他 甚至开始用第三人称观察自己，对自我意识是否真的存在提出了荒诞的质问。而对美国 社会的黑色讽刺也贯穿全文：安德鲁是否与那个最糟糕的美国总统是大学同学、而纨绔 子弟的总统是否在白宫策划一场针对人类集体大脑的阴谋，都需要读者在迷宫般...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27074630/?icn=index-latestbook-subject" title="大地蓝得像一只橙子">
#                 <img src="https://img1.doubanio.com/lpic/s29480639.jpg" class=""
#                   width="106px" height="158px" alt="大地蓝得像一只橙子">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27074630/?icn=index-latestbook-subject"
#                   title="大地蓝得像一只橙子">大地蓝得像一只橙子</a>
#               </div>
#               <div class="author">
#                 [法] 保罗·艾吕雅
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   大地蓝得像一只橙子
#                 </h4>
#                 <p>
#                   <span class="author">
#                     [法] 保罗·艾吕雅
#                   </span>
#                   /
#                   <span class="year">
#                     2017-7
#                   </span>
#                   /
#                   <span class="publisher">
#                     朗朗书房出版公司·南海出版公司
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   选译自校勘精良的1968年七星文库版《艾吕雅全集》两卷本，从1913年发表的第一部诗集直到1951年发表的最后一部诗集，涵盖了诗人一生中发表的大部分诗集，最后还收入诗人未入集的零散诗篇，整体上构成了对艾吕雅诗歌比较全面的了解。
# 艾吕雅的诗歌围绕着爱的真实，孤独，爱的狂热和消逝。透过他一生爱过的四位女性，他不断地歌唱爱的喜悦。他热爱抒情，热爱语词，对他...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27064883/?icn=index-latestbook-subject" title="日蚀">
#                 <img src="https://img3.doubanio.com/lpic/s29520445.jpg" class=""
#                   width="106px" height="158px" alt="日蚀">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27064883/?icn=index-latestbook-subject"
#                   title="日蚀">日蚀</a>
#               </div>
#               <div class="author">
#                 [日] 平野启一郎
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   日蚀
#                 </h4>
#                 <p>
#                   <span class="author">
#                     [日] 平野启一郎
#                   </span>
#                   /
#                   <span class="year">
#                     2017-8-1
#                   </span>
#                   /
#                   <span class="publisher">
#                     浙江文艺出版社
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   作者23岁凭借该作品惊艳日本文坛，获得第120届日本芥川奖，被誉为“三岛由纪夫转世”。
# 以魔幻的笔触重回中世纪末期的神权欧洲，体悟文艺复兴时代初期的奇幻世界和信仰困顿。
# 在欧洲中世纪末与文艺复兴初的过渡时期，巴黎大学的神学生尼古拉，为了寻求一本神学异端书籍，踏上了去佛罗伦萨的旅途。在路途中的村落他遇见了熟悉异端邪说的炼金术士皮埃尔，同时还发现了被...
#                 </p>
#               </div>
#             </div>
#           </li>
#     </ul>
#     <ul class="list-col list-col5 list-express slide-item">
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/26901113/?icn=index-latestbook-subject" title="教养身体的政治">
#                 <img src="https://img3.doubanio.com/lpic/s29511122.jpg" class=""
#                   width="106px" height="158px" alt="教养身体的政治">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/26901113/?icn=index-latestbook-subject"
#                   title="教养身体的政治">教养身体的政治</a>
#               </div>
#               <div class="author">
#                 [日] 深町英夫
#               </div>
#               <div class="more-meta">
#                 <h4 class="title">
#                   教养身体的政治
#                 </h4>
#                 <p>
#                   <span class="author">
#                     [日] 深町英夫
#                   </span>
#                   /
#                   <span class="year">
#                     2017-7
#                   </span>
#                   /
#                   <span class="publisher">
#                     生活·读书·新知三联书店
#                   </span>
#                 </p>
#                 <p class="abstract">
#
#                   本书是日本学者深町英夫撰写的关于中国国民党新生活运动的专书。对国民精神的改造，需从生活形态的重塑开始。于是，在主政者的倡导下，在全国上下展开了声势浩大的对于诸如卫生习惯、吃喝拉撒以及儿童养育方法等国民生活领域的“切身”改造。在国家面临深刻的内忧外患之际，国民党政权何故发动并持续了这种略带肤浅、琐碎之嫌的启蒙运动？国民党政权何故且如何企图介...
#                 </p>
#               </div>
#             </div>
#           </li>
#
#
#           <li class="">
#             <div class="cover">
#               <a href="https://book.douban.com/subject/27071333/?icn=index-latestbook-subject" title="法国中尉的女人">
#                 <img src="https://img1.doubanio.com/lpic/s29482939.jpg" class=""
#                   width="106px" height="158px" alt="法国中尉的女人">
#               </a>
#             </div>
#             <div class="info">
#               <div class="title">
#                 <a class="" href="https://book.douban.com/subject/27071333/?icn=index-latestbook-subject"
# ...
#                         <div class="author">东野圭吾</div>
#                     </div>
#                     <a href="https://book.douban.com/link2/?pre=0&amp;vendor=dangdang&amp;srcpage=bestseller&amp;price=2730&amp;pos=6&amp;url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s10554308%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D22935553&amp;srcsubj=&amp;type=bkbuy&amp;subject=10554308" target="_blank"><span class="buy-button">去购买</span></a>
#                 </li>
#
#                 <li class="item">
#                     <span class="rank-num">7.</span>
#                     <div class="book-info">
#                         <a href="https://book.douban.com/subject/1770782/" class="name" target="_blank">追风筝的人</a>
#                         <div class="author">[美] 卡勒德·胡赛尼</div>
#                     </div>
#                     <a href="https://book.douban.com/link2/?pre=0&amp;vendor=dangdang&amp;srcpage=bestseller&amp;price=1450&amp;pos=7&amp;url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s1770782%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23274638&amp;srcsubj=&amp;type=bkbuy&amp;subject=1770782" target="_blank"><span class="buy-button">去购买</span></a>
#                 </li>
#
#                 <li class="item">
#                     <span class="rank-num">8.</span>
#                     <div class="book-info">
#                         <a href="https://book.douban.com/subject/25960141/" class="name" target="_blank">地图（人文版）</a>
#                         <div class="author">(波兰)亚历山德拉·米热林斯卡/丹尼尔·米热林斯基 著</div>
#                     </div>
#                     <a href="https://book.douban.com/link2/?pre=0&amp;vendor=dangdang&amp;srcpage=bestseller&amp;price=7259&amp;pos=8&amp;url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s25960141%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23523508&amp;srcsubj=&amp;type=bkbuy&amp;subject=25960141" target="_blank"><span class="buy-button">去购买</span></a>
#                 </li>
#
#                 <li class="item">
#                     <span class="rank-num">9.</span>
#                     <div class="book-info">
#                         <a href="https://book.douban.com/subject/26356948/" class="name" target="_blank">摆渡人</a>
#                         <div class="author">[英]克莱儿·麦克福尔</div>
#                     </div>
#                     <a href="https://book.douban.com/link2/?pre=0&amp;vendor=dangdang&amp;srcpage=bestseller&amp;price=1639&amp;pos=9&amp;url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s26356948%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D23694647&amp;srcsubj=&amp;type=bkbuy&amp;subject=26356948" target="_blank"><span class="buy-button">去购买</span></a>
#                 </li>
#
#                 <li class="item">
#                     <span class="rank-num">10.</span>
#                     <div class="book-info">
#                         <a href="https://book.douban.com/subject/11637889/" class="name" target="_blank">一本书读完最美古诗词（上.下）</a>
#                         <div class="author"></div>
#                     </div>
#                     <a href="https://book.douban.com/link2/?pre=0&amp;vendor=dangdang&amp;srcpage=bestseller&amp;price=2390&amp;pos=10&amp;url=http%3A%2F%2Funion.dangdang.com%2Ftransfer.php%3Ffrom%3DP-306226-0-s11637889%26backurl%3Dhttp%3A%2F%2Fproduct.dangdang.com%2Fproduct.aspx%3Fproduct_id%3D22864933&amp;srcsubj=&amp;type=bkbuy&amp;subject=11637889" target="_blank"><span class="buy-button">去购买</span></a>
#                 </li>
#             </ul>
#     </div>
# </div>
#
#
#
#
#
#
#   <div class="block5">
#
#
#   <h2 class=''>
#     <span class="">豆瓣图书250</span>
#       <span class="link-more">
#         <a class="" href="/top250?icn=index-book250-all"
#           >更多»</a>
#       </span>
#   </h2>
#
#
#     <div class="content clearfix s" id="book_rec"
#       data-dstat-areaid="58"
#       data-dstat-mode="click,expose">
#
#
#     <dl>
#       <dt>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/26340138/?icn=index-book250-subject">
#           <img src="https://img3.doubanio.com/spic/s28049685.jpg" class="m_sub_img">
#         </a>
#       </dt>
#       <dd>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/26340138/?icn=index-book250-subject">
#           岛上书店
#         </a>
#         <p class="extra-info">
#
#
#   <span class="meta-label">
#     有电子书
#   </span>
#
#         </p>
#       </dd>
#     </dl>
#
#     <dl>
#       <dt>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/2382705/?icn=index-book250-subject">
#           <img src="https://img3.doubanio.com/spic/s2868780.jpg" class="m_sub_img">
#         </a>
#       </dt>
#       <dd>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/2382705/?icn=index-book250-subject">
#           不朽
#         </a>
#         <p class="extra-info">
#
#
#         </p>
#       </dd>
#     </dl>
#
#     <dl>
#       <dt>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/2298149/?icn=index-book250-subject">
#           <img src="https://img3.doubanio.com/spic/s27274091.jpg" class="m_sub_img">
#         </a>
#       </dt>
#       <dd>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/2298149/?icn=index-book250-subject">
#           盗墓笔记3
#         </a>
#         <p class="extra-info">
#
#
#         </p>
#       </dd>
#     </dl>
#       <div class="clearfix rr" style="width:100%"></div>
#
#     <dl>
#       <dt>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/3066477/?icn=index-book250-subject">
#           <img src="https://img3.doubanio.com/spic/s3078482.jpg" class="m_sub_img">
#         </a>
#       </dt>
#       <dd>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/3066477/?icn=index-book250-subject">
#           三体Ⅱ
#         </a>
#         <p class="extra-info">
#
#
#   <span class="meta-label">
#     有电子书
#   </span>
#
#         </p>
#       </dd>
#     </dl>
#
#     <dl>
#       <dt>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/4913064/?icn=index-book250-subject">
#           <img src="https://img3.doubanio.com/spic/s27279654.jpg" class="m_sub_img">
#         </a>
#       </dt>
#       <dd>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/4913064/?icn=index-book250-subject">
#           活着
#         </a>
#         <p class="extra-info">
#
#
#   <span class="meta-label">
#     有电子书
#   </span>
#
#         </p>
#       </dd>
#     </dl>
#
#     <dl>
#       <dt>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/5414391/?icn=index-book250-subject">
#           <img src="https://img1.doubanio.com/spic/s4575849.jpg" class="m_sub_img">
#         </a>
#       </dt>
#       <dd>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/5414391/?icn=index-book250-subject">
#           寻路中国
#         </a>
#         <p class="extra-info">
#
#
#   <span class="meta-label">
#     有电子书
#   </span>
#
#         </p>
#       </dd>
#     </dl>
#       <div class="clearfix rr" style="width:100%"></div>
#
#     <dl>
#       <dt>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/2159042/?icn=index-book250-subject">
#           <img src="https://img1.doubanio.com/spic/s27312538.jpg" class="m_sub_img">
#         </a>
#       </dt>
#       <dd>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/2159042/?icn=index-book250-subject">
#           挪威的森林
#         </a>
#         <p class="extra-info">
#
#
#         </p>
#       </dd>
#     </dl>
#
#     <dl>
#       <dt>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/1863930/?icn=index-book250-subject">
#           <img src="https://img3.doubanio.com/spic/s1804710.jpg" class="m_sub_img">
#         </a>
#       </dt>
#       <dd>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/1863930/?icn=index-book250-subject">
#           看不见的城市
#         </a>
#         <p class="extra-info">
#
#
#         </p>
#       </dd>
#     </dl>
#
#     <dl>
#       <dt>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/1039752/?icn=index-book250-subject">
#           <img src="https://img1.doubanio.com/spic/s1029019.jpg" class="m_sub_img">
#         </a>
#       </dt>
#       <dd>
#         <a onclick="moreurl(this, {from:'top'})" href="https://book.douban.com/subject/1039752/?icn=index-book250-subject">
#           且听风吟
#         </a>
#         <p class="extra-info">
#
#
#         </p>
#       </dd>
#     </dl>
#       <div class="clearfix rr" style="width:100%"></div>
#
#     </div>
#   </div>
#
#
#   <div class="contact">
#     <h2>联系我们</h2>
#     <ul class="apply-links">
#       <li>
#         合作联系：<img src="https://img3.doubanio.com/f/book/6a8e1160fbccbaa8c13ddf72e22145056bda0ba4/pics/book/email_book.png" />
#       </li>
#     </ul>
#   </div>
#
#
#   <div class="contact mod">
#       <h2>关注我们</h2>
#       <ul class="embassy-list clearfix">
#           <li>
#               <a href="https://site.douban.com/book/" target="_blank" class="icon-embassy-site"></a>
#               <a href="https://site.douban.com/book/" target="_blank" class="primary-link">豆瓣小站</a>
#           </li>
#           <li>
#               <a href="http://weibo.com/doubandushu" target="_blank" class="icon-embassy-weibo"></a>
#               <a href="http://weibo.com/doubandushu" target="_blank" class="primary-link">微博</a>
#           </li>
#           <li>
#               <a class="icon-embassy-weixin">
#                   <div class="hover"><img class="home-qrcode" src="https://img3.doubanio.com/f/book/ee2d0bf8adc46ee0e1a53c28abf41a7a3b589e54/pics/book/home_qrcode@2x.jpg"></div>
#               </a>
#               <a class="primary-link" href="javascript:;">微信</a>
#           </li>
#       </ul>
#   </div>
#   <!-- douban app begin -->
#   <div class="s" data-dstat-areaid="60" data-dstat-mode="click,expose">
#     <!-- douban ad begin -->
#     <div id="dale_book_home_inner_middle"></div>
#     <div id="dale_book_home_download_middle"></div>
#     <!-- douban ad end -->
#   </div>
#   <!-- douban app end -->
#
#   <!-- douban ad begin -->
#   <div id="dale_book_home_bottem_right" class="ad-placeholder"></div>
#   <!-- douban ad end -->
#
#       </div>
#       <div class="extra">
#
#       </div>
#     </div>
#   </div>
#
#
#   <div id="footer">
#
# <span id="icp" class="fleft gray-link">
#     &copy; 2005－2017 douban.com, all rights reserved 北京豆网科技有限公司
# </span>
#
# <a href="https://www.douban.com/hnypt/variformcyst.py" style="display: none;"></a>
#
# <span class="fright">
#     <a href="https://www.douban.com/about">关于豆瓣</a>
#     · <a href="https://www.douban.com/jobs">在豆瓣工作</a>
#     · <a href="https://www.douban.com/about?topic=contactus">联系我们</a>
#     · <a href="https://www.douban.com/about?policy=disclaimer">免责声明</a>
#
#     · <a href="https://help.douban.com/?app=book" target="_blank">帮助中心</a>
#     · <a href="https://book.douban.com/library_invitation">图书馆合作</a>
#     · <a href="https://www.douban.com/doubanapp/">移动应用</a>
#     · <a href="https://www.douban.com/partner/">豆瓣广告</a>
# </span>
#
#     <script src="https://img3.doubanio.com/f/book/7495d157b1564be6aae1d21c79280b5ea374400a/js/book/lib/do/init.js"
#       data-cfg-corelib="https://img3.doubanio.com/f/book/0495cb173e298c28593766009c7b0a953246c5b5/js/book/lib/jquery/jquery.js">
#     </script>
#   </div>
#
#   </div>
#   <script type="text/javascript" src="https://img3.doubanio.com/misc/mixed_static/33734cec318e690e.js"></script>
#   <!-- mako -->
#
#   <!-- douban ad begin -->
#
#
#
#
#
#
#
# <script type="text/javascript">
#     (function (global) {
#         var newNode = global.document.createElement('script'),
#             existingNode = global.document.getElementsByTagName('script')[0],
#             adSource = '//erebor.douban.com/',
#             userId = '',
#             browserId = 'rO95n3KqU70',
#             criteria = '3:/',
#             preview = '',
#             debug = false,
#             adSlots = ['dale_book_home_top_right', 'dale_book_home_top_right2', 'dale_book_home_left_middle', 'dale_book_home_bottem_right', 'dale_book_home_top_super_banner', 'dale_book_home_left_top', 'dale_book_homepage_right_bottom', 'dale_book_home_inner_middle', 'dale_book_home_download_middle'];
#
#         global.DoubanAdRequest = {src: adSource, uid: userId, bid: browserId, crtr: criteria, prv: preview, debug: debug};
#         global.DoubanAdSlots = (global.DoubanAdSlots || []).concat(adSlots);
#
#         newNode.setAttribute('type', 'text/javascript');
#         newNode.setAttribute('src', 'https://img3.doubanio.com/f/shire/a01a8a95c80c60b76f4d29cd788399ff7ac5e00e/js/ad.js');
#         newNode.setAttribute('async', true);
#         existingNode.parentNode.insertBefore(newNode, existingNode);
#     })(this);
# </script>
#
#
#
#
#
#
#
#
#
#
#   <!-- douban ad end -->
#   <script>
#     Do(function() {
#       $('.click-track').on('click', function(e) {
#         e.preventDefault()
#         var name = $(this).data('name')
#         moreurl(this, { from: name })
#       })
#     })
#   </script>
#
#
#
#
#
# <script type="text/javascript">
#   var _paq = _paq || [];
#   _paq.push(['trackPageView']);
#   _paq.push(['enableLinkTracking']);
#   (function() {
#     var p=(('https:' == document.location.protocol) ? 'https' : 'http'), u=p+'://fundin.douban.com/';
#     _paq.push(['setTrackerUrl', u+'piwik']);
#     _paq.push(['setSiteId', '100001']);
#     var d=document, g=d.createElement('script'), s=d.getElementsByTagName('script')[0];
#     g.type='text/javascript';
#     g.defer=true;
#     g.async=true;
#     g.src=p+'://s.doubanio.com/dae/fundin/piwik.js';
#     s.parentNode.insertBefore(g,s);
#   })();
# </script>
#
# <script type="text/javascript">
# var setMethodWithNs = function(namespace) {
#   var ns = namespace ? namespace + '.' : ''
#     , fn = function(string) {
#         if(!ns) {return string}
#         return ns + string
#       }
#   return fn
# }
#
# var gaWithNamespace = function(fn, namespace) {
#   var method = setMethodWithNs(namespace)
#   fn.call(this, method)
# }
#
# var _gaq = _gaq || []
#   , accounts = [
#       { id: 'UA-7019765-1', namespace: 'douban' }
#     , { id: 'UA-7019765-16', namespace: '' }
#     ]
#   , gaInit = function(account) {
#       gaWithNamespace(function(method) {
#         gaInitFn.call(this, method, account)
#       }, account.namespace)
#     }
#   , gaInitFn = function(method, account) {
#       _gaq.push([method('_setAccount'), account.id])
#
#
#   _gaq.push([method('_addOrganic'), 'google', 'q'])
#   _gaq.push([method('_addOrganic'), 'baidu', 'wd'])
#   _gaq.push([method('_addOrganic'), 'soso', 'w'])
#   _gaq.push([method('_addOrganic'), 'youdao', 'q'])
#   _gaq.push([method('_addOrganic'), 'so.360.cn', 'q'])
#   _gaq.push([method('_addOrganic'), 'sogou', 'query'])
#   if (account.namespace) {
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣'])
#     _gaq.push([method('_addIgnoredOrganic'), 'douban'])
#     _gaq.push([method('_addIgnoredOrganic'), '豆瓣网'])
#     _gaq.push([method('_addIgnoredOrganic'), 'www.douban.com'])
#   }
#
#       if (account.namespace === 'douban') {
#         _gaq.push([method('_setDomainName'), '.douban.com'])
#       }
#
#         _gaq.push([method('_setCustomVar'), 1, 'responsive_view_mode', 'desktop', 3])
#
#         _gaq.push([method('_setCustomVar'), 2, 'login_status', '0', 2]);
#
#       _gaq.push([method('_trackPageview')])
#     }
#
# for(var i = 0, l = accounts.length; i < l; i++) {
#   var account = accounts[i]
#   gaInit(account)
# }
#
#
# ;(function() {
#     var ga = document.createElement('script');
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     ga.setAttribute('async', 'true');
#     document.documentElement.firstChild.appendChild(ga);
# })()
# </script>
#
#
#
#
#
#
#
#
#
#   <!-- dis15-docker-->
#
#   </body>
# </html>

# %%
import requests
import re
content = requests.get('https://book.douban.com/').text
pattern = re.compile('<li.*?cover.*?href="(.*?)".*?title="(.*?)".*?more-meta.*?author">(.*?)</span>.*?year">(.*?)</span>.*?</li>', re.S)
results = re.findall(pattern, content)
print(results)
# Out:
# [('https://book.douban.com/subject/27102647/?icn=index-editionrecommend', '穿过生命中的泥泞时刻', '\n                    真实故事计划\n                  ', '\n                    2017-8\n                  '), ('https://book.douban.com/subject/27068494/?icn=index-editionrecommend', '手帖：南朝岁月', '\n                    蒋勋\n                  ', '\n                    2017-6\n                  '), ('https://book.douban.com/subject/27000191/?icn=index-editionrecommend', '自下而上', '\n                    [英] 马特·里德利\n                  ', '\n                    2017-7\n                  '), ('https://book.douban.com/subject/27093233/?icn=index-editionrecommend', '历史的温度', '\n                    张玮\n                  ', '\n                    2017-8-1\n                  '), ('https://book.douban.com/subject/27100549/?icn=index-editionrecommend', '不知归处', '\n                    双囍是朵花儿\n                  ', '\n                    2017-7\n                  '), ('https://book.douban.com/subject/27073040/?icn=index-latestbook-subject', '小小巴黎书店', '\n                    [德] 妮娜·乔治\n                  ', '\n                    2017-8\n                  '), ('https://book.douban.com/subject/26391029/?icn=index-latestbook-subject', '文稿拾零', '\n                    [阿根廷] 博尔赫斯\n                  ', '\n                    2017-7\n                  '), ('https://book.douban.com/subject/27096813/?icn=index-latestbook-subject', '上流法则', '\n                    [美] 埃默·托尔斯\n                  ', '\n                    2017-8\n                  '), ('https://book.douban.com/subject/27062550/?icn=index-latestbook-subject', '悠游小说林', '\n                    [意] 安贝托·艾柯\n                  ', '\n                    2017-8\n                  '), ('https://book.douban.com/subject/27077752/?icn=index-latestbook-subject', '温柔之歌', '\n                    [法] 蕾拉·斯利玛尼\n                  ', '\n                    2017-8-1\n                  '), ('https://book.douban.com/subject/27085617/?icn=index-latestbook-subject', '音乐与情感', '\n                    [美] 查尔斯·罗森\n                  ', '\n                    2017-7\n                  '), ('https://book.douban.com/subject/27078154/?icn=index-latestbook-subject', '搜神记', '\n                    冯唐\n                  ', '\n                    2017-8\n                  '), ('https://book.douban.com/subject/27081128/?icn=index-latestbook-subject', '万物：文明', '\n                    [德] 延斯·哈德\n                  ', '\n                    2017-8\n                  '), ('https://book.douban.com/subject/26694925/?icn=index-latestbook-subject', '白兔夫人', '\n                    [法] 吉尔·巴什莱\n                  ', '\n                    2017-9\n                  '), ('https://book.douban.com/subject/27077700/?icn=index-latestbook-subject', '在故宫寻找苏东坡', '\n                    祝勇\n                  ', '\n                    2017-7\n                  '), ('https://book.douban.com/subject/27087311/?icn=index-latestbook-subject', '鹰的王座', '\n                    [墨西哥] 卡洛斯·富恩特斯\n                  ', '\n                    2017-8\n                  '), ('https://book.douban.com/subject/27091051/?icn=index-latestbook-subject', '建筑改变日本', '\n                    [日] 伊东丰雄\n                  ', '\n                    2017-7\n                  '), ('https://book.douban.com/subject/27096938/?icn=index-latestbook-subject', '三个宝物', '\n                    [日]芥川龙之介\n                  ', '\n                    2017-7\n                  '), ('https://book.douban.com/subject/27082596/?icn=index-latestbook-subject', '海盗奇谭', '\n                    盛文强\n                  ', '\n                    2017-8\n                  '), ('https://book.douban.com/subject/27081783/?icn=index-latestbook-subject', '樱桃青衣', '\n                    张怡微\n                  ', '\n                    2017-7\n                  '), ('https://book.douban.com/subject/27025722/?icn=index-latestbook-subject', '最后的十字军东征', '\n                    [英] 奈杰尔·克利夫\n                  ', '\n                    2017-5-1\n                  '), ( ...

# %%
import requests
import re
content = requests.get('https://book.douban.com/').text
pattern = re.compile('<li.*?cover.*?href="(.*?)".*?title="(.*?)".*?more-meta.*?author">(.*?)</span>.*?year">(.*?)</span>.*?</li>', re.S)
results = re.findall(pattern, content)
for result in results:
    url, name, author, date = result
    print(url, name, author, date)
# Out:
# https://book.douban.com/subject/27102647/?icn=index-editionrecommend 穿过生命中的泥泞时刻
#                     真实故事计划
#
#                     2017-8
#
# https://book.douban.com/subject/27068494/?icn=index-editionrecommend 手帖：南朝岁月
#                     蒋勋
#
#                     2017-6
#
# https://book.douban.com/subject/27000191/?icn=index-editionrecommend 自下而上
#                     [英] 马特·里德利
#
#                     2017-7
#
# https://book.douban.com/subject/27093233/?icn=index-editionrecommend 历史的温度
#                     张玮
#
#                     2017-8-1
#
# https://book.douban.com/subject/27100549/?icn=index-editionrecommend 不知归处
#                     双囍是朵花儿
#
#                     2017-7
#
# https://book.douban.com/subject/27073403/?icn=index-latestbook-subject 等你呼唤我的名字
#                     [西] 阿尔伯特·埃斯皮诺萨
#
#                     2017-7
#
# https://book.douban.com/subject/27081128/?icn=index-latestbook-subject 万物：文明
#                     [德] 延斯·哈德
#
#                     2017-8
#
# https://book.douban.com/subject/27104259/?icn=index-latestbook-subject 盐
#                     孙频
#
#                     2017-8
#
# https://book.douban.com/subject/26901113/?icn=index-latestbook-subject 教养身体的政治
#                     [日] 深町英夫
#
#                     2017-7
#
# https://book.douban.com/subject/27069576/?icn=index-latestbook-subject 幻想曲
#                     Golo
#
#                     2017-7
#
# https://book.douban.com/subject/27025722/?icn=index-latestbook-subject 最后的十字军东征
#                     [英] 奈杰尔·克利夫
#
#                     2017-5-1
#
# https://book.douban.com/subject/27078154/?icn=index-latestbook-subject 搜神记
#                     冯唐
#
#                     2017-8
#
# https://book.douban.com/subject/27078238/?icn=index-latestbook-subject 写作课
#                     [美] 艾丽斯·马蒂森
#
#                     2017-8
#
# https://book.douban.com/subject/27073040/?icn=index-latestbook-subject 小小巴黎书店
#                     [德] 妮娜·乔治
#
#                     2017-8
#
# https://book.douban.com/subject/27077700/?icn=index-latestbook-subject 在故宫寻找苏东坡
#                     祝勇
#
#                     2017-7
#
# https://book.douban.com/subject/27086857/?icn=index-latestbook-subject 妈妈离婚记
#                     毛冷瞪
#
#                     2017-7
#
# https://book.douban.com/subject/27091051/?icn=index-latestbook-subject 建筑改变日本
#                     [日] 伊东丰雄
#
#                     2017-7
#
# https://book.douban.com/subject/27071333/?icn=index-latestbook-subject 法国中尉的女人
#                     [英] 约翰·福尔斯
#
#                     2017-8
#
# https://book.douban.com/subject/27097062/?icn=index-latestbook-subject 走出中东
#                     周轶君
#
#                     2017-8-1
#
# https://book.douban.com/subject/27104286/?icn=index-latestbook-subject 寂寞的游戏
#                     袁哲生
#
#                     2017-9
#
# https://book.douban.com/subject/27085768/?icn=index-latestbook-subject 巴黎：现代城市的发明
#                     [美] 若昂·德让
#
#                     2017-7
#
# https://book.douban.com/subject/27006493/?icn=index-latestbook-subject 戴上手套擦泪
#                     [瑞典] 乔纳斯·嘉德尔
#
#                     2017-8-31
#
# https://book.douban.com/subject/27087503/?icn=index-latestbook-subject 深度学习
#                     [美] 伊恩·古德费洛&nbsp;/&nbsp;[加] 约书亚·本吉奥&nbsp;/&nbsp;[加] 亚伦·库维尔
#
#                     2017-7-1
#
# https://book.douban.com/subject/27077752/?icn=index-latestbook-subject 温柔之歌
#                     [法] 蕾拉·斯利玛尼
#
#                     2017-8-1
#
# https://book.douban.com/subject/27085617/?icn=index-latestbook-subject 音乐与情感
#                     [美] 查尔斯·罗森
#
#                     2017-7
#
# https://book.douban.com/subject/27096938/?icn=index-latestbook-subject 三个宝物
#                     [日]芥川龙之介
#
#                     2017-7
#
# https://book.douban.com/subject/27092579/?icn=index-latestbook-subject 孤独的城市
#                     [英] 奥利维娅·莱恩
#
#                     2017-8
#
# https://book.douban.com/subject/27073559/?icn=index-latestbook-subject 兰亭序杀局1
#                     王觉仁
#
#                     2017-7-1
#
# https://book.douban.com/subject/27074630/?icn=index-latestbook-subject 大地蓝得像一只橙子
#                     [法] 保罗·艾吕雅
#
#                     2017-7
#
# https://book.douban.com/subject/26694925/?icn=index-latestbook-subject 白兔夫人
#                     [法] 吉尔·巴什莱
#
#                     2017-9
#
# https://book.douban.com/subject/26391029/?icn=index-latestbook-subject 文稿拾零
#                     [阿根廷] 博尔赫斯
#
#                     2017-7
#
# https://book.douban.com/subject/27064883/?icn=index-latestbook-subject 日蚀
#                     [日] 平野启一郎
#
#                     2017-8-1
#
# https://book.douban.com/subject/27082596/?icn=index-latestbook-subject 海盗奇谭
#                     盛文强
#
#                     2017-8
#
# https://book.douban.com/subject/27081783/?icn=index-latestbook-subject 樱桃青衣
#                     张怡微
#
#                     2017-7
#
# https://book.douban.com/subject/27089022/?icn=index-latestbook-subject 海洋中的爱与性
#                     [美] 玛拉·J. 哈尔特
#
#                     2017-8
#
# https://book.douban.com/subject/27099252/?icn=index-latestbook-subject 投敌者
#                     [德] 西格弗里德·伦茨
#
#                     2017-7
#
# https://book.douban.com/subject/27062550/?icn=index-latestbook-subject 悠游小说林
#                     [意] 安贝托·艾柯
#
#                     2017-8
#
# https://book.douban.com/subject/27107455/?icn=index-latestbook-subject 与情敌同居
#                     方悄悄
#
#                     2017-8-25
#
# https://book.douban.com/subject/27029273/?icn=index-latestbook-subject 如果这可以是首歌
#                     姚谦
#
#                     2017-7
#
# https://book.douban.com/subject/26720634/?icn=index-latestbook-subject 安德鲁的大脑
#                     [美] E.L.多克托罗
#
#                     2017-7
#
# https://www.douban.com/note/627607986/ 枪炮、病菌与钢铁（修订版）
#             [美] 贾雷德·戴蒙德
#
#             2006-4-1
#
# https://read.douban.com/ebook/2426691/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 心理罪：画像（电影《心理罪》原著）
#             雷米
#
#             2007-11
#
# https://read.douban.com/ebook/37712125/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 穆斯林的葬礼
#             霍达
#
#             2015-9
#
# https://read.douban.com/ebook/28465811/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 当呼吸化为空气
#             [美] 保罗·卡拉尼什
#
#             2016-12
#
# https://read.douban.com/ebook/33431245/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 美国众神
#             [英] 尼尔·盖曼
#
#             2017-4
#
# https://read.douban.com/ebook/37132118/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 歌以言志
#             周毅 / 舒明
#
#             2017-1-1
#
# https://read.douban.com/ebook/16824505/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 遗落的南境1：湮灭
#             [美] 杰夫·范德米尔
#
#             2015-12
#
# https://read.douban.com/ebook/8937101/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 从0到1
#             彼得·蒂尔 / 布莱克·马斯特斯
#
#             2015-1-1
#
# https://read.douban.com/ebook/36355268/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 穿越平行宇宙
#             [美]迈克斯•泰格马克 （Max Tegmark）
#
#             2017-6
#
# https://read.douban.com/ebook/37743048/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 动物凶猛
#             王朔
#
#             2015-3

# %%
import requests
import re
content = requests.get('https://book.douban.com/').text
pattern = re.compile('<li.*?cover.*?href="(.*?)".*?title="(.*?)".*?more-meta.*?author">(.*?)</span>.*?year">(.*?)</span>.*?</li>', re.S)
results = re.findall(pattern, content)
for result in results:
    author = re.sub('\s', '', author)
    date = re.sub('\s', '', date)
    url, name, author, date = result
    print(url, name, author, date)
# Out:
# https://book.douban.com/subject/27102647/?icn=index-editionrecommend 穿过生命中的泥泞时刻
#                     真实故事计划
#
#                     2017-8
#
# https://book.douban.com/subject/27068494/?icn=index-editionrecommend 手帖：南朝岁月
#                     蒋勋
#
#                     2017-6
#
# https://book.douban.com/subject/27000191/?icn=index-editionrecommend 自下而上
#                     [英] 马特·里德利
#
#                     2017-7
#
# https://book.douban.com/subject/27093233/?icn=index-editionrecommend 历史的温度
#                     张玮
#
#                     2017-8-1
#
# https://book.douban.com/subject/27100549/?icn=index-editionrecommend 不知归处
#                     双囍是朵花儿
#
#                     2017-7
#
# https://book.douban.com/subject/27073559/?icn=index-latestbook-subject 兰亭序杀局1
#                     王觉仁
#
#                     2017-7-1
#
# https://book.douban.com/subject/27077700/?icn=index-latestbook-subject 在故宫寻找苏东坡
#                     祝勇
#
#                     2017-7
#
# https://book.douban.com/subject/27087311/?icn=index-latestbook-subject 鹰的王座
#                     [墨西哥] 卡洛斯·富恩特斯
#
#                     2017-8
#
# https://book.douban.com/subject/27025722/?icn=index-latestbook-subject 最后的十字军东征
#                     [英] 奈杰尔·克利夫
#
#                     2017-5-1
#
# https://book.douban.com/subject/27104259/?icn=index-latestbook-subject 盐
#                     孙频
#
#                     2017-8
#
# https://book.douban.com/subject/27062550/?icn=index-latestbook-subject 悠游小说林
#                     [意] 安贝托·艾柯
#
#                     2017-8
#
# https://book.douban.com/subject/27069576/?icn=index-latestbook-subject 幻想曲
#                     Golo
#
#                     2017-7
#
# https://book.douban.com/subject/26391029/?icn=index-latestbook-subject 文稿拾零
#                     [阿根廷] 博尔赫斯
#
#                     2017-7
#
# https://book.douban.com/subject/27071333/?icn=index-latestbook-subject 法国中尉的女人
#                     [英] 约翰·福尔斯
#
#                     2017-8
#
# https://book.douban.com/subject/27082596/?icn=index-latestbook-subject 海盗奇谭
#                     盛文强
#
#                     2017-8
#
# https://book.douban.com/subject/27064883/?icn=index-latestbook-subject 日蚀
#                     [日] 平野启一郎
#
#                     2017-8-1
#
# https://book.douban.com/subject/27074630/?icn=index-latestbook-subject 大地蓝得像一只橙子
#                     [法] 保罗·艾吕雅
#
#                     2017-7
#
# https://book.douban.com/subject/26720634/?icn=index-latestbook-subject 安德鲁的大脑
#                     [美] E.L.多克托罗
#
#                     2017-7
#
# https://book.douban.com/subject/27029273/?icn=index-latestbook-subject 如果这可以是首歌
#                     姚谦
#
#                     2017-7
#
# https://book.douban.com/subject/27104286/?icn=index-latestbook-subject 寂寞的游戏
#                     袁哲生
#
#                     2017-9
#
# https://book.douban.com/subject/27097062/?icn=index-latestbook-subject 走出中东
#                     周轶君
#
#                     2017-8-1
#
# https://book.douban.com/subject/27096813/?icn=index-latestbook-subject 上流法则
#                     [美] 埃默·托尔斯
#
#                     2017-8
#
# https://book.douban.com/subject/26901113/?icn=index-latestbook-subject 教养身体的政治
#                     [日] 深町英夫
#
#                     2017-7
#
# https://book.douban.com/subject/27073403/?icn=index-latestbook-subject 等你呼唤我的名字
#                     [西] 阿尔伯特·埃斯皮诺萨
#
#                     2017-7
#
# https://book.douban.com/subject/27089022/?icn=index-latestbook-subject 海洋中的爱与性
#                     [美] 玛拉·J. 哈尔特
#
#                     2017-8
#
# https://book.douban.com/subject/27078154/?icn=index-latestbook-subject 搜神记
#                     冯唐
#
#                     2017-8
#
# https://book.douban.com/subject/27085768/?icn=index-latestbook-subject 巴黎：现代城市的发明
#                     [美] 若昂·德让
#
#                     2017-7
#
# https://book.douban.com/subject/27096938/?icn=index-latestbook-subject 三个宝物
#                     [日]芥川龙之介
#
#                     2017-7
#
# https://book.douban.com/subject/27091051/?icn=index-latestbook-subject 建筑改变日本
#                     [日] 伊东丰雄
#
#                     2017-7
#
# https://book.douban.com/subject/27107455/?icn=index-latestbook-subject 与情敌同居
#                     方悄悄
#
#                     2017-8-25
#
# https://book.douban.com/subject/27073266/?icn=index-latestbook-subject 知日：这就是三岛由纪夫
#                     茶乌龙
#
#                     2017-8
#
# https://book.douban.com/subject/27006493/?icn=index-latestbook-subject 戴上手套擦泪
#                     [瑞典] 乔纳斯·嘉德尔
#
#                     2017-8-31
#
# https://book.douban.com/subject/27081128/?icn=index-latestbook-subject 万物：文明
#                     [德] 延斯·哈德
#
#                     2017-8
#
# https://book.douban.com/subject/27073040/?icn=index-latestbook-subject 小小巴黎书店
#                     [德] 妮娜·乔治
#
#                     2017-8
#
# https://book.douban.com/subject/27085617/?icn=index-latestbook-subject 音乐与情感
#                     [美] 查尔斯·罗森
#
#                     2017-7
#
# https://book.douban.com/subject/27099252/?icn=index-latestbook-subject 投敌者
#                     [德] 西格弗里德·伦茨
#
#                     2017-7
#
# https://book.douban.com/subject/27078238/?icn=index-latestbook-subject 写作课
#                     [美] 艾丽斯·马蒂森
#
#                     2017-8
#
# https://book.douban.com/subject/27077752/?icn=index-latestbook-subject 温柔之歌
#                     [法] 蕾拉·斯利玛尼
#
#                     2017-8-1
#
# https://book.douban.com/subject/27087503/?icn=index-latestbook-subject 深度学习
#                     [美] 伊恩·古德费洛&nbsp;/&nbsp;[加] 约书亚·本吉奥&nbsp;/&nbsp;[加] 亚伦·库维尔
#
#                     2017-7-1
#
# https://book.douban.com/subject/26694925/?icn=index-latestbook-subject 白兔夫人
#                     [法] 吉尔·巴什莱
#
#                     2017-9
#
# https://www.douban.com/note/627607986/ 枪炮、病菌与钢铁（修订版）
#             [美] 贾雷德·戴蒙德
#
#             2006-4-1
#
# https://read.douban.com/ebook/2426691/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 心理罪：画像（电影《心理罪》原著）
#             雷米
#
#             2007-11
#
# https://read.douban.com/ebook/37712125/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 穆斯林的葬礼
#             霍达
#
#             2015-9
#
# https://read.douban.com/ebook/28465811/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 当呼吸化为空气
#             [美] 保罗·卡拉尼什
#
#             2016-12
#
# https://read.douban.com/ebook/33431245/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 美国众神
#             [英] 尼尔·盖曼
#
#             2017-4
#
# https://read.douban.com/ebook/37132118/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 歌以言志
#             周毅 / 舒明
#
#             2017-1-1
#
# https://read.douban.com/ebook/16824505/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 遗落的南境1：湮灭
#             [美] 杰夫·范德米尔
#
#             2015-12
#
# https://read.douban.com/ebook/8937101/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 从0到1
#             彼得·蒂尔 / 布莱克·马斯特斯
#
#             2015-1-1
#
# https://read.douban.com/ebook/36355268/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 穿越平行宇宙
#             [美]迈克斯•泰格马克 （Max Tegmark）
#
#             2017-6
#
# https://read.douban.com/ebook/37743048/?dcs=book-hot&amp;dcm=douban&amp;dct=read-subject 动物凶猛
#             王朔
#
#             2015-3
