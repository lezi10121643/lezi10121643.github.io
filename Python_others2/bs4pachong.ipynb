# %%
import requests
newsurl='http://news.qq.com/'
res=requests.get(newsurl)
print(res.text)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="renderer" content="webkit" />
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <title>新闻中心_腾讯网</title>
#     <meta name="keywords" content="新闻 新闻中心 事实派 新闻频道,时事报道">
#     <meta name="description" content="腾讯新闻，事实派。新闻中心,包含有时政新闻、国内新闻、国际新闻、社会新闻、时事评论、新闻图片、新闻专题、新闻论坛、军事、历史、的专业时事报道门户网站">
#     <meta name="author" content="skeetershi" />
#     <link rel="stylesheet" type="text/css" href="http://mat1.gtimg.com/news/skeetershi/news_index/css/index.min_061601.css">
#     <link rel="alternate" type="application/vnd.wap.xhtml+xml" media="handheld" href="http://xw.qq.com/m/news/">
#     <!-- 2016.7.13 jackiejiang add house.com use-->
# <script src="http://mat1.gtimg.com/house/js/h5rewrite.js"></script>
#
# <!--2014.3.20 byAustinjin-->
# <!--20140225 menshen-->
# ...

# %%
from bs4 import BeautifulSoup
html_sample='<html> \
    <body> \
    <h1 id="title">Hello World</h1> \
    <a href="#" class="link">This is link1</a> \
    <a href="#link2" class="link">This is link2</a> \
    </body> \
</html>'

soup=BeautifulSoup(html_sample,'html.parser')#筛选器，除去所有标签
soup.text
# Out:
# '  Hello World This is link1 This is link2  '

# %%
soup.select('h1')#提取特定元素
# Out:
# [<h1 id="title">Hello World</h1>]

# %%
soup.select('h1')[0]#取列表中的第0个元素
# Out:
# <h1 id="title">Hello World</h1>

# %%
soup.select('h1')[0].text#把文字内容拿出来
# Out:
# 'Hello World'

# %%
soup.select('a')
# Out:
# [<a class="link" href="#">This is link1</a>,
#  <a class="link" href="#">This is link2</a>]

# %%
soup.select('a')[0]#取列表第一个元素
# Out:
# <a class="link" href="#">This is link1</a>

# %%
soup.select('a')[1]#取列表第二个元素
# Out:
# <a class="link" href="#link2">This is link2</a>

# %%
soup.select('a')[0].text#取列表第一个元素内容
# Out:
# 'This is link1'

# %%
for alink in soup.select('a'):
    print(alink.text)
# Out:
# This is link1
# This is link2

# %%
soup.select('#title')[0].text#y因为这里抓取的是标签id
# Out:
# 'Hello World'

# %%
soup.select('.link')[0].text
# Out:
# 'This is link1'

# %%
for link in soup.select('a'):
    print(link['href'])
# Out:
# #
# #link2

# %%
import requests
from bs4 import BeautifulSoup
res=requests.get('http://news.qq.com/')
#print(res)
soup=BeautifulSoup(res.text,'html.parser')
#print(soup)
for news in soup.select('.Q-tpWrap .text'):#Wrap后面一定有个空格，因为网页里有
    #print(news)
    print(news.select('a')[0].text,news.select('a')[0]['href'])
    print('===================================')
# Out:
# 杜特尔特声称将命军队占领南海争议岛礁 中方回应 http://news.qq.com/a/20170407/050077.htm
# ...
# 许勤任河北省副省长、代理省长(图/简历) http://news.qq.com/a/20170407/022093.htm
# ...
# 巴西众院弹劾总统案获通过 罗塞夫政党承认落败 http://news.qq.com/a/20160418/023091.htm
# ...
# 雄安新区安新县：公职人员要劝阻亲友在当地购房炒房 http://news.qq.com/a/20170407/036806.htm
# ...
# 江苏原副省长李云峰严重违纪被开除党籍和公职 http://news.qq.com/a/20170407/032625.htm
# ...
# 美官方：美国单独对叙实施打击 其他国家未参与 http://news.qq.com/a/20170407/027359.htm
# ...
# %%
import requests
from bs4 import BeautifulSoup
res=requests.get('http://r.qidian.com/yuepiao?chn=-1&page=1')
#print(res)
soup=BeautifulSoup(res.text,'html.parser')
#print(soup)
#for news in soup.select('.rank-view-list h4'):#Wrap后面一定有个空格，因为网页里有
for news in soup.select('.rank-view-list li'):#Wrap后面一定有个空格，因为网页里有    
    print(news)
    #print(news.select('a')[1].text,news.select('a')[2].text,news.select('a')[3].text,news.select('p')[1].text,news.select('p')[2].text,news.select('a')[0]['href'])

#    print('===================================')
# Out:
# <li data-rid="1">
# <div class="book-img-box">
# <span class="rank-tag no1">1<cite></cite></span>
# <a data-bid="1004608738" data-eid="qd_C39" href="//book.qidian.com/info/1004608738" target="_blank"><img src="//qidian.qpic.cn/qdbimg/349573/1004608738/150"/></a>
# </div>
# <div class="book-mid-info">
# <h4><a data-bid="1004608738" data-eid="qd_C40" href="//book.qidian.com/info/1004608738" target="_blank">圣墟</a></h4>
# <p class="author">
# <img src="//qidian.gtimg.com/qd/images/ico/user.0.1.png"><a class="name" data-eid="qd_C41" href="//me.qidian.com/authorIndex.aspx?id=4362453" target="_blank">辰东</a><em>|</em><a data-eid="qd_C42" href="//xuanhuan.qidian.com" target="_blank">玄幻</a><em>|</em><span>连载</span>
# </img></p>
# <p class="intro">
#                                         在破败中崛起，在寂灭中复苏。沧海成尘，雷电枯竭，那一缕幽雾又一次临近大地，世间的枷锁被打开了，一个全新的世界就此揭开神秘的一角……
#                                     </p>
# ...

# %%
#https://chrome.google.com/webstore/detail/infolite/ipjbadabbpedegielkhgpiekdlmfpgal

# %%
import requests
from bs4 import BeautifulSoup
res=requests.get('http://r.qidian.com/yuepiao?chn=-1&page=1')
#print(res)
soup=BeautifulSoup(res.text,'html.parser')
#print(soup)
#for news in soup.select('.rank-view-list h4'):#Wrap后面一定有个空格，因为网页里有
newsary=[]
for news in soup.select('.rank-view-list li'):#Wrap后面一定有个空格，因为网页里有    
    #print(news)
    #print(news.select('a')[1].text,news.select('a')[2].text,news.select('a')[3].text,news.select('p')[1].text,news.select('p')[2].text,news.select('a')[0]['href'])
    newsary.append({'title':news.select('a')[1].text,'name':news.select('a')[2].text,'style':news.select('a')[3].text,'describe':news.select('p')[2].text,'url':news.select('a')[0]['href']})

# %%
len(newsary)
# Out:
# 20

# %%
import pandas
newsdf=pandas.DataFrame(newsary)
newsdf
# Out:
#                                        describe     name style    title  \
# 0          最新更新 第三百二十一章 福祸相依·2017-04-07 20:57\n       辰东    玄幻       圣墟
# 1        最新更新 第706章 目瞪口呆的巨鬼王·2017-04-07 17:50\n       耳根    仙侠     一念永恒
# 2             最新更新 第2413章沐少晨·2017-04-07 18:10\n     厌笔萧生    玄幻       帝霸
# 3       最新更新 第872章 强势碾压（第二更）·2017-04-07 09:01\n     十里剑神    都市  重生之都市修仙
# 4        最新更新 第七百零三章 平安藤山不平安·2017-04-07 21:00\n     鹅是老五    仙侠     不朽凡人
# 5    最新更新 第1172章 各地高手汇聚（第三更）·2017-04-07 21:35\n    EK巧克力    玄幻     剑逆苍穹
# 6            最新更新 第三百八十章 打上门·2017-04-07 19:00\n     横扫天涯    玄幻    天道图书馆
# 7         最新更新 第一一二章 黑夜中的萤火虫·2017-04-07 18:35\n      跃千愁    仙侠       道君
# 8            最新更新 第六十二章 极限之后·2017-04-07 14:04\n     骷髅精灵    仙侠     斗战狂潮
# 9                最新更新 363、轮渡·2017-04-07 22:33\n  争斤论两花花帽    都市   我的1979
# 10         最新更新 第六百八十六章 神的遗物·2017-04-07 23:02\n       二目    奇幻   放开那个女巫
# 11          最新更新 第1512章【三年后】·2017-04-07 18:51\n       尝谕    职场   我真是大明星
# ...

# %%
newsdf.to_excel('news.xlsx')#输入到to按住Tab有很多格式，储存

# %%
import requests
from bs4 import BeautifulSoup
newsary=[]
for i in range(25):
    res=requests.get('http://r.qidian.com/yuepiao?chn=-1&page='+str(i))
#print(res)
    soup=BeautifulSoup(res.text,'html.parser')
#print(soup)
#for news in soup.select('.rank-view-list h4'):#Wrap后面一定有个空格，因为网页里有

    for news in soup.select('.rank-view-list li'):#Wrap后面一定有个空格，因为网页里有    
    #print(news)
    #print(news.select('a')[1].text,news.select('a')[2].text,news.select('a')[3].text,news.select('p')[1].text,news.select('p')[2].text,news.select('a')[0]['href'])
        newsary.append({'title':news.select('a')[1].text,'name':news.select('a')[2].text,'style':news.select('a')[3].text,'describe':news.select('p')[1].text,'lastest':news.select('p')[2].text,'url':news.select('a')[0]['href']})

# %%
len(newsary)
# Out:
# 500

# %%
print(newsary)
# Out:
# [{'url': '//book.qidian.com/info/1004608738', 'describe': '最新更新 第三百二十三章 另一条辉煌路·2017-04-08 21:10\n', 'style': '玄幻', 'name': '辰东', 'title': '圣墟'}, {'url': '//book.qidian.com/info/1003354631', 'describe': '最新更新 第708章 我是你的师尊！·2017-04-08 17:50\n', 'style': '仙侠', 'name': '耳根', 'title': '一念永恒'}, {'url': '//book.qidian.com/info/3258971', 'describe': '最新更新 第2415章蜕变·2017-04-08 18:10\n', 'style': '玄幻', 'name': '厌笔萧生', 'title': '帝霸'}, {'url': '//book.qidian.com/info/3548786', 'describe': '最新更新 第874章 璀璨如斯（第一更）·2017-04-08 21:48\n', 'style': '都市', 'name': '十里剑神', 'title': '重生之都市修仙'}, {'url': '//book.qidian.com/info/1003307568', 'describe': '最新更新 第七百零五章 我知道出路·2017-04-08 21:00\n', 'style': '仙侠', 'name': '鹅是老五', 'title': '不朽凡人'}, {'url': '//book.qidian.com/info/1004179514', 'describe': '最新更新 三章已更！求月票！·2017-04-08 17:04\n', 'style': '玄幻', 'name': '横扫天涯', 'title': '天道图书馆'}, {'url': '//book.qidian.com/info/2371777', 'describe': '最新更新 第1176章 上位神家族（第二更）·2017-04-08 20:48\n', 'style': '玄幻', 'name': 'EK巧克力', '
# ...

# %%
import pandas
newsdf=pandas.DataFrame(newsary)
newsdf
# Out:
#                                               describe  \
# 0    \r\n                                        在破...
# 1    \r\n                                        一念...
# 2    \r\n                                        千万...
# 3    \r\n                                        正式...
# 4    \r\n                                        在这...
# 5    \r\n                                        剑道...
# 6    \r\n                                        张悬...
# 7    \r\n                                        一个...
# 8    \r\n                                        双月...
# 9    \r\n                                        一觉...
# 10   \r\n                                        程岩...
# 11   \r\n                                        一心...
# 12   \r\n                                        森罗...
# 13   \r\n                                        在这...
# 14   \r\n                                        爱黄...
# 15   \r\n                                        老牌...
# ...

# %%
newsdf.to_excel('qidian_rank1.xlsx')#输入到to按住Tab有很多格式，储存
