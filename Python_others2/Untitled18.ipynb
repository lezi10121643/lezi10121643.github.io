# %%
import urllib.request
from bs4 import BeautifulSoup
import lxml

req = urllib.request.urlopen('https://www.qidian.com/rank/hotsales?page=1')
req1 = req.read().decode('UTF-8')

soup = BeautifulSoup(req1,'lxml')

for ul in soup.select('ul'):
    
    print(ul.select('li'))
# Out:
#         </b>页游</a> <div class="game-dropdown hidden" id="web-dropdown"> <cite></cite> <div class="web-game-list"> <dl class="lately" id="lately"> <dt>最近玩过</dt> <dd data-rid="1"><a class="name" data-eid="qd_A29" href="javascript:" target="_blank"></a><strong></strong><a class="link" data-eid="qd_A29" href="javascript:" target="_blank">GO<i>&gt;</i></a></dd> <dd data-rid="2"><a class="name" data-eid="qd_A30" href="javascript:" target="_blank"></a><strong></strong><a class="link" data-eid="qd_A30" href="javascript:" target="_blank">GO<i>&gt;</i></a></dd> </dl> <dl class="web-list" id="log-web-list"> <dt>今日开服</dt> <dd class="act" data-rid="1"> <h3> <span></span> <i>11-21</i><a data-eid="qd_A31" href="http://cpgame.qd.game.qidian.com/Home/GameServer/lists?name=bjsg" target="_blank">霸将三国</a><strong>2区</strong></h3> <p><a data-eid="qd_A31" href="http://cpgame.qd.game.qidian.com/Home/GameServer/lists?name=bjsg" target="_blank"><img src="//qidian.qpic.cn/qidian_common/349573/dde0c11ff4c104e4
# ...
