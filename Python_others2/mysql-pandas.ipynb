# %%
#检测是否安装好环境
import MySQLdb
import pandas as pd

# %%
#使用python连接数据库
conn = MySQLdb.connect(
    host = '127.0.0.1',#本地地址
    user = 'root',#一般默认用户名
    passwd = 'wangdawei',#本地数据库登录密码
    db = 'test',#数据库名称
    port = 3306,#安装mysql默认的端口号
    charset = 'utf8'#设置数据库统一编码
)

# %%
sql = 'SELECT * FROM `tdb_goods`;'
df = pd.read_sql(sql,conn)

# %%
df.head()
# Out:
#    goods_id                  goods_name  cate_id  brand_id  goods_price  \
# 0         1            R510VC 15.6英寸笔记本        5         2       3399.0
# 1         2           Y400N 14.0英寸笔记本电脑        5         7       4899.0
# 2         3            G150TH 15.6英寸游戏本        4         9       8499.0
# 3         4            X550CC 15.6英寸笔记本        5         2       2799.0
# 4         5  X240(20ALA0EYCD) 12.5英寸超极本        7         7       4999.0
#
#    is_show  is_saleoff
# 0        1           0
# 1        1           0
# 2        1           0
# 3        1           0
# 4        1           0

# %%
sql1 = 'SELECT * FROM `tdb_goods` WHERE `cate_id` = 3;'
df1 = pd.read_sql(sql1,conn)
df1
# Out:
#    goods_id                 goods_name  cate_id  brand_id  goods_price  \
# 0        15         Z220SFF F4F06PA工作站        3         4       4288.0
# 1        16       PowerEdge T110 II服务器        3         5       5388.0
# 2        17  Mac Pro MD878CH/A 专业级台式电脑        3         8      28888.0
# 3        20     X3250 M4机架式服务器 2583i14        3         1       6888.0
#
#    is_show  is_saleoff
# 0        1           0
# 1        1           0
# 2        1           0
# 3        1           0

# %%
sql2 = 'SELECT * FROM `tdb_goods` WHERE `goods_price` > 5000;'
df2 = pd.read_sql(sql2,conn)
df2
# Out:
#    goods_id                 goods_name  cate_id  brand_id  goods_price  \
# 0         3           G150TH 15.6英寸游戏本        4         9       8499.0
# 1         7    SVP13226SCB 13.3英寸触控超极本        7         6       7999.0
# 2        13  iMac ME086CH/A 21.5英寸一体电脑        1         8       9188.0
# 3        16       PowerEdge T110 II服务器        3         5       5388.0
# 4        17  Mac Pro MD878CH/A 专业级台式电脑        3         8      28888.0
# 5        18             HMZ-T3W 头戴显示设备        6         6       6999.0
# 6        20     X3250 M4机架式服务器 2583i14        3         1       6888.0
# 7        34                伟哥牌notebook        8         1      66666.0
# 8        36                伟哥牌notebook        8         1      66666.0
# 9        39                伟哥牌notebook        8         1      66666.0
#
#    is_show  is_saleoff
# 0        1           0
# 1        1           0
# 2        1           0
# 3        1           0
# 4        1           0
# 5        1           0
# 6        1           0
# 7        1           0
# 8        1           0
# 9        1           0

# %%
sql2 = 'SELECT * FROM `tdb_goods` WHERE `goods_price` > 5000 ORDER BY `goods_price;'
df2 = pd.read_sql(sql2,conn)
df2
# Out:
#    goods_id                 goods_name  cate_id  brand_id  goods_price  \
# 0        16       PowerEdge T110 II服务器        3         5       5388.0
# 1        20     X3250 M4机架式服务器 2583i14        3         1       6888.0
# 2        18             HMZ-T3W 头戴显示设备        6         6       6999.0
# 3         7    SVP13226SCB 13.3英寸触控超极本        7         6       7999.0
# 4         3           G150TH 15.6英寸游戏本        4         9       8499.0
# 5        13  iMac ME086CH/A 21.5英寸一体电脑        1         8       9188.0
# 6        17  Mac Pro MD878CH/A 专业级台式电脑        3         8      28888.0
# 7        34                伟哥牌notebook        8         1      66666.0
# 8        36                伟哥牌notebook        8         1      66666.0
# 9        39                伟哥牌notebook        8         1      66666.0
#
#    is_show  is_saleoff
# 0        1           0
# 1        1           0
# 2        1           0
# 3        1           0
# 4        1           0
# 5        1           0
# 6        1           0
# 7        1           0
# 8        1           0
# 9        1           0

# %%
sql2 = 'SELECT * FROM `tdb_goods` WHERE `goods_price` > 5000 ORDER BY `goods_price` DESC;'
df2 = pd.read_sql(sql2,conn)
df2
# Out:
#    goods_id                 goods_name  cate_id  brand_id  goods_price  \
# 0        39                伟哥牌notebook        8         1      66666.0
# 1        36                伟哥牌notebook        8         1      66666.0
# 2        34                伟哥牌notebook        8         1      66666.0
# 3        17  Mac Pro MD878CH/A 专业级台式电脑        3         8      28888.0
# 4        13  iMac ME086CH/A 21.5英寸一体电脑        1         8       9188.0
# 5         3           G150TH 15.6英寸游戏本        4         9       8499.0
# 6         7    SVP13226SCB 13.3英寸触控超极本        7         6       7999.0
# 7        18             HMZ-T3W 头戴显示设备        6         6       6999.0
# 8        20     X3250 M4机架式服务器 2583i14        3         1       6888.0
# 9        16       PowerEdge T110 II服务器        3         5       5388.0
#
#    is_show  is_saleoff
# 0        1           0
# 1        1           0
# 2        1           0
# 3        1           0
# 4        1           0
# 5        1           0
# 6        1           0
# 7        1           0
# 8        1           0
# 9        1           0

# %%
sql3 = 'SELECT * FROM `tdb_goods` WHERE `goods_name` like "%平板电脑%";'
df3 = pd.read_sql(sql3,conn)
df3
# Out:
#    goods_id                                         goods_name  cate_id  \
# 0         8                      iPad mini MD531CH/A 7.9英寸平板电脑        2
# 1         9           iPad Air MD788CH/A 9.7英寸平板电脑 （16G WiFi版）        2
# 2        10   iPad mini ME279CH/A 配备 Retina 显示屏 7.9英寸平板电脑 （...        2
#
#    brand_id  goods_price  is_show  is_saleoff
# 0         8       1998.0        1           0
# 1         8       3388.0        1           0
# 2         8       2788.0        1           0

# %%
df.to_csv('E:\goods_info.csv', encoding = 'utf-8', index = False)

# %%
conn.close()

# %%
sql = 'SELECT * FROM `tdb_goods`;'
df = pd.read_sql(sql,conn)
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1403             else:
# -> 1404                 cur.execute(*args)
#    1405             return cur
#
# C:\ProgramData\Anaconda3\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     249             exc, value = sys.exc_info()[:2]
# --> 250             self.errorhandler(self, exc, value)
#     251         self._executed = query
#
# C:\ProgramData\Anaconda3\lib\site-packages\MySQLdb\connections.py in defaulterrorhandler(***failed resolving arguments***)
#      49     if isinstance(errorvalue, BaseException):
# ---> 50         raise errorvalue
#      51     if errorclass is not None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\MySQLdb\cursors.py in execute(self, query, args)
#     246         try:
# --> 247             res = self._query(query)
#     248         except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\MySQLdb\cursors.py in _query(self, q)
#     410     def _query(self, q):
# --> 411         rowcount = self._do_query(q)
#     412         self._post_get_result()
#
# C:\ProgramData\Anaconda3\lib\site-packages\MySQLdb\cursors.py in _do_query(self, q)
#     373         self._last_executed = q
# --> 374         db.query(q)
#     375         self._do_get_result()
#
# C:\ProgramData\Anaconda3\lib\site-packages\MySQLdb\connections.py in query(self, query)
#     291         else:
# --> 292             _mysql.connection.query(self, query)
#     293
#
# InterfaceError: (0, '')
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1407             try:
# -> 1408                 self.con.rollback()
#    1409             except Exception:  # pragma: no cover
#
# OperationalError: (2006, 'MySQL server has gone away')
#
# During handling of the above exception, another exception occurred:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-32-f12c87ea7079> in <module>()
#       1 sql = 'SELECT * FROM `tdb_goods`;'
# ----> 2 df = pd.read_sql(sql,conn)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     398             sql, index_col=index_col, params=params,
#     399             coerce_float=coerce_float, parse_dates=parse_dates,
# --> 400             chunksize=chunksize)
#     401
#     402     try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1437
#    1438         args = _convert_params(sql, params)
# -> 1439         cursor = self.execute(*args)
#    1440         columns = [col_desc[0] for col_desc in cursor.description]
#    1441
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1410                 ex = DatabaseError("Execution failed on sql: %s\n%s\nunable"
#    1411                                    " to rollback" % (args[0], exc))
# -> 1412                 raise_with_traceback(ex)
#    1413
#    1414             ex = DatabaseError(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\compat\__init__.py in raise_with_traceback(exc, traceback)
#     342         if traceback == Ellipsis:
#     343             _, _, traceback = sys.exc_info()
# --> 344         raise exc.with_traceback(traceback)
#     345 else:
#     346     # this version of raise is a syntax error in Python 3
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1406         except Exception as exc:
#    1407             try:
# -> 1408                 self.con.rollback()
#    1409             except Exception:  # pragma: no cover
#    1410                 ex = DatabaseError("Execution failed on sql: %s\n%s\nunable"
#
# DatabaseError: Execution failed on sql: SELECT * FROM `tdb_goods`;
# (0, '')
# unable to rollback
